# %% [markdown]
# # BAGECO 2025 - Metagenomics Workshop
#
# **From Sequences to Predictions – End-to-end analysis using BioAutoML**
#
# *This class was developed for the 17th Symposium on Bacterial Genetics and Ecology (BAGECO 2025) and will be presented at the Metagenomics Workshop on 30.06.2025.*
#
# *For any questions regarding this material, please contact:*
#
# *Breno L. S. de Almeida: breno.livio-silva.de.almeida@ufz.de*
#
# ---
#
# This Jupyter Notebook demonstrates how to use [BioAutoML](https://academic.oup.com/bib/article/23/4/bbac218/6618238) without requiring any local installation.
#
# The demonstration includes three use cases:
#
# 1. Multi-class prediction of DNA/RNA sequences (more than two classes)
#
# 2. Binary classification of protein sequences (two classes)
#
# 3. Prediction using structured data
#
# ---

# %% [markdown]
# ## 1. Installing BioAutoML

# %% [markdown]
# First, let's clone the BioAutoML repository from GitHub using Git. Then, we'll navigate into the BioAutoML directory.

# %%
# !git clone https://github.com/Bonidia/BioAutoML.git BioAutoML
# %cd /content/BioAutoML
# Out:
# Cloning into 'BioAutoML'...
# remote: Enumerating objects: 1081, done.
# remote: Counting objects: 100% (357/357), done.
# remote: Compressing objects: 100% (206/206), done.
# remote: Total 1081 (delta 195), reused 256 (delta 148), pack-reused 724 (from 1)
# Receiving objects: 100% (1081/1081), 82.17 MiB | 10.89 MiB/s, done.
# Resolving deltas: 100% (470/470), done.
# Updating files: 100% (416/416), done.
# /content/BioAutoML

# %% [markdown]
# We’ll use Git to switch to the workshop-specific branch. Next, we'll download the required code to run MathFeature within BioAutoML.

# %%
# !git checkout bageco
# !git submodule init
# !git submodule update
# Out:
# Branch 'bageco' set up to track remote branch 'bageco' from 'origin'.
# Switched to a new branch 'bageco'
# Submodule 'MathFeature' (https://github.com/Bonidia/MathFeature.git) registered for path 'MathFeature'
# Submodule 'MathFeature-WebServer' (https://github.com/Bonidia/MathFeature-WebServer.git) registered for path 'MathFeature-WebServer'
# Cloning into '/content/BioAutoML/MathFeature'...
# Cloning into '/content/BioAutoML/MathFeature-WebServer'...
# Submodule path 'MathFeature': checked out '69d2a3206c6db02be9d46db74ad61fc05cc6aee2'
# Submodule path 'MathFeature-WebServer': checked out '5d13e073b30d0f9b333adb411bc843722c09d0ba'

# %% [markdown]
# Let's now retrieve all the necessary packages to run BioAutoML. For our demonstration we will use [uv](https://astral.sh/blog/uv), a very fast package manager.
#
# If you really want to install BioAutoML locally, you can use miniconda installed in your machine. Do all the steps from before, with the exception of `!git checkout bageco`, and run the following:
#
# ```bash
# conda env create -f BioAutoML-env.yml -n bioautoml
# ```
#
# This will install any necessary packages for BioAutoML in a isolated environment and access with:
#
# ```bash
# conda activate bioautoml
# ```
#
# And exit the environment with:
#
# ```bash
# conda deactivate
# ```
#
# Let's continue using uv with the command sync to download all the necessary packages.

# %%
#!uv add scikit-learn==1.1.0 pandas catboost lightgbm matplotlib-inline  hyperopt setuptools biopython xgboost imbalanced-learn igraph tpot
# !uv sync
# Out:
# Using CPython 3.8.20
# Creating virtual environment at: .venv
# Resolved 80 packages in 6ms
# ⠙ Preparing packages... (0/49)
# ⠙ Preparing packages... (0/49)
# ⠙ Preparing packages... (0/49)
# pytz       ------------------------------     0 B/497.29 KiB
# ⠙ Preparing packages... (0/49)
# pytz       ------------------------------ 14.91 KiB/497.29 KiB
# ⠙ Preparing packages... (0/49)
# tzdata     ------------------------------     0 B/339.69 KiB
# pytz       ------------------------------ 14.91 KiB/497.29 KiB
# ⠙ Preparing packages... (0/49)
# tzdata     ------------------------------ 14.91 KiB/339.69 KiB
# pytz       ------------------------------ 14.91 KiB/497.29 KiB
# ⠙ Preparing packages... (0/49)
# python-dateutil ------------------------------     0 B/224.50 KiB
# tzdata     ------------------------------ 14.91 KiB/339.69 KiB
# pytz       ------------------------------ 14.91 KiB/497.29 KiB
# ⠙ Preparing packages... (0/49)
# python-dateutil ------------------------------ 14.90 KiB/224.50 KiB
# tzdata     ------------------------------ 14.91 KiB/339.69 KiB
# pytz       ------------------------------ 14.91 KiB/497.29 KiB
# ⠙ Preparing packages... (0/49)
# certifi    ------------------------------     0 B/153.96 KiB
# python-dateutil ------------------------------ 14.90 KiB/224.50 KiB
# tzdata     ------------------------------ 14.91 KiB/339.69 KiB
# pytz       ------------------------------ 14.91 KiB/497.29 KiB
# ⠙ Preparing packages... (0/49)
# certifi    ------------------------------ 14.91 KiB/153.96 KiB
# python-dateutil ------------------------------ 14.90 KiB/224.50 KiB
# tzdata     ------------------------------ 14.91 KiB/339.69 KiB
# pytz       ------------------------------ 14.91 KiB/497.29 KiB
# ⠙ Preparing packages... (0/49)
# charset-normalizer ------------------------------     0 B/143.96 KiB
# certifi    ------------------------------ 14.91 KiB/153.96 KiB
# python-dateutil ------------------------------ 14.90 KiB/224.50 KiB
# tzdata     ------------------------------ 14.91 KiB/339.69 KiB
# pytz       ------------------------------ 14.91 KiB/497.29 KiB
# ⠙ Preparing packages... (0/49)
# charset-normalizer ------------------------------ 14.90 KiB/143.96 KiB
# certifi    ------------------------------ 14.91 KiB/153.96 KiB
# python-dateutil ------------------------------ 14.90 KiB/224.50 KiB
# tzdata     ------------------------------ 14.91 KiB/339.69 KiB
# pytz       ------------------------------ 14.91 KiB/497.29 KiB
# ⠙ Preparing packages... (0/49)
# urllib3    ------------------------------     0 B/123.38 KiB
# charset-normalizer ------------------------------ 14.90 KiB/143.96 KiB
# certifi    ------------------------------ 14.91 KiB/153.96 KiB
# python-dateutil ------------------------------ 14.90 KiB/224.50 KiB
# tzdata     ------------------------------ 14.91 KiB/339.69 KiB
# pytz       ------------------------------ 14.91 KiB/497.29 KiB
# ⠙ Preparing packages... (0/49)
# urllib3    ------------------------------ 14.91 KiB/123.38 KiB
# charset-normalizer ------------------------------ 14.90 KiB/143.96 KiB
# certifi    ------------------------------ 14.91 KiB/153.96 KiB
# python-dateutil ------------------------------ 14.90 KiB/224.50 KiB
# tzdata     ------------------------------ 14.91 KiB/339.69 KiB
# pytz       ------------------------------ 14.91 KiB/497.29 KiB
# ⠙ Preparing packages... (0/49)
# idna       ------------------------------     0 B/68.79 KiB
# urllib3    ------------------------------ 14.91 KiB/123.38 KiB
# charset-normalizer ------------------------------ 14.90 KiB/143.96 KiB
# certifi    ------------------------------ 14.91 KiB/153.96 KiB
# python-dateutil ------------------------------ 14.90 KiB/224.50 KiB
# tzdata     ------------------------------ 14.91 KiB/339.69 KiB
# pytz       ------------------------------ 14.91 KiB/497.29 KiB
# ⠙ Preparing packages... (0/49)
# idna       ------------------------------ 14.92 KiB/68.79 KiB
# urllib3    ------------------------------ 14.91 KiB/123.38 KiB
# charset-normalizer ------------------------------ 14.90 KiB/143.96 KiB
# certifi    ------------------------------ 14.91 KiB/153.96 KiB
# python-dateutil ------------------------------ 14.90 KiB/224.50 KiB
# tzdata     ------------------------------ 14.91 KiB/339.69 KiB
# pytz       ------------------------------ 14.91 KiB/497.29 KiB
# ⠙ Preparing packages... (0/49)
# packaging  ------------------------------     0 B/64.91 KiB
# idna       ------------------------------ 14.92 KiB/68.79 KiB
# urllib3    ------------------------------ 14.91 KiB/123.38 KiB
# charset-normalizer ------------------------------ 14.90 KiB/143.96 KiB
# certifi    ------------------------------ 14.91 KiB/153.96 KiB
# python-dateutil ------------------------------ 14.90 KiB/224.50 KiB
# tzdata     ------------------------------ 14.91 KiB/339.69 KiB
# pytz       ------------------------------ 14.91 KiB/497.29 KiB
# ⠙ Preparing packages... (0/49)
# packaging  ------------------------------ 1.87 KiB/64.91 KiB
# idna       ------------------------------ 14.92 KiB/68.79 KiB
# urllib3    ------------------------------ 14.91 KiB/123.38 KiB
# charset-normalizer ------------------------------ 14.90 KiB/143.96 KiB
# certifi    ------------------------------ 14.91 KiB/153.96 KiB
# python-dateutil ------------------------------ 14.90 KiB/224.50 KiB
# tzdata     ------------------------------ 14.91 KiB/339.69 KiB
# pytz       ------------------------------ 14.91 KiB/497.29 KiB
# ⠙ Preparing packages... (0/49)
# zipp       ------------------------------ 8.98 KiB/8.98 KiB
# matplotlib-inline ------------------------------ 9.67 KiB/9.67 KiB
# texttable  ------------------------------ 10.52 KiB/10.52 KiB
# six        ------------------------------ 10.79 KiB/10.79 KiB
# threadpoolctl ------------------------------ 14.91 KiB/17.98 KiB
# cloudpickle ------------------------------ 14.91 KiB/20.50 KiB
# importlib-resources ------------------------------ 14.90 KiB/35.27 KiB
# graphviz   ------------------------------ 14.95 KiB/46.02 KiB
# requests   ------------------------------ 14.91 KiB/63.33 KiB
# packaging  ------------------------------ 1.87 KiB/64.91 KiB
# idna       ------------------------------ 14.92 KiB/68.79 KiB
# tqdm       ------------------------------ 8.47 KiB/76.70 KiB
# traitlets  ------------------------------ 14.94 KiB/83.36 KiB
# tpot       ------------------------------ 16.00 KiB/85.33 KiB
# pyparsing  ------------------------------ 14.91 KiB/101.66 KiB
# urllib3    ------------------------------ 14.91 KiB/123.38 KiB
# charset-normalizer ------------------------------ 14.90 KiB/143.96 KiB
# certifi    ------------------------------ 153.96 KiB/153.96 KiB
# py4j       ------------------------------ 14.91 KiB/198.25 KiB
# python-dateutil ------------------------------ 14.90 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 16.00 KiB/252.27 KiB
# contourpy  ------------------------------ 14.96 KiB/294.07 KiB
# ⠙ Preparing packages... (0/49)
# update-checker ------------------------------ 6.84 KiB/6.84 KiB
# cycler     ------------------------------ 8.13 KiB/8.13 KiB
# zipp       ------------------------------ 8.98 KiB/8.98 KiB
# matplotlib-inline ------------------------------ 9.67 KiB/9.67 KiB
# texttable  ------------------------------ 10.52 KiB/10.52 KiB
# six        ------------------------------ 10.79 KiB/10.79 KiB
# threadpoolctl ------------------------------ 14.91 KiB/17.98 KiB
# cloudpickle ------------------------------ 20.50 KiB/20.50 KiB
# importlib-resources ------------------------------ 14.90 KiB/35.27 KiB
# graphviz   ------------------------------ 14.95 KiB/46.02 KiB
# requests   ------------------------------ 14.91 KiB/63.33 KiB
# packaging  ------------------------------ 14.91 KiB/64.91 KiB
# idna       ------------------------------ 30.92 KiB/68.79 KiB
# tqdm       ------------------------------ 8.47 KiB/76.70 KiB
# traitlets  ------------------------------ 14.94 KiB/83.36 KiB
# tpot       ------------------------------ 32.00 KiB/85.33 KiB
# pyparsing  ------------------------------ 14.91 KiB/101.66 KiB
# urllib3    ------------------------------ 14.91 KiB/123.38 KiB
# charset-normalizer ------------------------------ 14.90 KiB/143.96 KiB
# certifi    ------------------------------ 153.96 KiB/153.96 KiB
# py4j       ------------------------------ 14.91 KiB/198.25 KiB
# python-dateutil ------------------------------ 14.90 KiB/224.50 KiB
# ⠙ Preparing packages... (0/49)
# update-checker ------------------------------ 6.84 KiB/6.84 KiB
# cycler     ------------------------------ 8.13 KiB/8.13 KiB
# zipp       ------------------------------ 8.98 KiB/8.98 KiB
# matplotlib-inline ------------------------------ 9.67 KiB/9.67 KiB
# six        ------------------------------ 10.79 KiB/10.79 KiB
# threadpoolctl ------------------------------ 17.98 KiB/17.98 KiB
# cloudpickle ------------------------------ 20.50 KiB/20.50 KiB
# importlib-resources ------------------------------ 14.90 KiB/35.27 KiB
# graphviz   ------------------------------ 14.95 KiB/46.02 KiB
# requests   ------------------------------ 14.91 KiB/63.33 KiB
# packaging  ------------------------------ 14.91 KiB/64.91 KiB
# idna       ------------------------------ 30.92 KiB/68.79 KiB
# tqdm       ------------------------------ 8.47 KiB/76.70 KiB
# traitlets  ------------------------------ 46.94 KiB/83.36 KiB
# tpot       ------------------------------ 32.00 KiB/85.33 KiB
# pyparsing  ------------------------------ 78.91 KiB/101.66 KiB
# urllib3    ------------------------------ 46.91 KiB/123.38 KiB
# charset-normalizer ------------------------------ 30.90 KiB/143.96 KiB
# certifi    ------------------------------ 153.96 KiB/153.96 KiB
# py4j       ------------------------------ 42.43 KiB/198.25 KiB
# python-dateutil ------------------------------ 30.90 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 32.00 KiB/252.27 KiB
# ⠙ Preparing packages... (0/49)
# update-checker ------------------------------ 6.84 KiB/6.84 KiB
# cycler     ------------------------------ 8.13 KiB/8.13 KiB
# zipp       ------------------------------ 8.98 KiB/8.98 KiB
# matplotlib-inline ------------------------------ 9.67 KiB/9.67 KiB
# threadpoolctl ------------------------------ 17.98 KiB/17.98 KiB
# cloudpickle ------------------------------ 20.50 KiB/20.50 KiB
# importlib-resources ------------------------------ 14.90 KiB/35.27 KiB
# graphviz   ------------------------------ 14.95 KiB/46.02 KiB
# requests   ------------------------------ 14.91 KiB/63.33 KiB
# packaging  ------------------------------ 14.91 KiB/64.91 KiB
# idna       ------------------------------ 68.79 KiB/68.79 KiB
# tqdm       ------------------------------ 14.92 KiB/76.70 KiB
# traitlets  ------------------------------ 46.94 KiB/83.36 KiB
# tpot       ------------------------------ 32.00 KiB/85.33 KiB
# pyparsing  ------------------------------ 78.91 KiB/101.66 KiB
# urllib3    ------------------------------ 46.91 KiB/123.38 KiB
# charset-normalizer ------------------------------ 124.66 KiB/143.96 KiB
# certifi    ------------------------------ 153.96 KiB/153.96 KiB
# py4j       ------------------------------ 42.43 KiB/198.25 KiB
# python-dateutil ------------------------------ 30.90 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 32.00 KiB/252.27 KiB
# contourpy  ------------------------------ 14.96 KiB/294.07 KiB
# ⠹ Preparing packages... (1/49)
# update-checker ------------------------------ 6.84 KiB/6.84 KiB
# cycler     ------------------------------ 8.13 KiB/8.13 KiB
# zipp       ------------------------------ 8.98 KiB/8.98 KiB
# matplotlib-inline ------------------------------ 9.67 KiB/9.67 KiB
# threadpoolctl ------------------------------ 17.98 KiB/17.98 KiB
# cloudpickle ------------------------------ 20.50 KiB/20.50 KiB
# importlib-resources ------------------------------ 14.90 KiB/35.27 KiB
# graphviz   ------------------------------ 14.95 KiB/46.02 KiB
# requests   ------------------------------ 14.91 KiB/63.33 KiB
# packaging  ------------------------------ 14.91 KiB/64.91 KiB
# idna       ------------------------------ 68.79 KiB/68.79 KiB
# tqdm       ------------------------------ 14.92 KiB/76.70 KiB
# traitlets  ------------------------------ 46.94 KiB/83.36 KiB
# tpot       ------------------------------ 32.00 KiB/85.33 KiB
# pyparsing  ------------------------------ 78.91 KiB/101.66 KiB
# urllib3    ------------------------------ 46.91 KiB/123.38 KiB
# charset-normalizer ------------------------------ 124.66 KiB/143.96 KiB
# certifi    ------------------------------ 153.96 KiB/153.96 KiB
# py4j       ------------------------------ 42.43 KiB/198.25 KiB
# python-dateutil ------------------------------ 30.90 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 32.00 KiB/252.27 KiB
# contourpy  ------------------------------ 14.96 KiB/294.07 KiB
# ⠹ Preparing packages... (1/49)
# update-checker ------------------------------ 6.84 KiB/6.84 KiB
# cycler     ------------------------------ 8.13 KiB/8.13 KiB
# zipp       ------------------------------ 8.98 KiB/8.98 KiB
# matplotlib-inline ------------------------------ 9.67 KiB/9.67 KiB
# threadpoolctl ------------------------------ 17.98 KiB/17.98 KiB
# importlib-resources ------------------------------ 14.90 KiB/35.27 KiB
# graphviz   ------------------------------ 14.95 KiB/46.02 KiB
# requests   ------------------------------ 30.91 KiB/63.33 KiB
# packaging  ------------------------------ 14.91 KiB/64.91 KiB
# idna       ------------------------------ 68.79 KiB/68.79 KiB
# tqdm       ------------------------------ 14.92 KiB/76.70 KiB
# traitlets  ------------------------------ 62.94 KiB/83.36 KiB
# tpot       ------------------------------ 48.00 KiB/85.33 KiB
# pyparsing  ------------------------------ 94.91 KiB/101.66 KiB
# urllib3    ------------------------------ 46.91 KiB/123.38 KiB
# charset-normalizer ------------------------------ 124.66 KiB/143.96 KiB
# certifi    ------------------------------ 153.96 KiB/153.96 KiB
# py4j       ------------------------------ 42.43 KiB/198.25 KiB
# python-dateutil ------------------------------ 46.90 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 32.00 KiB/252.27 KiB
# contourpy  ------------------------------ 14.96 KiB/294.07 KiB
# joblib     ------------------------------ 30.95 KiB/294.74 KiB
# ⠹ Preparing packages... (1/49)
# update-checker ------------------------------ 6.84 KiB/6.84 KiB
# cycler     ------------------------------ 8.13 KiB/8.13 KiB
# zipp       ------------------------------ 8.98 KiB/8.98 KiB
# matplotlib-inline ------------------------------ 9.67 KiB/9.67 KiB
# importlib-resources ------------------------------ 14.90 KiB/35.27 KiB
# graphviz   ------------------------------ 14.95 KiB/46.02 KiB
# requests   ------------------------------ 30.91 KiB/63.33 KiB
# packaging  ------------------------------ 14.91 KiB/64.91 KiB
# idna       ------------------------------ 68.79 KiB/68.79 KiB
# tqdm       ------------------------------ 14.92 KiB/76.70 KiB
# traitlets  ------------------------------ 62.94 KiB/83.36 KiB
# tpot       ------------------------------ 48.00 KiB/85.33 KiB
# pyparsing  ------------------------------ 94.91 KiB/101.66 KiB
# urllib3    ------------------------------ 46.91 KiB/123.38 KiB
# charset-normalizer ------------------------------ 124.66 KiB/143.96 KiB
# certifi    ------------------------------ 153.96 KiB/153.96 KiB
# py4j       ------------------------------ 42.43 KiB/198.25 KiB
# python-dateutil ------------------------------ 46.90 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 32.00 KiB/252.27 KiB
# contourpy  ------------------------------ 14.96 KiB/294.07 KiB
# joblib     ------------------------------ 30.95 KiB/294.74 KiB
# tzdata     ------------------------------ 14.91 KiB/339.69 KiB
# ⠹ Preparing packages... (1/49)
# update-checker ------------------------------ 6.84 KiB/6.84 KiB
# cycler     ------------------------------ 8.13 KiB/8.13 KiB
# zipp       ------------------------------ 8.98 KiB/8.98 KiB
# matplotlib-inline ------------------------------ 9.67 KiB/9.67 KiB
# importlib-resources ------------------------------ 14.90 KiB/35.27 KiB
# graphviz   ------------------------------ 30.95 KiB/46.02 KiB
# requests   ------------------------------ 30.91 KiB/63.33 KiB
# packaging  ------------------------------ 14.91 KiB/64.91 KiB
# idna       ------------------------------ 68.79 KiB/68.79 KiB
# tqdm       ------------------------------ 14.92 KiB/76.70 KiB
# traitlets  ------------------------------ 62.94 KiB/83.36 KiB
# tpot       ------------------------------ 48.00 KiB/85.33 KiB
# pyparsing  ------------------------------ 94.91 KiB/101.66 KiB
# urllib3    ------------------------------ 46.91 KiB/123.38 KiB
# charset-normalizer ------------------------------ 124.66 KiB/143.96 KiB
# py4j       ------------------------------ 42.43 KiB/198.25 KiB
# python-dateutil ------------------------------ 46.90 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 32.00 KiB/252.27 KiB
# contourpy  ------------------------------ 236.23 KiB/294.07 KiB
# joblib     ------------------------------ 46.95 KiB/294.74 KiB
# tzdata     ------------------------------ 14.91 KiB/339.69 KiB
# narwhals   ------------------------------ 62.91 KiB/351.45 KiB
# ⠹ Preparing packages... (1/49)
# update-checker ------------------------------ 6.84 KiB/6.84 KiB
# cycler     ------------------------------ 8.13 KiB/8.13 KiB
# zipp       ------------------------------ 8.98 KiB/8.98 KiB
# matplotlib-inline ------------------------------ 9.67 KiB/9.67 KiB
# importlib-resources ------------------------------ 14.90 KiB/35.27 KiB
# graphviz   ------------------------------ 30.95 KiB/46.02 KiB
# requests   ------------------------------ 30.91 KiB/63.33 KiB
# packaging  ------------------------------ 14.91 KiB/64.91 KiB
# idna       ------------------------------ 68.79 KiB/68.79 KiB
# tqdm       ------------------------------ 14.92 KiB/76.70 KiB
# traitlets  ------------------------------ 62.94 KiB/83.36 KiB
# tpot       ------------------------------ 48.00 KiB/85.33 KiB
# pyparsing  ------------------------------ 94.91 KiB/101.66 KiB
# urllib3    ------------------------------ 46.91 KiB/123.38 KiB
# charset-normalizer ------------------------------ 124.66 KiB/143.96 KiB
# py4j       ------------------------------ 42.43 KiB/198.25 KiB
# python-dateutil ------------------------------ 46.90 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 32.00 KiB/252.27 KiB
# contourpy  ------------------------------ 236.23 KiB/294.07 KiB
# joblib     ------------------------------ 46.95 KiB/294.74 KiB
# tzdata     ------------------------------ 14.91 KiB/339.69 KiB
# narwhals   ------------------------------ 62.91 KiB/351.45 KiB
# ⠹ Preparing packages... (1/49)
# cycler     ------------------------------ 8.13 KiB/8.13 KiB
# zipp       ------------------------------ 8.98 KiB/8.98 KiB
# matplotlib-inline ------------------------------ 9.67 KiB/9.67 KiB
# importlib-resources ------------------------------ 14.90 KiB/35.27 KiB
# graphviz   ------------------------------ 30.95 KiB/46.02 KiB
# requests   ------------------------------ 30.91 KiB/63.33 KiB
# packaging  ------------------------------ 30.91 KiB/64.91 KiB
# idna       ------------------------------ 68.79 KiB/68.79 KiB
# tqdm       ------------------------------ 30.92 KiB/76.70 KiB
# traitlets  ------------------------------ 78.94 KiB/83.36 KiB
# tpot       ------------------------------ 48.00 KiB/85.33 KiB
# pyparsing  ------------------------------ 94.91 KiB/101.66 KiB
# urllib3    ------------------------------ 62.91 KiB/123.38 KiB
# charset-normalizer ------------------------------ 140.56 KiB/143.96 KiB
# py4j       ------------------------------ 58.43 KiB/198.25 KiB
# python-dateutil ------------------------------ 46.90 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 32.00 KiB/252.27 KiB
# contourpy  ------------------------------ 237.09 KiB/294.07 KiB
# joblib     ------------------------------ 46.95 KiB/294.74 KiB
# tzdata     ------------------------------ 14.91 KiB/339.69 KiB
# narwhals   ------------------------------ 62.91 KiB/351.45 KiB
# future     ------------------------------ 46.95 KiB/479.81 KiB
# ⠹ Preparing packages... (1/49)
# zipp       ------------------------------ 8.98 KiB/8.98 KiB
# matplotlib-inline ------------------------------ 9.67 KiB/9.67 KiB
# importlib-resources ------------------------------ 14.90 KiB/35.27 KiB
# graphviz   ------------------------------ 30.95 KiB/46.02 KiB
# requests   ------------------------------ 30.91 KiB/63.33 KiB
# packaging  ------------------------------ 30.91 KiB/64.91 KiB
# idna       ------------------------------ 68.79 KiB/68.79 KiB
# tqdm       ------------------------------ 30.92 KiB/76.70 KiB
# traitlets  ------------------------------ 78.94 KiB/83.36 KiB
# tpot       ------------------------------ 48.00 KiB/85.33 KiB
# pyparsing  ------------------------------ 94.91 KiB/101.66 KiB
# urllib3    ------------------------------ 62.91 KiB/123.38 KiB
# charset-normalizer ------------------------------ 140.56 KiB/143.96 KiB
# py4j       ------------------------------ 58.43 KiB/198.25 KiB
# python-dateutil ------------------------------ 46.90 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 32.00 KiB/252.27 KiB
# contourpy  ------------------------------ 237.09 KiB/294.07 KiB
# joblib     ------------------------------ 46.95 KiB/294.74 KiB
# tzdata     ------------------------------ 14.91 KiB/339.69 KiB
# narwhals   ------------------------------ 62.91 KiB/351.45 KiB
# future     ------------------------------ 46.95 KiB/479.81 KiB
# pytz       ------------------------------ 30.91 KiB/497.29 KiB
# ⠹ Preparing packages... (1/49)
# zipp       ------------------------------ 8.98 KiB/8.98 KiB
# importlib-resources ------------------------------ 14.90 KiB/35.27 KiB
# graphviz   ------------------------------ 30.95 KiB/46.02 KiB
# requests   ------------------------------ 30.91 KiB/63.33 KiB
# packaging  ------------------------------ 30.91 KiB/64.91 KiB
# idna       ------------------------------ 68.79 KiB/68.79 KiB
# tqdm       ------------------------------ 30.92 KiB/76.70 KiB
# traitlets  ------------------------------ 78.94 KiB/83.36 KiB
# tpot       ------------------------------ 48.00 KiB/85.33 KiB
# pyparsing  ------------------------------ 94.91 KiB/101.66 KiB
# urllib3    ------------------------------ 62.91 KiB/123.38 KiB
# charset-normalizer ------------------------------ 140.56 KiB/143.96 KiB
# py4j       ------------------------------ 58.43 KiB/198.25 KiB
# python-dateutil ------------------------------ 46.90 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 32.00 KiB/252.27 KiB
# contourpy  ------------------------------ 237.09 KiB/294.07 KiB
# joblib     ------------------------------ 46.95 KiB/294.74 KiB
# tzdata     ------------------------------ 14.91 KiB/339.69 KiB
# narwhals   ------------------------------ 62.91 KiB/351.45 KiB
# future     ------------------------------ 46.95 KiB/479.81 KiB
# pytz       ------------------------------ 30.91 KiB/497.29 KiB
# kiwisolver ------------------------------ 252.53 KiB/1.13 MiB
# ⠹ Preparing packages... (1/49)
# importlib-resources ------------------------------ 14.90 KiB/35.27 KiB
# graphviz   ------------------------------ 30.95 KiB/46.02 KiB
# requests   ------------------------------ 30.91 KiB/63.33 KiB
# packaging  ------------------------------ 30.91 KiB/64.91 KiB
# idna       ------------------------------ 68.79 KiB/68.79 KiB
# tqdm       ------------------------------ 46.92 KiB/76.70 KiB
# traitlets  ------------------------------ 78.94 KiB/83.36 KiB
# tpot       ------------------------------ 48.00 KiB/85.33 KiB
# pyparsing  ------------------------------ 94.91 KiB/101.66 KiB
# urllib3    ------------------------------ 62.91 KiB/123.38 KiB
# charset-normalizer ------------------------------ 140.56 KiB/143.96 KiB
# py4j       ------------------------------ 58.43 KiB/198.25 KiB
# python-dateutil ------------------------------ 62.79 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 32.00 KiB/252.27 KiB
# contourpy  ------------------------------ 268.08 KiB/294.07 KiB
# joblib     ------------------------------ 46.95 KiB/294.74 KiB
# tzdata     ------------------------------ 14.91 KiB/339.69 KiB
# narwhals   ------------------------------ 77.27 KiB/351.45 KiB
# future     ------------------------------ 46.95 KiB/479.81 KiB
# pytz       ------------------------------ 30.91 KiB/497.29 KiB
# kiwisolver ------------------------------ 284.53 KiB/1.13 MiB
# setuptools ------------------------------ 53.37 KiB/1.19 MiB
# ⠹ Preparing packages... (1/49)
# importlib-resources ------------------------------ 14.90 KiB/35.27 KiB
# graphviz   ------------------------------ 30.95 KiB/46.02 KiB
# requests   ------------------------------ 30.91 KiB/63.33 KiB
# packaging  ------------------------------ 30.91 KiB/64.91 KiB
# tqdm       ------------------------------ 46.92 KiB/76.70 KiB
# traitlets  ------------------------------ 78.94 KiB/83.36 KiB
# tpot       ------------------------------ 48.00 KiB/85.33 KiB
# pyparsing  ------------------------------ 94.91 KiB/101.66 KiB
# urllib3    ------------------------------ 78.91 KiB/123.38 KiB
# charset-normalizer ------------------------------ 140.56 KiB/143.96 KiB
# py4j       ------------------------------ 58.43 KiB/198.25 KiB
# python-dateutil ------------------------------ 62.79 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 32.00 KiB/252.27 KiB
# contourpy  ------------------------------ 268.08 KiB/294.07 KiB
# joblib     ------------------------------ 46.95 KiB/294.74 KiB
# tzdata     ------------------------------ 14.91 KiB/339.69 KiB
# narwhals   ------------------------------ 77.27 KiB/351.45 KiB
# future     ------------------------------ 46.95 KiB/479.81 KiB
# pytz       ------------------------------ 30.91 KiB/497.29 KiB
# kiwisolver ------------------------------ 284.53 KiB/1.13 MiB
# setuptools ------------------------------ 53.37 KiB/1.19 MiB
# hyperopt   ------------------------------ 48.00 KiB/1.51 MiB
# ⠹ Preparing packages... (1/49)
# importlib-resources ------------------------------ 14.90 KiB/35.27 KiB
# graphviz   ------------------------------ 30.95 KiB/46.02 KiB
# requests   ------------------------------ 30.91 KiB/63.33 KiB
# packaging  ------------------------------ 46.91 KiB/64.91 KiB
# tqdm       ------------------------------ 46.92 KiB/76.70 KiB
# traitlets  ------------------------------ 78.94 KiB/83.36 KiB
# tpot       ------------------------------ 48.00 KiB/85.33 KiB
# pyparsing  ------------------------------ 94.91 KiB/101.66 KiB
# urllib3    ------------------------------ 78.91 KiB/123.38 KiB
# charset-normalizer ------------------------------ 140.56 KiB/143.96 KiB
# py4j       ------------------------------ 58.43 KiB/198.25 KiB
# python-dateutil ------------------------------ 62.79 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 32.00 KiB/252.27 KiB
# contourpy  ------------------------------ 268.08 KiB/294.07 KiB
# joblib     ------------------------------ 46.95 KiB/294.74 KiB
# tzdata     ------------------------------ 14.91 KiB/339.69 KiB
# narwhals   ------------------------------ 77.27 KiB/351.45 KiB
# future     ------------------------------ 46.95 KiB/479.81 KiB
# pytz       ------------------------------ 30.91 KiB/497.29 KiB
# kiwisolver ------------------------------ 284.53 KiB/1.13 MiB
# setuptools ------------------------------ 53.37 KiB/1.19 MiB
# hyperopt   ------------------------------ 48.00 KiB/1.51 MiB
# ⠹ Preparing packages... (1/49)
# importlib-resources ------------------------------ 14.90 KiB/35.27 KiB
# graphviz   ------------------------------ 30.95 KiB/46.02 KiB
# requests   ------------------------------ 30.91 KiB/63.33 KiB
# packaging  ------------------------------ 62.91 KiB/64.91 KiB
# tqdm       ------------------------------ 46.92 KiB/76.70 KiB
# traitlets  ------------------------------ 78.94 KiB/83.36 KiB
# tpot       ------------------------------ 48.00 KiB/85.33 KiB
# pyparsing  ------------------------------ 94.91 KiB/101.66 KiB
# urllib3    ------------------------------ 78.91 KiB/123.38 KiB
# charset-normalizer ------------------------------ 140.56 KiB/143.96 KiB
# py4j       ------------------------------ 58.43 KiB/198.25 KiB
# python-dateutil ------------------------------ 62.79 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 32.00 KiB/252.27 KiB
# contourpy  ------------------------------ 268.08 KiB/294.07 KiB
# joblib     ------------------------------ 46.95 KiB/294.74 KiB
# tzdata     ------------------------------ 14.91 KiB/339.69 KiB
# narwhals   ------------------------------ 77.27 KiB/351.45 KiB
# future     ------------------------------ 46.95 KiB/479.81 KiB
# pytz       ------------------------------ 30.91 KiB/497.29 KiB
# kiwisolver ------------------------------ 284.53 KiB/1.13 MiB
# setuptools ------------------------------ 53.37 KiB/1.19 MiB
# hyperopt   ------------------------------ 48.00 KiB/1.51 MiB
# ⠹ Preparing packages... (1/49)
# importlib-resources ------------------------------ 14.90 KiB/35.27 KiB
# graphviz   ------------------------------ 30.95 KiB/46.02 KiB
# requests   ------------------------------ 46.91 KiB/63.33 KiB
# tqdm       ------------------------------ 46.92 KiB/76.70 KiB
# traitlets  ------------------------------ 78.94 KiB/83.36 KiB
# tpot       ------------------------------ 48.00 KiB/85.33 KiB
# pyparsing  ------------------------------ 101.66 KiB/101.66 KiB
# urllib3    ------------------------------ 78.91 KiB/123.38 KiB
# charset-normalizer ------------------------------ 140.66 KiB/143.96 KiB
# py4j       ------------------------------ 58.43 KiB/198.25 KiB
# python-dateutil ------------------------------ 77.61 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 32.00 KiB/252.27 KiB
# contourpy  ------------------------------ 284.08 KiB/294.07 KiB
# joblib     ------------------------------ 46.95 KiB/294.74 KiB
# tzdata     ------------------------------ 14.91 KiB/339.69 KiB
# narwhals   ------------------------------ 93.27 KiB/351.45 KiB
# future     ------------------------------ 76.30 KiB/479.81 KiB
# pytz       ------------------------------ 30.91 KiB/497.29 KiB
# kiwisolver ------------------------------ 300.53 KiB/1.13 MiB
# setuptools ------------------------------ 53.37 KiB/1.19 MiB
# hyperopt   ------------------------------ 65.13 KiB/1.51 MiB
# networkx   ------------------------------ 46.87 KiB/1.98 MiB
# ⠹ Preparing packages... (1/49)
# importlib-resources ------------------------------ 30.90 KiB/35.27 KiB
# graphviz   ------------------------------ 30.95 KiB/46.02 KiB
# requests   ------------------------------ 46.91 KiB/63.33 KiB
# tqdm       ------------------------------ 46.92 KiB/76.70 KiB
# traitlets  ------------------------------ 78.94 KiB/83.36 KiB
# tpot       ------------------------------ 48.00 KiB/85.33 KiB
# pyparsing  ------------------------------ 101.66 KiB/101.66 KiB
# urllib3    ------------------------------ 78.91 KiB/123.38 KiB
# charset-normalizer ------------------------------ 143.96 KiB/143.96 KiB
# py4j       ------------------------------ 58.43 KiB/198.25 KiB
# python-dateutil ------------------------------ 77.61 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 32.00 KiB/252.27 KiB
# contourpy  ------------------------------ 284.08 KiB/294.07 KiB
# joblib     ------------------------------ 62.95 KiB/294.74 KiB
# tzdata     ------------------------------ 14.91 KiB/339.69 KiB
# narwhals   ------------------------------ 93.27 KiB/351.45 KiB
# future     ------------------------------ 92.30 KiB/479.81 KiB
# pytz       ------------------------------ 46.91 KiB/497.29 KiB
# kiwisolver ------------------------------ 316.53 KiB/1.13 MiB
# setuptools ------------------------------ 61.81 KiB/1.19 MiB
# hyperopt   ------------------------------ 65.13 KiB/1.51 MiB
# networkx   ------------------------------ 62.87 KiB/1.98 MiB
# ⠸ Preparing packages... (11/49)
# importlib-resources ------------------------------ 30.90 KiB/35.27 KiB
# graphviz   ------------------------------ 30.95 KiB/46.02 KiB
# requests   ------------------------------ 46.91 KiB/63.33 KiB
# tqdm       ------------------------------ 62.92 KiB/76.70 KiB
# traitlets  ------------------------------ 78.94 KiB/83.36 KiB
# tpot       ------------------------------ 51.25 KiB/85.33 KiB
# urllib3    ------------------------------ 78.91 KiB/123.38 KiB
# charset-normalizer ------------------------------ 143.96 KiB/143.96 KiB
# py4j       ------------------------------ 58.43 KiB/198.25 KiB
# python-dateutil ------------------------------ 221.61 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 32.00 KiB/252.27 KiB
# contourpy  ------------------------------ 284.08 KiB/294.07 KiB
# joblib     ------------------------------ 78.39 KiB/294.74 KiB
# tzdata     ------------------------------ 14.91 KiB/339.69 KiB
# narwhals   ------------------------------ 109.16 KiB/351.45 KiB
# future     ------------------------------ 92.30 KiB/479.81 KiB
# pytz       ------------------------------ 46.91 KiB/497.29 KiB
# kiwisolver ------------------------------ 332.53 KiB/1.13 MiB
# setuptools ------------------------------ 61.81 KiB/1.19 MiB
# hyperopt   ------------------------------ 65.13 KiB/1.51 MiB
# networkx   ------------------------------ 62.87 KiB/1.98 MiB
# biopython  ------------------------------ 14.95 KiB/2.97 MiB
# ⠸ Preparing packages... (11/49)
# importlib-resources ------------------------------ 30.90 KiB/35.27 KiB
# graphviz   ------------------------------ 30.95 KiB/46.02 KiB
# requests   ------------------------------ 62.91 KiB/63.33 KiB
# tqdm       ------------------------------ 62.92 KiB/76.70 KiB
# traitlets  ------------------------------ 78.94 KiB/83.36 KiB
# tpot       ------------------------------ 64.00 KiB/85.33 KiB
# urllib3    ------------------------------ 78.91 KiB/123.38 KiB
# py4j       ------------------------------ 74.43 KiB/198.25 KiB
# python-dateutil ------------------------------ 221.61 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 32.00 KiB/252.27 KiB
# contourpy  ------------------------------ 284.08 KiB/294.07 KiB
# joblib     ------------------------------ 78.39 KiB/294.74 KiB
# tzdata     ------------------------------ 14.91 KiB/339.69 KiB
# narwhals   ------------------------------ 109.16 KiB/351.45 KiB
# future     ------------------------------ 92.30 KiB/479.81 KiB
# pytz       ------------------------------ 46.91 KiB/497.29 KiB
# kiwisolver ------------------------------ 348.53 KiB/1.13 MiB
# setuptools ------------------------------ 61.81 KiB/1.19 MiB
# hyperopt   ------------------------------ 81.13 KiB/1.51 MiB
# networkx   ------------------------------ 75.36 KiB/1.98 MiB
# biopython  ------------------------------ 14.95 KiB/2.97 MiB
# igraph     ------------------------------ 64.00 KiB/3.01 MiB
# ⠸ Preparing packages... (11/49)
# importlib-resources ------------------------------ 30.90 KiB/35.27 KiB
# graphviz   ------------------------------ 30.95 KiB/46.02 KiB
# requests   ------------------------------ 62.91 KiB/63.33 KiB
# tqdm       ------------------------------ 62.92 KiB/76.70 KiB
# traitlets  ------------------------------ 78.94 KiB/83.36 KiB
# tpot       ------------------------------ 64.00 KiB/85.33 KiB
# urllib3    ------------------------------ 78.91 KiB/123.38 KiB
# py4j       ------------------------------ 74.43 KiB/198.25 KiB
# python-dateutil ------------------------------ 221.61 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 32.00 KiB/252.27 KiB
# contourpy  ------------------------------ 284.08 KiB/294.07 KiB
# joblib     ------------------------------ 78.39 KiB/294.74 KiB
# tzdata     ------------------------------ 14.91 KiB/339.69 KiB
# narwhals   ------------------------------ 109.16 KiB/351.45 KiB
# future     ------------------------------ 92.30 KiB/479.81 KiB
# pytz       ------------------------------ 46.91 KiB/497.29 KiB
# kiwisolver ------------------------------ 348.53 KiB/1.13 MiB
# setuptools ------------------------------ 61.81 KiB/1.19 MiB
# hyperopt   ------------------------------ 81.13 KiB/1.51 MiB
# networkx   ------------------------------ 75.36 KiB/1.98 MiB
# biopython  ------------------------------ 14.95 KiB/2.97 MiB
# igraph     ------------------------------ 64.00 KiB/3.01 MiB
# ⠸ Preparing packages... (11/49)
# importlib-resources ------------------------------ 30.90 KiB/35.27 KiB
# graphviz   ------------------------------ 46.02 KiB/46.02 KiB
# requests   ------------------------------ 62.91 KiB/63.33 KiB
# tqdm       ------------------------------ 76.70 KiB/76.70 KiB
# traitlets  ------------------------------ 78.94 KiB/83.36 KiB
# tpot       ------------------------------ 64.00 KiB/85.33 KiB
# urllib3    ------------------------------ 94.91 KiB/123.38 KiB
# py4j       ------------------------------ 74.43 KiB/198.25 KiB
# python-dateutil ------------------------------ 221.61 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 48.00 KiB/252.27 KiB
# contourpy  ------------------------------ 294.07 KiB/294.07 KiB
# joblib     ------------------------------ 112.36 KiB/294.74 KiB
# tzdata     ------------------------------ 14.91 KiB/339.69 KiB
# narwhals   ------------------------------ 125.16 KiB/351.45 KiB
# future     ------------------------------ 108.30 KiB/479.81 KiB
# pytz       ------------------------------ 46.91 KiB/497.29 KiB
# kiwisolver ------------------------------ 380.53 KiB/1.13 MiB
# setuptools ------------------------------ 61.81 KiB/1.19 MiB
# hyperopt   ------------------------------ 97.13 KiB/1.51 MiB
# networkx   ------------------------------ 91.36 KiB/1.98 MiB
# biopython  ------------------------------ 25.39 KiB/2.97 MiB
# igraph     ------------------------------ 304.00 KiB/3.01 MiB
#    Building stopit==1.1.2
# ⠸ Preparing packages... (11/49)
# importlib-resources ------------------------------ 30.90 KiB/35.27 KiB
# graphviz   ------------------------------ 46.02 KiB/46.02 KiB
# requests   ------------------------------ 62.91 KiB/63.33 KiB
# tqdm       ------------------------------ 76.70 KiB/76.70 KiB
# traitlets  ------------------------------ 78.94 KiB/83.36 KiB
# tpot       ------------------------------ 64.00 KiB/85.33 KiB
# urllib3    ------------------------------ 94.91 KiB/123.38 KiB
# py4j       ------------------------------ 74.43 KiB/198.25 KiB
# python-dateutil ------------------------------ 224.50 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 60.64 KiB/252.27 KiB
# joblib     ------------------------------ 112.36 KiB/294.74 KiB
# tzdata     ------------------------------ 14.91 KiB/339.69 KiB
# narwhals   ------------------------------ 125.16 KiB/351.45 KiB
# future     ------------------------------ 124.30 KiB/479.81 KiB
# pytz       ------------------------------ 46.91 KiB/497.29 KiB
# kiwisolver ------------------------------ 396.53 KiB/1.13 MiB
# setuptools ------------------------------ 61.81 KiB/1.19 MiB
# hyperopt   ------------------------------ 97.13 KiB/1.51 MiB
# networkx   ------------------------------ 91.36 KiB/1.98 MiB
# biopython  ------------------------------ 57.28 KiB/2.97 MiB
# igraph     ------------------------------ 368.00 KiB/3.01 MiB
#    Building stopit==1.1.2
# ⠸ Preparing packages... (11/49)
# importlib-resources ------------------------------ 30.90 KiB/35.27 KiB
# graphviz   ------------------------------ 46.02 KiB/46.02 KiB
# requests   ------------------------------ 62.91 KiB/63.33 KiB
# tqdm       ------------------------------ 76.70 KiB/76.70 KiB
# traitlets  ------------------------------ 78.94 KiB/83.36 KiB
# tpot       ------------------------------ 64.00 KiB/85.33 KiB
# urllib3    ------------------------------ 94.91 KiB/123.38 KiB
# py4j       ------------------------------ 74.43 KiB/198.25 KiB
# imbalanced-learn ------------------------------ 60.64 KiB/252.27 KiB
# joblib     ------------------------------ 112.36 KiB/294.74 KiB
# tzdata     ------------------------------ 30.91 KiB/339.69 KiB
# narwhals   ------------------------------ 125.16 KiB/351.45 KiB
# future     ------------------------------ 124.30 KiB/479.81 KiB
# pytz       ------------------------------ 46.91 KiB/497.29 KiB
# kiwisolver ------------------------------ 396.53 KiB/1.13 MiB
# setuptools ------------------------------ 61.81 KiB/1.19 MiB
# hyperopt   ------------------------------ 97.13 KiB/1.51 MiB
# networkx   ------------------------------ 91.36 KiB/1.98 MiB
# biopython  ------------------------------ 57.28 KiB/2.97 MiB
# igraph     ------------------------------ 368.00 KiB/3.01 MiB
# lightgbm   ------------------------------ 365.36 KiB/3.40 MiB
#    Building stopit==1.1.2
# ⠸ Preparing packages... (11/49)
# importlib-resources ------------------------------ 30.90 KiB/35.27 KiB
# graphviz   ------------------------------ 46.02 KiB/46.02 KiB
# requests   ------------------------------ 63.33 KiB/63.33 KiB
# traitlets  ------------------------------ 83.36 KiB/83.36 KiB
# tpot       ------------------------------ 80.00 KiB/85.33 KiB
# urllib3    ------------------------------ 94.91 KiB/123.38 KiB
# py4j       ------------------------------ 74.43 KiB/198.25 KiB
# imbalanced-learn ------------------------------ 60.64 KiB/252.27 KiB
# joblib     ------------------------------ 112.36 KiB/294.74 KiB
# tzdata     ------------------------------ 30.91 KiB/339.69 KiB
# narwhals   ------------------------------ 125.16 KiB/351.45 KiB
# future     ------------------------------ 124.30 KiB/479.81 KiB
# pytz       ------------------------------ 46.91 KiB/497.29 KiB
# kiwisolver ------------------------------ 396.53 KiB/1.13 MiB
# setuptools ------------------------------ 61.81 KiB/1.19 MiB
# hyperopt   ------------------------------ 97.13 KiB/1.51 MiB
# networkx   ------------------------------ 91.36 KiB/1.98 MiB
# biopython  ------------------------------ 57.28 KiB/2.97 MiB
# igraph     ------------------------------ 384.00 KiB/3.01 MiB
# lightgbm   ------------------------------ 381.36 KiB/3.40 MiB
# pillow     ------------------------------ 384.00 KiB/4.32 MiB
#    Building stopit==1.1.2
# ⠸ Preparing packages... (11/49)
# importlib-resources ------------------------------ 30.90 KiB/35.27 KiB
# graphviz   ------------------------------ 46.02 KiB/46.02 KiB
# traitlets  ------------------------------ 83.36 KiB/83.36 KiB
# tpot       ------------------------------ 80.00 KiB/85.33 KiB
# urllib3    ------------------------------ 94.91 KiB/123.38 KiB
# py4j       ------------------------------ 74.43 KiB/198.25 KiB
# imbalanced-learn ------------------------------ 60.64 KiB/252.27 KiB
# joblib     ------------------------------ 112.36 KiB/294.74 KiB
# tzdata     ------------------------------ 30.91 KiB/339.69 KiB
# narwhals   ------------------------------ 125.16 KiB/351.45 KiB
# future     ------------------------------ 124.30 KiB/479.81 KiB
# pytz       ------------------------------ 46.91 KiB/497.29 KiB
# kiwisolver ------------------------------ 412.53 KiB/1.13 MiB
# setuptools ------------------------------ 61.81 KiB/1.19 MiB
# hyperopt   ------------------------------ 97.13 KiB/1.51 MiB
# networkx   ------------------------------ 91.36 KiB/1.98 MiB
# biopython  ------------------------------ 57.28 KiB/2.97 MiB
# igraph     ------------------------------ 384.00 KiB/3.01 MiB
# lightgbm   ------------------------------ 381.36 KiB/3.40 MiB
# pillow     ------------------------------ 384.00 KiB/4.32 MiB
# fonttools  ------------------------------ 125.17 KiB/4.47 MiB
#    Building stopit==1.1.2
# ⠸ Preparing packages... (11/49)
# importlib-resources ------------------------------ 30.90 KiB/35.27 KiB
# graphviz   ------------------------------ 46.02 KiB/46.02 KiB
# traitlets  ------------------------------ 83.36 KiB/83.36 KiB
# tpot       ------------------------------ 80.00 KiB/85.33 KiB
# urllib3    ------------------------------ 94.91 KiB/123.38 KiB
# py4j       ------------------------------ 74.43 KiB/198.25 KiB
# imbalanced-learn ------------------------------ 60.64 KiB/252.27 KiB
# joblib     ------------------------------ 112.36 KiB/294.74 KiB
# tzdata     ------------------------------ 30.91 KiB/339.69 KiB
# narwhals   ------------------------------ 125.16 KiB/351.45 KiB
# future     ------------------------------ 124.30 KiB/479.81 KiB
# pytz       ------------------------------ 46.91 KiB/497.29 KiB
# kiwisolver ------------------------------ 412.53 KiB/1.13 MiB
# setuptools ------------------------------ 61.81 KiB/1.19 MiB
# hyperopt   ------------------------------ 97.13 KiB/1.51 MiB
# networkx   ------------------------------ 91.36 KiB/1.98 MiB
# biopython  ------------------------------ 57.28 KiB/2.97 MiB
# igraph     ------------------------------ 384.00 KiB/3.01 MiB
# lightgbm   ------------------------------ 381.36 KiB/3.40 MiB
# pillow     ------------------------------ 384.00 KiB/4.32 MiB
# fonttools  ------------------------------ 125.17 KiB/4.47 MiB
#    Building stopit==1.1.2
# ⠼ Preparing packages... (17/49)
# importlib-resources ------------------------------ 30.90 KiB/35.27 KiB
# graphviz   ------------------------------ 46.02 KiB/46.02 KiB
# traitlets  ------------------------------ 83.36 KiB/83.36 KiB
# tpot       ------------------------------ 80.00 KiB/85.33 KiB
# urllib3    ------------------------------ 94.91 KiB/123.38 KiB
# py4j       ------------------------------ 77.61 KiB/198.25 KiB
# imbalanced-learn ------------------------------ 76.64 KiB/252.27 KiB
# joblib     ------------------------------ 128.36 KiB/294.74 KiB
# tzdata     ------------------------------ 30.91 KiB/339.69 KiB
# narwhals   ------------------------------ 141.16 KiB/351.45 KiB
# future     ------------------------------ 124.30 KiB/479.81 KiB
# pytz       ------------------------------ 46.91 KiB/497.29 KiB
# kiwisolver ------------------------------ 428.53 KiB/1.13 MiB
# setuptools ------------------------------ 61.81 KiB/1.19 MiB
# hyperopt   ------------------------------ 97.13 KiB/1.51 MiB
# networkx   ------------------------------ 100.50 KiB/1.98 MiB
# biopython  ------------------------------ 77.08 KiB/2.97 MiB
# igraph     ------------------------------ 388.28 KiB/3.01 MiB
# lightgbm   ------------------------------ 381.36 KiB/3.40 MiB
# pillow     ------------------------------ 400.00 KiB/4.32 MiB
# fonttools  ------------------------------ 125.17 KiB/4.47 MiB
#    Building stopit==1.1.2
# ⠼ Preparing packages... (17/49)
# graphviz   ------------------------------ 46.02 KiB/46.02 KiB
# traitlets  ------------------------------ 83.36 KiB/83.36 KiB
# tpot       ------------------------------ 80.00 KiB/85.33 KiB
# urllib3    ------------------------------ 94.91 KiB/123.38 KiB
# py4j       ------------------------------ 77.61 KiB/198.25 KiB
# imbalanced-learn ------------------------------ 76.64 KiB/252.27 KiB
# joblib     ------------------------------ 128.36 KiB/294.74 KiB
# tzdata     ------------------------------ 30.91 KiB/339.69 KiB
# narwhals   ------------------------------ 141.16 KiB/351.45 KiB
# future     ------------------------------ 140.30 KiB/479.81 KiB
# pytz       ------------------------------ 46.91 KiB/497.29 KiB
# kiwisolver ------------------------------ 448.43 KiB/1.13 MiB
# setuptools ------------------------------ 76.83 KiB/1.19 MiB
# hyperopt   ------------------------------ 97.13 KiB/1.51 MiB
# networkx   ------------------------------ 100.50 KiB/1.98 MiB
# biopython  ------------------------------ 77.08 KiB/2.97 MiB
# igraph     ------------------------------ 400.00 KiB/3.01 MiB
# lightgbm   ------------------------------ 413.36 KiB/3.40 MiB
# pillow     ------------------------------ 416.00 KiB/4.32 MiB
# fonttools  ------------------------------ 205.17 KiB/4.47 MiB
# matplotlib ------------------------------ 62.84 KiB/8.79 MiB
#    Building stopit==1.1.2
# ⠼ Preparing packages... (17/49)
# graphviz   ------------------------------ 46.02 KiB/46.02 KiB
# tpot       ------------------------------ 80.00 KiB/85.33 KiB
# urllib3    ------------------------------ 94.91 KiB/123.38 KiB
# py4j       ------------------------------ 77.61 KiB/198.25 KiB
# imbalanced-learn ------------------------------ 76.64 KiB/252.27 KiB
# joblib     ------------------------------ 128.36 KiB/294.74 KiB
# tzdata     ------------------------------ 30.91 KiB/339.69 KiB
# narwhals   ------------------------------ 141.16 KiB/351.45 KiB
# future     ------------------------------ 140.30 KiB/479.81 KiB
# pytz       ------------------------------ 46.91 KiB/497.29 KiB
# kiwisolver ------------------------------ 448.43 KiB/1.13 MiB
# setuptools ------------------------------ 76.83 KiB/1.19 MiB
# hyperopt   ------------------------------ 97.13 KiB/1.51 MiB
# networkx   ------------------------------ 100.50 KiB/1.98 MiB
# biopython  ------------------------------ 77.08 KiB/2.97 MiB
# igraph     ------------------------------ 400.00 KiB/3.01 MiB
# lightgbm   ------------------------------ 413.36 KiB/3.40 MiB
# pillow     ------------------------------ 416.00 KiB/4.32 MiB
# fonttools  ------------------------------ 205.17 KiB/4.47 MiB
# matplotlib ------------------------------ 62.84 KiB/8.79 MiB
# plotly     ------------------------------ 158.92 KiB/9.19 MiB
#    Building stopit==1.1.2
# ⠼ Preparing packages... (17/49)
# ...
# xgboost    ------------------------------ 106.99 MiB/213.28 MiB
# ⠴ Preparing packages... (45/49)
# scipy      ------------------------------ 32.89 MiB/32.94 MiB
# catboost   ------------------------------ 94.45 MiB/94.56 MiB
# xgboost    ------------------------------ 106.99 MiB/213.28 MiB
# ⠦ Preparing packages... (45/49)
# scipy      ------------------------------ 32.89 MiB/32.94 MiB
# catboost   ------------------------------ 94.45 MiB/94.56 MiB
# xgboost    ------------------------------ 106.99 MiB/213.28 MiB
# ⠦ Preparing packages... (45/49)
# scipy      ------------------------------ 32.89 MiB/32.94 MiB
# catboost   ------------------------------ 94.56 MiB/94.56 MiB
# xgboost    ------------------------------ 108.56 MiB/213.28 MiB
# ⠦ Preparing packages... (45/49)
# scipy      ------------------------------ 32.89 MiB/32.94 MiB
# catboost   ------------------------------ 94.56 MiB/94.56 MiB
# xgboost    ------------------------------ 110.06 MiB/213.28 MiB
# ⠦ Preparing packages... (45/49)
# scipy      ------------------------------ 32.89 MiB/32.94 MiB
# catboost   ------------------------------ 94.56 MiB/94.56 MiB
# xgboost    ------------------------------ 110.82 MiB/213.28 MiB
# ⠧ Preparing packages... (45/49)
# scipy      ------------------------------ 32.89 MiB/32.94 MiB
# catboost   ------------------------------ 94.56 MiB/94.56 MiB
# xgboost    ------------------------------ 110.82 MiB/213.28 MiB
# ⠧ Preparing packages... (45/49)
# scipy      ------------------------------ 32.89 MiB/32.94 MiB
# catboost   ------------------------------ 94.56 MiB/94.56 MiB
# xgboost    ------------------------------ 112.21 MiB/213.28 MiB
# ⠧ Preparing packages... (45/49)
# scipy      ------------------------------ 32.89 MiB/32.94 MiB
# catboost   ------------------------------ 94.56 MiB/94.56 MiB
# xgboost    ------------------------------ 113.00 MiB/213.28 MiB
# ⠧ Preparing packages... (45/49)
# scipy      ------------------------------ 32.89 MiB/32.94 MiB
# xgboost    ------------------------------ 113.00 MiB/213.28 MiB
# ⠇ Preparing packages... (45/49)
# scipy      ------------------------------ 32.89 MiB/32.94 MiB
# xgboost    ------------------------------ 113.00 MiB/213.28 MiB
# ⠇ Preparing packages... (45/49)
# scipy      ------------------------------ 32.89 MiB/32.94 MiB
# xgboost    ------------------------------ 114.22 MiB/213.28 MiB
# ⠇ Preparing packages... (45/49)
# scipy      ------------------------------ 32.89 MiB/32.94 MiB
# xgboost    ------------------------------ 114.97 MiB/213.28 MiB
# ⠇ Preparing packages... (45/49)
# scipy      ------------------------------ 32.93 MiB/32.94 MiB
# xgboost    ------------------------------ 115.09 MiB/213.28 MiB
# ⠇ Preparing packages... (45/49)
# scipy      ------------------------------ 32.93 MiB/32.94 MiB
# xgboost    ------------------------------ 116.00 MiB/213.28 MiB
# ⠋ Preparing packages... (46/49)
# scipy      ------------------------------ 32.93 MiB/32.94 MiB
# xgboost    ------------------------------ 116.00 MiB/213.28 MiB
# ⠋ Preparing packages... (46/49)
# scipy      ------------------------------ 32.93 MiB/32.94 MiB
# xgboost    ------------------------------ 116.62 MiB/213.28 MiB
# ⠋ Preparing packages... (46/49)
# scipy      ------------------------------ 32.93 MiB/32.94 MiB
# xgboost    ------------------------------ 118.00 MiB/213.28 MiB
# ⠋ Preparing packages... (46/49)
# scipy      ------------------------------ 32.93 MiB/32.94 MiB
# xgboost    ------------------------------ 118.00 MiB/213.28 MiB
# ⠙ Preparing packages... (46/49)
# scipy      ------------------------------ 32.93 MiB/32.94 MiB
# xgboost    ------------------------------ 118.43 MiB/213.28 MiB
# ⠙ Preparing packages... (46/49)
# scipy      ------------------------------ 32.93 MiB/32.94 MiB
# xgboost    ------------------------------ 120.06 MiB/213.28 MiB
# ⠙ Preparing packages... (46/49)
# scipy      ------------------------------ 32.93 MiB/32.94 MiB
# xgboost    ------------------------------ 121.84 MiB/213.28 MiB
# ⠙ Preparing packages... (46/49)
# scipy      ------------------------------ 32.93 MiB/32.94 MiB
# xgboost    ------------------------------ 121.99 MiB/213.28 MiB
# ⠹ Preparing packages... (46/49)
# scipy      ------------------------------ 32.94 MiB/32.94 MiB
# xgboost    ------------------------------ 122.99 MiB/213.28 MiB
# ⠹ Preparing packages... (46/49)
# scipy      ------------------------------ 32.94 MiB/32.94 MiB
# xgboost    ------------------------------ 122.99 MiB/213.28 MiB
# ⠹ Preparing packages... (46/49)
# scipy      ------------------------------ 32.94 MiB/32.94 MiB
# xgboost    ------------------------------ 124.46 MiB/213.28 MiB
# ⠹ Preparing packages... (46/49)
# xgboost    ------------------------------ 124.99 MiB/213.28 MiB
# ⠹ Preparing packages... (46/49)
# xgboost    ------------------------------ 124.99 MiB/213.28 MiB
# ⠸ Preparing packages... (47/49)
# xgboost    ------------------------------ 125.53 MiB/213.28 MiB
# ⠸ Preparing packages... (47/49)
# xgboost    ------------------------------ 126.96 MiB/213.28 MiB
# ⠸ Preparing packages... (47/49)
# xgboost    ------------------------------ 127.06 MiB/213.28 MiB
# ⠸ Preparing packages... (47/49)
# xgboost    ------------------------------ 128.09 MiB/213.28 MiB
# ⠼ Preparing packages... (47/49)
# xgboost    ------------------------------ 128.23 MiB/213.28 MiB
# ⠼ Preparing packages... (47/49)
# xgboost    ------------------------------ 129.84 MiB/213.28 MiB
# ⠼ Preparing packages... (47/49)
# xgboost    ------------------------------ 130.25 MiB/213.28 MiB
# ⠼ Preparing packages... (47/49)
# xgboost    ------------------------------ 131.26 MiB/213.28 MiB
# ⠴ Preparing packages... (47/49)
# xgboost    ------------------------------ 132.00 MiB/213.28 MiB
# ⠴ Preparing packages... (47/49)
# xgboost    ------------------------------ 132.99 MiB/213.28 MiB
# ⠴ Preparing packages... (47/49)
# xgboost    ------------------------------ 134.24 MiB/213.28 MiB
# ⠴ Preparing packages... (47/49)
# xgboost    ------------------------------ 135.98 MiB/213.28 MiB
# ⠦ Preparing packages... (47/49)
# xgboost    ------------------------------ 135.98 MiB/213.28 MiB
# ⠦ Preparing packages... (47/49)
# xgboost    ------------------------------ 136.91 MiB/213.28 MiB
# ⠦ Preparing packages... (47/49)
# xgboost    ------------------------------ 136.97 MiB/213.28 MiB
# ⠦ Preparing packages... (47/49)
# xgboost    ------------------------------ 138.02 MiB/213.28 MiB
# ⠧ Preparing packages... (47/49)
# xgboost    ------------------------------ 139.57 MiB/213.28 MiB
# ⠧ Preparing packages... (47/49)
# xgboost    ------------------------------ 139.98 MiB/213.28 MiB
# ⠧ Preparing packages... (47/49)
# xgboost    ------------------------------ 140.12 MiB/213.28 MiB
# ⠧ Preparing packages... (47/49)
# xgboost    ------------------------------ 141.45 MiB/213.28 MiB
# ⠇ Preparing packages... (47/49)
# xgboost    ------------------------------ 141.99 MiB/213.28 MiB
# ⠇ Preparing packages... (47/49)
# xgboost    ------------------------------ 142.60 MiB/213.28 MiB
# ⠇ Preparing packages... (47/49)
# xgboost    ------------------------------ 143.99 MiB/213.28 MiB
# ⠇ Preparing packages... (47/49)
# xgboost    ------------------------------ 143.99 MiB/213.28 MiB
# ⠋ Preparing packages... (47/49)
# xgboost    ------------------------------ 145.16 MiB/213.28 MiB
# ⠋ Preparing packages... (47/49)
# xgboost    ------------------------------ 146.00 MiB/213.28 MiB
# ⠋ Preparing packages... (47/49)
# xgboost    ------------------------------ 146.23 MiB/213.28 MiB
# ⠋ Preparing packages... (47/49)
# xgboost    ------------------------------ 147.11 MiB/213.28 MiB
# ⠙ Preparing packages... (47/49)
# xgboost    ------------------------------ 147.99 MiB/213.28 MiB
# ⠙ Preparing packages... (47/49)
# xgboost    ------------------------------ 148.60 MiB/213.28 MiB
# ⠙ Preparing packages... (47/49)
# xgboost    ------------------------------ 149.99 MiB/213.28 MiB
# ⠙ Preparing packages... (47/49)
# xgboost    ------------------------------ 149.99 MiB/213.28 MiB
# ⠹ Preparing packages... (47/49)
# xgboost    ------------------------------ 151.59 MiB/213.28 MiB
# ⠹ Preparing packages... (47/49)
# xgboost    ------------------------------ 152.03 MiB/213.28 MiB
# ⠹ Preparing packages... (47/49)
# xgboost    ------------------------------ 153.58 MiB/213.28 MiB
# ⠹ Preparing packages... (47/49)
# xgboost    ------------------------------ 153.59 MiB/213.28 MiB
# ⠸ Preparing packages... (47/49)
# xgboost    ------------------------------ 153.59 MiB/213.28 MiB
# ⠸ Preparing packages... (47/49)
# xgboost    ------------------------------ 154.76 MiB/213.28 MiB
# ⠸ Preparing packages... (47/49)
# xgboost    ------------------------------ 155.83 MiB/213.28 MiB
# ⠸ Preparing packages... (47/49)
# xgboost    ------------------------------ 157.00 MiB/213.28 MiB
# ⠼ Preparing packages... (47/49)
# xgboost    ------------------------------ 157.74 MiB/213.28 MiB
# ⠼ Preparing packages... (47/49)
# xgboost    ------------------------------ 159.68 MiB/213.28 MiB
# ⠼ Preparing packages... (47/49)
# xgboost    ------------------------------ 159.99 MiB/213.28 MiB
# ⠼ Preparing packages... (47/49)
# xgboost    ------------------------------ 161.57 MiB/213.28 MiB
# ⠴ Preparing packages... (47/49)
# xgboost    ------------------------------ 162.40 MiB/213.28 MiB
# ⠴ Preparing packages... (47/49)
# xgboost    ------------------------------ 164.98 MiB/213.28 MiB
# ⠴ Preparing packages... (47/49)
# xgboost    ------------------------------ 166.02 MiB/213.28 MiB
# ⠴ Preparing packages... (47/49)
# xgboost    ------------------------------ 167.73 MiB/213.28 MiB
# ⠦ Preparing packages... (47/49)
# xgboost    ------------------------------ 168.94 MiB/213.28 MiB
# ⠦ Preparing packages... (47/49)
# xgboost    ------------------------------ 169.31 MiB/213.28 MiB
# ⠦ Preparing packages... (47/49)
# xgboost    ------------------------------ 171.00 MiB/213.28 MiB
# ⠦ Preparing packages... (47/49)
# xgboost    ------------------------------ 173.03 MiB/213.28 MiB
# ⠧ Preparing packages... (47/49)
# xgboost    ------------------------------ 174.98 MiB/213.28 MiB
# ⠧ Preparing packages... (47/49)
# xgboost    ------------------------------ 174.98 MiB/213.28 MiB
# ⠧ Preparing packages... (47/49)
# xgboost    ------------------------------ 175.81 MiB/213.28 MiB
# ⠧ Preparing packages... (47/49)
# xgboost    ------------------------------ 177.68 MiB/213.28 MiB
# ⠇ Preparing packages... (47/49)
# xgboost    ------------------------------ 178.67 MiB/213.28 MiB
# ⠇ Preparing packages... (47/49)
# xgboost    ------------------------------ 179.95 MiB/213.28 MiB
# ⠇ Preparing packages... (47/49)
# xgboost    ------------------------------ 180.70 MiB/213.28 MiB
# ⠇ Preparing packages... (47/49)
# xgboost    ------------------------------ 182.68 MiB/213.28 MiB
# ⠋ Preparing packages... (47/49)
# xgboost    ------------------------------ 182.97 MiB/213.28 MiB
# ⠋ Preparing packages... (47/49)
# xgboost    ------------------------------ 184.54 MiB/213.28 MiB
# ⠋ Preparing packages... (47/49)
# xgboost    ------------------------------ 184.99 MiB/213.28 MiB
# ⠋ Preparing packages... (47/49)
# xgboost    ------------------------------ 186.64 MiB/213.28 MiB
# ⠙ Preparing packages... (47/49)
# xgboost    ------------------------------ 186.92 MiB/213.28 MiB
# ⠙ Preparing packages... (47/49)
# xgboost    ------------------------------ 188.99 MiB/213.28 MiB
# ⠙ Preparing packages... (47/49)
# xgboost    ------------------------------ 190.28 MiB/213.28 MiB
# ⠙ Preparing packages... (47/49)
# xgboost    ------------------------------ 190.67 MiB/213.28 MiB
# ⠹ Preparing packages... (47/49)
# xgboost    ------------------------------ 190.67 MiB/213.28 MiB
# ⠹ Preparing packages... (47/49)
# xgboost    ------------------------------ 191.96 MiB/213.28 MiB
# ⠹ Preparing packages... (47/49)
# xgboost    ------------------------------ 192.70 MiB/213.28 MiB
# ⠹ Preparing packages... (47/49)
# xgboost    ------------------------------ 193.54 MiB/213.28 MiB
# ⠸ Preparing packages... (47/49)
# xgboost    ------------------------------ 194.38 MiB/213.28 MiB
# ⠸ Preparing packages... (47/49)
# xgboost    ------------------------------ 195.95 MiB/213.28 MiB
# ⠸ Preparing packages... (47/49)
# xgboost    ------------------------------ 197.26 MiB/213.28 MiB
# ⠸ Preparing packages... (47/49)
# xgboost    ------------------------------ 198.64 MiB/213.28 MiB
# ⠼ Preparing packages... (47/49)
# xgboost    ------------------------------ 198.97 MiB/213.28 MiB
# ⠼ Preparing packages... (47/49)
# xgboost    ------------------------------ 200.83 MiB/213.28 MiB
# ⠼ Preparing packages... (47/49)
# xgboost    ------------------------------ 202.84 MiB/213.28 MiB
# ⠼ Preparing packages... (47/49)
# xgboost    ------------------------------ 202.96 MiB/213.28 MiB
# ⠴ Preparing packages... (47/49)
# xgboost    ------------------------------ 204.97 MiB/213.28 MiB
# ⠴ Preparing packages... (47/49)
# xgboost    ------------------------------ 204.97 MiB/213.28 MiB
# ⠴ Preparing packages... (47/49)
# xgboost    ------------------------------ 206.95 MiB/213.28 MiB
# ⠴ Preparing packages... (47/49)
# xgboost    ------------------------------ 207.97 MiB/213.28 MiB
# ⠦ Preparing packages... (47/49)
# xgboost    ------------------------------ 209.53 MiB/213.28 MiB
# ⠦ Preparing packages... (47/49)
# xgboost    ------------------------------ 210.00 MiB/213.28 MiB
# ⠦ Preparing packages... (47/49)
# xgboost    ------------------------------ 210.38 MiB/213.28 MiB
# ⠦ Preparing packages... (47/49)
# xgboost    ------------------------------ 211.92 MiB/213.28 MiB
# ⠧ Preparing packages... (47/49)
# xgboost    ------------------------------ 212.86 MiB/213.28 MiB
# ⠧ Preparing packages... (47/49)
# xgboost    ------------------------------ 213.15 MiB/213.28 MiB
# ⠧ Preparing packages... (47/49)
# xgboost    ------------------------------ 213.17 MiB/213.28 MiB
# ⠧ Preparing packages... (47/49)
# xgboost    ------------------------------ 213.28 MiB/213.28 MiB
# ⠧ Preparing packages... (47/49)
# ⠇ Preparing packages... (48/49)
# ⠇ Preparing packages... (48/49)
# ⠇ Preparing packages... (48/49)
# ⠇ Preparing packages... (48/49)
# ⠋ Preparing packages... (48/49)
# ⠋ Preparing packages... (48/49)
# ⠋ Preparing packages... (48/49)
# ⠋ Preparing packages... (48/49)
# ⠙ Preparing packages... (48/49)
# ⠙ Preparing packages... (48/49)
# ⠙ Preparing packages... (48/49)
# ⠙ Preparing packages... (48/49)
# ⠹ Preparing packages... (48/49)
# ⠹ Preparing packages... (48/49)
# ⠹ Preparing packages... (48/49)
# ⠹ Preparing packages... (48/49)
# ⠸ Preparing packages... (48/49)
# ⠸ Preparing packages... (48/49)
# ⠸ Preparing packages... (48/49)
# ⠸ Preparing packages... (48/49)
# ⠼ Preparing packages... (48/49)
# ⠼ Preparing packages... (48/49)
# ⠼ Preparing packages... (48/49)
# ⠼ Preparing packages... (48/49)
# ⠴ Preparing packages... (48/49)
# ⠴ Preparing packages... (48/49)
# ⠴ Preparing packages... (48/49)
# ⠴ Preparing packages... (48/49)
# ⠦ Preparing packages... (48/49)
# ⠦ Preparing packages... (48/49)
# ⠦ Preparing packages... (48/49)
# ⠦ Preparing packages... (48/49)
# ⠧ Preparing packages... (48/49)
# ⠧ Preparing packages... (48/49)
# ⠧ Preparing packages... (48/49)
# ⠧ Preparing packages... (48/49)
# ⠇ Preparing packages... (48/49)
# ⠇ Preparing packages... (48/49)
# ⠇ Preparing packages... (48/49)
# ⠇ Preparing packages... (48/49)
# ⠋ Preparing packages... (48/49)
# ⠋ Preparing packages... (48/49)
# ⠋ Preparing packages... (48/49)
# Prepared 49 packages in 25.22s
# Installed 49 packages in 291ms
#  + biopython==1.83
#  + catboost==1.2.8
#  + certifi==2025.6.15
#  + charset-normalizer==3.4.2
#  + cloudpickle==3.1.1
#  + contourpy==1.1.1
#  + cycler==0.12.1
#  + deap==1.4.3
#  + fonttools==4.57.0
#  + future==1.0.0
#  + graphviz==0.20.3
#  + hyperopt==0.2.7
#  + idna==3.10
#  + igraph==0.11.8
#  + imbalanced-learn==0.12.4
#  + importlib-resources==6.4.5
#  + joblib==1.4.2
#  + kiwisolver==1.4.7
#  + lightgbm==4.6.0
#  + matplotlib==3.7.5
#  + matplotlib-inline==0.1.7
#  + narwhals==1.42.1
#  + networkx==3.1
#  + numpy==1.24.4
#  + nvidia-nccl-cu12==2.27.5
#  + packaging==25.0
#  + pandas==2.0.3
#  + pillow==10.4.0
#  + plotly==6.2.0
#  + py4j==0.10.9.9
#  + pyparsing==3.1.4
#  + python-dateutil==2.9.0.post0
#  + pytz==2025.2
#  + requests==2.32.4
#  + scikit-learn==1.1.0
#  + scipy==1.10.1
#  + setuptools==75.3.2
#  + six==1.17.0
#  + stopit==1.1.2
#  + texttable==1.7.0
#  + threadpoolctl==3.5.0
#  + tpot==0.12.1
#  + tqdm==4.67.1
#  + traitlets==5.14.3
#  + tzdata==2025.2
#  + update-checker==0.18.0
#  + urllib3==2.2.3
#  + xgboost==2.1.4
#  + zipp==3.20.2

# %% [markdown]
# ## 2. Running BioAutoML

# %% [markdown]
# BioAutoML provides multiple scripts for automated classification tasks, including:
#
# - `BioAutoML-feature.py`: Performs automated classification for DNA/RNA sequences. It extracts descriptors (e.g., using MathFeature), selects the most relevant features, and proceeds with binary or multiclass classification.
#
# - `BioAutoML-feature-protein.py`: Executes automated classification for protein sequences, following the same workflow as the DNA/RNA script—feature extraction, selection, and classification.
#
# - `BioAutoML-binary.py`: Handles binary classification tasks. This script can be called by the DNA/RNA or protein scripts or run independently using structured input data.
#
# - `BioAutoML-multiclass.py`: Manages multiclass classification. Like the binary script, it can be invoked by other BioAutoML scripts or used standalone with structured data.

# %% [markdown]
# ## 2.1 DNA/RNA classification

# %% [markdown]
# Let us use `BioAutoML-feature.py` for DNA/RNA classification.
#
# BioAutoML only deals with DNA/RNA sequences using the 4-letter nucleotide notation by IUPAC (A, G, C, and T), eliminating other sequences. BioAutoML considers Uracil in DNA as its counterpart to Thymine in DNA.
#
# To run the script, you can run it locally in the conda environment using `python BioAutoML-feature.py` and the rest of the required arguments. As we are using the uv package manager, we will use `uv run` to run the script in Google Colab.
#
# We have the following arguments that can be used to run the script:
#
# `--fasta_train`: List of paths containing FASTA files used for training;
#
# `--fasta_label_train`: List of labels for the FASTA files used for training;
#
# `--fasta_test`: List of paths containing FASTA files used for testing (optional);
#
# `--fasta_label_test`: List of labels for the FASTA files used for testing (optional);
#
# `--output`: Folder to create and save results;
#
# `--n_cpu`: Number of CPU cores to use (`-1` will use all cores available);
#
# `--estimations`: Number of trials using Bayesian optimization to find the best combination of descriptors and classifiers for classification.
#
# We will run the script using an example from the BioAutoML paper, which involves classifying three classes of RNA: rRNA, sRNA, and tRNA. We will use just five trials for a quick example, but it is recommended to choose at least 50 trials to generate a more accurate model for your problem.

# %%
# !uv run BioAutoML-feature.py \
--fasta_train exemplo_fasta/train/rRNA.fasta exemplo_fasta/train/sRNA.fasta exemplo_fasta/train/tRNA.fasta \
--fasta_label_train rRNA sRNA tRNA \
--fasta_test exemplo_fasta/test/rRNA.fasta exemplo_fasta/test/sRNA.fasta exemplo_fasta/test/tRNA.fasta \
--fasta_label_test rRNA sRNA tRNA \
--output experiment_1 --n_cpu -1 --estimations 5
# Out:
# Streaming output truncated to the last 5000 lines.
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# 100% 5/5 [02:50<00:00, 34.09s/trial, best loss: -0.9844509604608127]
# Computation time - Pipeline - Automated Feature Engineering: 3.8305259346961975 minutes
#
#
# ###################################################################################
# ###################################################################################
# #####################        BioAutoML - MultiClass         #######################
# ##########              Author: Robson Parmezan Bonidia                 ###########
# ##########         WebPage: https://bonidia.github.io/website/          ###########
# ###################################################################################
# ###################################################################################
#
#
# Train - experiment_1/best_descriptors/best_train.csv: Found File
# Train_labels - experiment_1/feat_extraction/flabeltrain.csv: Found File
# Test - experiment_1/best_descriptors/best_test.csv: Found File
# Test_labels - experiment_1/feat_extraction/flabeltest.csv: Found File
# Test_nameseq - experiment_1/feat_extraction/fnameseqtest.csv: Found File
# Number of samples (train): 205
# Number of Labels (train):
# sRNA    133
# tRNA     40
# rRNA     32
# Name: count, dtype: int64
# Number of samples (test): 51
# Number of Labels (test):
# sRNA    33
# tRNA    10
# rRNA     8
# Name: count, dtype: int64
# Number of features (train): 394
# Number of features (test): 394
# Checking missing values...
# There are no missing values...
# Applying StandardScaler()....
# Choosing Classifier...
# Tuning: False
# Classifier: Random Forest
# Applying Feature Importance-Based Feature Selection...
# 100% 5/5 [00:12<00:00,  2.48s/trial, best loss: -0.9900073909830007]
# Best Feature Subset: 92
# Reduction: 302 features
# Saving dataset with selected feature subset - train: experiment_1/best_feature_train.csv
# Saving dataset with selected feature subset - test: experiment_1/best_feature_test.csv
# Feature Selection - Finished...
# Training: StratifiedKFold (cross-validation = 10)...
# Saving results in experiment_1/training_kfold(10)_metrics.csv...
# Saving confusion matrix in experiment_1/training_confusion_matrix.csv...
# Saving trained model in experiment_1/trained_model.sav...
# Training: Finished...
# Generating Feature Importance - Selected feature subset...
# Saving results in experiment_1/feature_importance.csv...
# Generating Performance Test...
# Saving prediction in experiment_1/test_predictions.csv...
# Generating Metrics - Test set...
# Saving Metrics - Test set: experiment_1/metrics_test.csv...
# Saving confusion matrix in experiment_1/test_confusion_matrix.csv...
# Task completed - results generated in experiment_1/!
# Computation time - Pipeline: 0.3799187024434408 minutes

# %% [markdown]
# Multiple results regarding the classification are generated in the new folder created as output for the script.
#
# Let's use the Pandas library to check the generated results. For example we can check the best features found used for training (and therefore, for testing).

# %%
import pandas as pd

df_best_feature_train = pd.read_csv("experiment_1/best_feature_train.csv").sample(5)
df_best_feature_train
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-8-170074303.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df_best_feature_train = pd.read_csv("experiment_1/best_feature_train.csv").sample(5)
#       4 df_best_feature_train
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'experiment_1/best_feature_train.csv'

# %% [markdown]
# BioAutoML employs 10-fold cross-validation on the training dataset to evaluate and recommend the most suitable descriptors and classifier for a given dataset. This approach ensures robust model selection by assessing average performance metrics along with their standard deviations.

# %%
df_training_kfold = pd.read_csv("experiment_1/training_kfold(10)_metrics.csv")
df_training_kfold
# Out:
#     ACC  std_ACC    MCC  std_MCC  F1_micro  std_F1_micro  F1_macro  \
# 0  0.99     0.03  0.981     0.06      0.99          0.03    0.9865
#
#    std_F1_macro    F1_w  std_F1_w   kappa  std_kappa
# 0          0.04  0.9887      0.03  0.9787       0.06

# %% [markdown]
# We have the following confusion matrix for the training dataset.

# %%
df_training_confusion_matrix = pd.read_csv("experiment_1/training_confusion_matrix.csv", header=None)
df_training_confusion_matrix
# Out:
#       0     1     2     3    4
# 0  REAL  rRNA  sRNA  tRNA  All
# 1  rRNA    32     0     0   32
# 2  sRNA     0   133     0  133
# 3  tRNA     0     2    38   40
# 4   All    32   135    38  205

# %% [markdown]
# A test dataset is optional for model evaluation in BioAutoML. If provided, it serves as an independent validation set, ensuring unbiased performance assessment. BioAutoML automatically applies the previously selected features to the test dataset for consistency.

# %%
df_best_feature_test = pd.read_csv("experiment_1/best_feature_test.csv").sample(5)
df_best_feature_test
# Out:
#          AAC       AGC       AGT       ATA       ATG       ATT       CAT  \
# 33  0.407943 -0.411942 -0.262346  1.116870 -0.724370  2.689235  0.906930
# 15 -1.043542 -1.069199 -0.978176  0.133031  0.939737 -0.752259 -0.028481
# 23 -1.043542 -1.069199  0.142663  0.010493  0.723885 -0.752259  1.003437
# 9   1.316113  0.640389 -0.512691  1.310778 -0.520170  0.206846  0.614353
# 20  0.131470 -0.005068  0.180787 -0.572904  1.896282 -0.354263  1.675304
#
#          CCC       CGA       CGG  ...     T_ACG     T_ATC     T_CAC     T_CCA  \
# 33 -0.205443 -0.673999 -0.433216  ... -0.577250 -0.613017 -0.587293  0.241295
# 15 -0.720289 -0.133629  0.427538  ... -0.577250 -0.258021 -0.587293 -0.470438
# 23 -0.720289 -0.252084  0.238852  ... -0.260843 -0.258021 -0.587293 -0.470438
# 9   0.284083  0.519953 -0.076214  ... -0.260843 -0.613017 -0.042519 -0.114572
# 20 -0.303509 -1.419709 -0.659471  ...  0.055564  0.096974 -0.042519 -0.114572
#
#        T_CCC     T_GCG     T_GGG     T_TGA  average_ORF_length  \
# 33 -0.471188 -0.594507 -0.251639 -0.457552            1.521763
# 15 -0.471188  0.301625 -0.459647 -0.457552           -0.653143
# 23 -0.471188 -0.146441 -0.459647 -0.457552           -0.653143
# 9  -0.141517 -0.594507 -0.043631 -0.145930            0.917622
# 20 -0.471188 -0.594507 -0.459647 -0.457552            2.246731
#
#     maximum_GC_content_ORF
# 33                0.647435
# 15               -0.827785
# 23               -0.827785
# 9                 1.195374
# 20                1.090728
#
# [5 rows x 92 columns]

# %% [markdown]
# We can check the metrics regarding the test dataset.

# %%
df_metrics_test = pd.read_csv("experiment_1/metrics_test.csv")
df_metrics_test
# Out:
#      Unnamed: 0  precision    recall  f1-score    support
# 0          rRNA   1.000000  1.000000  1.000000   8.000000
# 1          sRNA   0.970588  1.000000  0.985075  33.000000
# 2          tRNA   1.000000  0.900000  0.947368  10.000000
# 3      accuracy   0.980392  0.980392  0.980392   0.980392
# 4     macro avg   0.990196  0.966667  0.977481  51.000000
# 5  weighted avg   0.980969  0.980392  0.980022  51.000000

# %% [markdown]
# We can also check the prediction done for individual samples.

# %%
df_test_predictions = pd.read_csv("experiment_1/test_predictions.csv", header=None).sample(5)
df_test_predictions
# Out:
#                            0     1
# 42    U00096.3/225500-225572  tRNA
# 16  U00096.3/4325981-4325905  sRNA
# 45  U00096.3/3982375-3982448  tRNA
# 22  U00096.3/4094503-4094573  sRNA
# 8   U00096.3/4027375-4027452  sRNA

# %% [markdown]
# Next we have the following confusion matrix for the test dataset.

# %%
df_test_confusion_matrix = pd.read_csv("experiment_1/test_confusion_matrix.csv", header=None)
df_test_confusion_matrix
# Out:
#       0     1     2     3    4
# 0  REAL  rRNA  sRNA  tRNA  All
# 1  rRNA     8     0     0    8
# 2  sRNA     0    33     0   33
# 3  tRNA     0     1     9   10
# 4   All     8    34     9   51

# %% [markdown]
# Finally, we can also the check the feature importance of the datasets used. For example, let's see the ten most important features.

# %%
df_feature_importance = pd.read_csv("experiment_1/feature_importance.csv", header=None).head(10)
df_feature_importance
# Out:
#                                  0
# 0     1. Feature (GGT): (0.079014)
# 1     2. Feature (GGG): (0.065344)
# 2   3. Feature (T_GCG): (0.046055)
# 3   4. Feature (A_TCC): (0.030537)
# 4   5. Feature (G_TTC): (0.029295)
# 5   6. Feature (C_ATG): (0.027328)
# 6   7. Feature (G_ACT): (0.026743)
# 7   8. Feature (T_CCA): (0.024867)
# 8     9. Feature (TAG): (0.023178)
# 9  10. Feature (A_GCC): (0.023124)

# %% [markdown]
# We can check the best features found used for training (and therefore, for testing).

# %% [markdown]
# ## 2.2 Protein classification

# %% [markdown]
# Let’s use `BioAutoML-feature-protein.py` for protein classification.
#
# BioAutoML handles protein sequences represented with the standard 20-letter IUPAC amino acid notation, automatically filtering out sequences that contain ambiguous amino acids.
#
# The script accepts the same command-line arguments as the DNA/RNA classification script.
#
# In this example, we’ll run it on a dataset of [non-classically secreted proteins](https://academic.oup.com/bioinformatics/article/36/3/704/5545087) from Zhang et al.

# %%
# !uv run BioAutoML-feature-protein.py \
--fasta_train MathFeature/Case\ Studies/CS-I/train_P.fasta MathFeature/Case\ Studies/CS-I/train_N.fasta \
--fasta_label_train positive negative \
--fasta_test MathFeature/Case\ Studies/CS-I/test_P.fasta MathFeature/Case\ Studies/CS-I/test_N.fasta \
--fasta_label_test positive negative \
--output experiment_2 --n_cpu -1 --estimations 1
# Out:
# ###################################################################################
# ###################################################################################
# ##########         BioAutoML- Automated Feature Engineering             ###########
# ##########              Author: Robson Parmezan Bonidia                 ###########
# ##########         WebPage: https://bonidia.github.io/website/          ###########
# ###################################################################################
# ###################################################################################
#
#
# Train - MathFeature/Case Studies/CS-I/train_P.fasta: Found File
# Train - MathFeature/Case Studies/CS-I/train_N.fasta: Found File
# Test - MathFeature/Case Studies/CS-I/test_P.fasta: Found File
# Test - MathFeature/Case Studies/CS-I/test_N.fasta: Found File
# Error: experiment_2/feat_extraction - No such file or directory.
# Creating Directory...
# Extracting features with MathFeature...
# Automated Feature Engineering - Bayesian Optimization
# 100% 1/1 [07:32<00:00, 452.02s/trial, best loss: -0.7690800865800865]
# Done writing JSON data into .json file - Best descriptors!
# Computation time - Pipeline - Automated Feature Engineering: 10.53468414147695 minutes
#
#
# ###################################################################################
# ###################################################################################
# #####################        BioAutoML - Binary             #######################
# ##########              Author: Robson Parmezan Bonidia                 ###########
# ##########         WebPage: https://bonidia.github.io/website/          ###########
# ###################################################################################
# ###################################################################################
#
#
# Train - experiment_2/best_descriptors/best_train.csv: Found File
# Train_labels - experiment_2/feat_extraction/flabeltrain.csv: Found File
# Test - experiment_2/best_descriptors/best_test.csv: Found File
# Test_labels - experiment_2/feat_extraction/flabeltest.csv: Found File
# Test_nameseq - experiment_2/feat_extraction/fnameseqtest.csv: Found File
# Number of samples (train): 587
# Number of samples (test): 68
# Number of features (train): 429
# Number of features (test): 429
# Checking missing values...
# There are no missing values...
# Applying StandardScaler()....
# Choosing Classifier...
# Tuning: False
# Classifier: CatBoost
# Applying Feature Importance-Based Feature Selection...
# 100% 1/1 [00:53<00:00, 53.05s/trial, best loss: -0.7123043855279423]
# Best Feature Subset: 4
# Reduction: 425 features
# Saving dataset with selected feature subset - train: experiment_2/best_feature_train.csv
# Saving dataset with selected feature subset - test: experiment_2/best_feature_test.csv
# Feature Selection - Finished...
# Training: StratifiedKFold (cross-validation = 10)...
# Saving results in experiment_2/training_kfold(10)_metrics.csv...
# Saving confusion matrix in experiment_2/training_confusion_matrix.csv...
# Saving trained model in experiment_2/trained_model.sav...
# Training: Finished...
# Generating Feature Importance - Selected feature subset...
# Saving results in experiment_2/feature_importance.csv...
# Generating Performance Test...
# Saving prediction in experiment_2/test_predictions.csv...
# Generating Metrics - Test set...
# Saving Metrics - Test set: experiment_2/metrics_test.csv...
# Saving confusion matrix in experiment_2/test_confusion_matrix.csv...
# Task completed - results generated in experiment_2/!
# Computation time - Pipeline: 2.7376896182696027 minutes

# %% [markdown]
# We can check the best features found used for training.

# %%
df_best_feature_train = pd.read_csv("experiment_2/best_feature_train.csv").sample(5)
df_best_feature_train
# Out:
#            AA        AE        AV        GV
# 34   0.497500  0.435258  0.151608  1.770790
# 99   1.466538  0.509530 -1.080399  0.901097
# 351 -0.938113 -1.149214 -0.200930  0.946971
# 572 -0.938113 -1.149214 -0.406959  1.252372
# 241  1.048448  0.808418 -0.268581  0.551747

# %% [markdown]
# Average and standard deviation for metrics using 10-fold cross-validation.

# %%
df_training_kfold = pd.read_csv("experiment_2/training_kfold(10)_metrics.csv")
df_training_kfold
# Out:
#      ACC  std_ACC    MCC  std_MCC      F1  std_F1  balanced_ACC  \
# 0  0.818     0.04  0.482     0.12  0.5905    0.09        0.7248
#
#    std_balanced_ACC   kappa  std_kappa   gmean  std_gmean
# 0              0.05  0.4752       0.12  0.6998       0.06

# %% [markdown]
# Confusion matrix for training dataset.

# %%
df_training_confusion_matrix = pd.read_csv("experiment_2/training_confusion_matrix.csv", header=None)
df_training_confusion_matrix
# Out:
#           0         1         2    3
# 0      REAL  negative  positive  All
# 1  negative       403        43  446
# 2  positive        64        77  141
# 3       All       467       120  587

# %% [markdown]
# Test dataset used for prediction using selected descriptors and features.

# %%
df_best_feature_test = pd.read_csv("experiment_2/best_feature_test.csv").sample(5)
df_best_feature_test
# Out:
#           AA        AE        AV        GV
# 53 -0.938113  2.323296 -1.080399 -1.108193
# 7   1.045835  0.219326  2.821334  1.378442
# 52  0.450139  0.127620  0.905207 -0.334858
# 21 -0.125273 -0.775412 -1.080399  0.250200
# 56 -0.448438 -0.473653 -1.080399  0.528465

# %% [markdown]
# Now let's see metrics for binary classification task regarding the test dataset.

# %%
df_metrics_test = pd.read_csv("experiment_2/metrics_test.csv")
df_metrics_test
# Out:
#                   Metrics: Test Set
# 0      Accuracy: 0.6176470588235294
# 1        Recall: 0.8529411764705882
# 2                   Precision: 0.58
# 3            F1: 0.6904761904761905
# 4           AUC: 0.7006920415224913
# 5  balanced ACC: 0.6176470588235294
# 6         gmean: 0.5710731717337529
# 7          MCC: 0.26666666666666666

# %% [markdown]
# We can see predictions done regarding the test dataset.

# %%
df_test_predictions = pd.read_csv("experiment_2/test_predictions.csv", header=None).sample(5)
df_test_predictions
# Out:
#                        0         1
# 59  sp|Q65K78|MOBA_BACLD  positive
# 17   sp|P80868|EFG_BACSU  negative
# 36   sp|Q8DPJ8|RNC_STRR6  negative
# 65  sp|P45947|ARSC_BACSU  negative
# 37   sp|Q88VH0|APT_LACPL  negative

# %% [markdown]
# Confusion matrix for test dataset.

# %%
df_test_confusion_matrix = pd.read_csv("experiment_2/test_confusion_matrix.csv", header=None)
df_test_confusion_matrix
# Out:
#           0         1         2    3
# 0      REAL  negative  positive  All
# 1  negative        29         5   34
# 2  positive        21        13   34
# 3       All        50        18   68

# %% [markdown]
# Feature importance for our dataset.

# %%
df_feature_importance = pd.read_csv("experiment_2/feature_importance.csv", header=None).head(10)
df_feature_importance
# Out:
#                               0
# 0  1. Feature (AA): (27.673667)
# 1  2. Feature (AV): (25.485922)
# 2  3. Feature (AE): (24.590570)
# 3  4. Feature (GV): (22.249840)

# %% [markdown]
# ## 2.3 Structured data classification

# %% [markdown]
# We can also use BioAutoML using structured data, without the need of biological sequences. We can directly use the scripts for binary and multiclass classification.
#
# As example, let us use `BioAutoML-binary.py` for binary classification. Note that `BioAutoML-multiclass.py` is very similar to the binary classification script (with the exception of not having feature selection as an argument).
#
# The structured dataset requires separate CSV files for features and labels, where the labels file must include a column named `label`, and this applies to both training and test sets. For test set evaluation, an additional CSV file is required containing sample names in a column titled `nameseq`.
#
# We have the following arguments that can be used to run the script:
#
# `--train`: Path to the CSV file consisting of the training dataset;
#
# `--train_label`: Path to the CSV file consisting of the labels for the training dataset;
#
# `--test`: Path to the CSV file consisting of the test dataset;
#
# `--test_label`: Path to the CSV file consisting of the labels for the test dataset;
#
# `--test_nameseq`: Path to the CSV file consisting of the names for the samples used in the test dataset;
#
# `--normalization`: Normalization - Features (default = False);
#
# `--featureselection`: Feature Selection (default = True);
#
# `--n_cpu`: Number of CPU cores to use (`-1` will use all cores available);
#
# `--classifier`: Classifier to be used; 0: CatBoost, 1: Random Forest, 2: LightGBM, 3: XGBoost;
#
# `--estimations`: Number of trials using Bayesian optimization to find the best combination of descriptors and classifiers for classification. Note: In this script the original BioAutoML uses a fixed number of trials;
#
# `--imbalance`: To deal with the imbalanced dataset problem (default = False);
#
# `--tuning`: Tuning Classifier (default = False);
#
# `--output`: Folder to create and save results;
#
# We will run an AntiCancer dataset as our example of structured data.

# %%
# !uv run BioAutoML-binary.py \
--train example_csv/AntiCancer/train.csv \
--train_label example_csv/AntiCancer/train_labels.csv \
--test example_csv/AntiCancer/test.csv \
--test_label example_csv/AntiCancer/test_labels.csv \
--test_nameseq example_csv/AntiCancer/test_names.csv \
--normalization True \
--featureselection 1 \
--classifier 1 \
--tuning True \
--output experiment_3 --n_cpu -1 --estimations 5
# Out:
# ###################################################################################
# ###################################################################################
# #####################        BioAutoML - Binary             #######################
# ##########              Author: Robson Parmezan Bonidia                 ###########
# ##########         WebPage: https://bonidia.github.io/website/          ###########
# ###################################################################################
# ###################################################################################
#
#
# Train - example_csv/AntiCancer/train.csv: Found File
# Train_labels - example_csv/AntiCancer/train_labels.csv: Found File
# Test - example_csv/AntiCancer/test.csv: Found File
# Test_labels - example_csv/AntiCancer/test_labels.csv: Found File
# Test_nameseq - example_csv/AntiCancer/test_names.csv: Found File
# Number of samples (train): 240
# Number of samples (test): 104
# Number of features (train): 32
# Number of features (test): 32
# Checking missing values...
# There are no missing values...
# Applying StandardScaler()....
# Choosing Classifier...
# Tuning: True
# Classifier: Random Forest
# 100% 5/5 [00:40<00:00,  8.03s/trial, best loss: -0.8557706093189964]
# Finished Tuning
# Applying Feature Importance-Based Feature Selection...
# 100% 5/5 [00:31<00:00,  6.36s/trial, best loss: -0.8574193548387097]
# Best Feature Subset: 28
# Reduction: 4 features
# Saving dataset with selected feature subset - train: experiment_3/best_feature_train.csv
# Saving dataset with selected feature subset - test: experiment_3/best_feature_test.csv
# Feature Selection - Finished...
# Training: StratifiedKFold (cross-validation = 10)...
# Saving results in experiment_3/training_kfold(10)_metrics.csv...
# Saving confusion matrix in experiment_3/training_confusion_matrix.csv...
# Saving trained model in experiment_3/trained_model.sav...
# Training: Finished...
# Generating Feature Importance - Selected feature subset...
# Saving results in experiment_3/feature_importance.csv...
# Generating Performance Test...
# Saving prediction in experiment_3/test_predictions.csv...
# Generating Metrics - Test set...
# Saving Metrics - Test set: experiment_3/metrics_test.csv...
# Saving confusion matrix in experiment_3/test_confusion_matrix.csv...
# Task completed - results generated in experiment_3/!
# Computation time - Pipeline: 1.7017882068951924 minutes

# %% [markdown]
# The training dataset with selected features.

# %%
df_best_feature_train = pd.read_csv("experiment_3/best_feature_train.csv").sample(5)
df_best_feature_train
# Out:
#          AB.1      AD.1    ASSD.1      AS.1     APL.1    TALU.1      NE.1  \
# 69  -0.070511 -0.112009 -1.472136  0.933721 -0.116351  3.742713 -0.906931
# 75  -0.071851 -0.113304 -0.770558 -0.610568 -0.117061 -0.399544 -1.630867
# 203 -0.064074 -0.112548 -0.426219 -0.419043 -0.112820 -0.399544  0.299629
# 200 -0.066801 -0.112993 -0.529521 -0.776340 -0.111925 -0.399544 -0.786275
# 204 -0.062177 -0.112548 -0.450814 -0.350154 -0.109171 -0.399544 -0.062339
#
#        MOT3.1    MOT4.1         A  ...         L         M         N  \
# 69  -0.258154 -0.109640 -0.155858  ... -0.222618 -0.078331 -0.092564
# 75  -1.275034 -0.811338 -0.164907  ... -0.222618 -0.078331 -0.085988
# 203  0.177651  0.007309 -0.159209  ... -0.218235 -0.064786 -0.092564
# 200 -0.766594 -0.606676 -0.162058  ... -0.218235 -0.071559 -0.092564
# 204 -0.330788 -0.402014 -0.164907  ...  4.708229 -0.068172 -0.086536
#
#             P         Q         R         S         T         W         Y
# 69  -0.065427 -0.062450 -0.112840 -0.076544 -0.913765 -0.076728 -0.578649
# 75  -0.050145 -0.058464 -0.110528 -0.097260 -0.913765 -0.076728  2.274133
# 203 -0.072736 -0.051353 -0.114409 -0.093999 -0.913765 -0.053717  0.583595
# 200 -0.072736 -0.069758 -0.105071 -0.097260  0.211279 -0.042212 -0.578649
# 204 -0.067559 -0.059406 -0.114076 -0.089923 -0.069982 -0.050841 -0.578649
#
# [5 rows x 28 columns]

# %% [markdown]
# Average and standard deviation of metrics using 10-fold cross-validation.

# %%
df_training_kfold = pd.read_csv("experiment_3/training_kfold(10)_metrics.csv")
df_training_kfold
# Out:
#       ACC  std_ACC     MCC  std_MCC      F1  std_F1  balanced_ACC  \
# 0  0.8708     0.07  0.7158     0.18  0.7879    0.14        0.8357
#
#    std_balanced_ACC   kappa  std_kappa   gmean  std_gmean
# 0               0.1  0.6991       0.18  0.8204       0.11

# %% [markdown]
# Confusion matrix for training dataset.

# %%
df_training_confusion_matrix = pd.read_csv("experiment_3/training_confusion_matrix.csv", header=None)
df_training_confusion_matrix
# Out:
#       0    1   2    3
# 0  REAL    0   1  All
# 1     0  149   5  154
# 2     1   22  64   86
# 3   All  171  69  240

# %% [markdown]
# Selected features for test dataset.

# %%
df_best_feature_test = pd.read_csv("experiment_3/best_feature_test.csv").sample(5)
df_best_feature_test
# Out:
#          AB.1      AD.1    ASSD.1      AS.1     APL.1    TALU.1      NE.1  \
# 97  11.491439 -0.112548 -0.433704 -0.397521 -0.110657 -0.399544  0.178973
# 66  -0.068385 -0.109920  1.809837  1.160465 -0.116684  0.019541  1.023565
# 89  -0.067703 -0.113021 -0.549197 -0.758169 -0.112658 -0.399544 -0.906931
# 90  -0.066630 -0.111793  1.492747  0.730698 -0.113442 -0.399544 -0.062339
# 56  -0.067543 -0.111659  1.882024  0.404497 -0.113058 -0.399544 -0.424307
#
#       MOT3.1    MOT4.1         A  ...         L         M         N         P  \
# 97  0.105017 -0.021928 -0.162935  ... -0.213515 -0.073642 -0.089782 -0.072736
# 66  1.267165  1.439942 -0.160245  ... -0.208274 -0.074637 -0.092564 -0.072736
# 89 -0.839228 -0.635913 -0.161891  ... -0.220298 -0.078331 -0.088309 -0.072736
# 90 -0.185520 -0.197352 -0.162770  ... -0.220975 -0.078331 -0.092564 -0.046850
# 56 -0.476057 -0.431252 -0.160023  ... -0.220740 -0.078331 -0.085675 -0.066819
#
#            Q         R         S         T         W         Y
# 97 -0.064980 -0.117077 -0.093874  0.643989 -0.076728  0.628297
# 66 -0.065994 -0.103979 -0.094592 -0.913765 -0.057901 -0.578649
# 89 -0.069758 -0.108602 -0.097260 -0.913765 -0.040182 -0.578649
# 90 -0.069758 -0.102069 -0.089923  0.773802 -0.050841  0.728876
# 56 -0.052011 -0.117077 -0.088875  0.050559 -0.076728 -0.578649
#
# [5 rows x 28 columns]

# %% [markdown]
# Metrics regarding the test dataset.

# %%
df_metrics_test = pd.read_csv("experiment_3/metrics_test.csv")
df_metrics_test
# Out:
#                   Metrics: Test Set
# 0      Accuracy: 0.8557692307692307
# 1        Recall: 0.9807692307692307
# 2     Precision: 0.7846153846153846
# 3            F1: 0.8717948717948717
# 4                       AUC: 0.9375
# 5  balanced ACC: 0.8557692307692307
# 6         gmean: 0.8465907962713515
# 7           MCC: 0.7348737631265355

# %% [markdown]
# Predictions for the test dataset.

# %%
df_test_predictions = pd.read_csv("experiment_3/test_predictions.csv", header=None).sample(5)
df_test_predictions
# Out:
#               0  1
# 96  non-ACP_188  0
# 75   non-ACP_33  0
# 0         ACP_1  1
# 45       ACP_89  1
# 7         ACP_8  1

# %% [markdown]
# Confusion matrix for the test dataset.

# %%
df_test_confusion_matrix = pd.read_csv("experiment_3/test_confusion_matrix.csv", header=None)
df_test_confusion_matrix
# Out:
#       0   1   2    3
# 0  REAL   0   1  All
# 1     0  51   1   52
# 2     1  14  38   52
# 3   All  65  39  104

# %% [markdown]
# Feature importance for the dataset with the most important features.

# %%
df_feature_importance = pd.read_csv("experiment_3/feature_importance.csv", header=None).head(10)
df_feature_importance
# Out:
#                                 0
# 0      1. Feature (K): (0.123231)
# 1      2. Feature (C): (0.092589)
# 2      3. Feature (R): (0.079057)
# 3      4. Feature (P): (0.069036)
# 4      5. Feature (Q): (0.062090)
# 5      6. Feature (F): (0.049899)
# 6   7. Feature (AB.1): (0.047528)
# 7      8. Feature (I): (0.044462)
# 8  9. Feature (APL.1): (0.040998)
# 9     10. Feature (A): (0.040895)
