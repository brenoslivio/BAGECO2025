# %% [markdown]
# <a href="https://colab.research.google.com/github/brenoslivio/BAGECO2025/blob/main/02_BioAutoML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BAGECO 2025 - Metagenomics Workshop
#
# **From Sequences to Predictions – End-to-end analysis using BioAutoML**
#
# *This class was developed for the 17th Symposium on Bacterial Genetics and Ecology (BAGECO 2025) and will be presented at the Metagenomics Workshop on 30.06.2025.*
#
# *For any questions regarding this material, please contact:*
#
# *Breno L. S. de Almeida: breno-livio.silva-de-almeida@ufz.de*
#
# ---
#
# This Jupyter Notebook demonstrates how to use [BioAutoML](https://academic.oup.com/bib/article/23/4/bbac218/6618238) without requiring any local installation.
#
# The demonstration includes three use cases:
#
# 1. Multi-class prediction of DNA/RNA sequences (more than two classes)
#
# 2. Binary classification of protein sequences (two classes)
#
# 3. Prediction using structured data
#
# ---

# %% [markdown]
# ## BioAutoML: Automated Feature Engineering and Metalearning for Classification of Biological Sequences
#
# BioAutoML is an automated machine learning (AutoML) tool that simplifies the analysis of biological sequences, such as noncoding RNAs (ncRNAs), by handling feature extraction, algorithm selection, and model tuning. Traditionally, these tasks require deep expertise and manual effort, but BioAutoML automates the process, transforming raw sequences into structured data, selecting the best features, and optimizing predictive models. This enables faster, more accurate classification of ncRNAs, helping researchers uncover biological insights without extensive machine learning knowledge.
#
# It is also a user-friendly package for binary and multi-class classification, automating feature engineering and metalearning, as demonstrated by the next figure. It requires only biological sequence data (FASTA files) for end-to-end ML experiments, from feature extraction to predictive model generation. Alternatively, its modules can be used independently—either to generate optimal numerical representations for other ML tools or to build models from externally extracted features. BioAutoML consists of two main components:
#
# - Automated Feature Engineering (extraction and selection)
#
# - Metalearning (algorithm recommendation and hyperparameter tuning).
#
# ![modules](https://github.com/Bonidia/BioAutoML/raw/main/img/bio-v2-1.png)
#
# This first stage uses the MathFeature package to extract feature descriptors, including Mathematical (Fourier, Shannon, Tsallis) and Conventional (NAC, DNC, TNC, ORF, kGap, Fickett score, etc.). Over 15 techniques numerically represent biological sequence information.
#
# The second module automates feature engineering, using Bayesian optimization to select the best feature vector and ML algorithm (including ensembles), as shown by the next figure. This approach efficiently handles the NP-hard problem of optimizing numerous feature descriptor combinations.
#
# ![optimization](https://github.com/Bonidia/BioAutoML/raw/main/img/bio-v4-1.png)
#
# This module takes as input:
#
# - All feature descriptors from the first module;
#
# - An objective function (balanced accuracy for binary problems, weighted F1-score for multi-class);
#
# - ML algorithms (CatBoost, AdaBoost, Random Forest, LightGBM) for wrapper-based feature selection. These classifiers were chosen for their strong predictive performance, model interpretability, and widespread use in bioinformatics.
#
# The search space is represented by a partially binary vector (e.g., [1, 0, 1, 0, 0, 1, [2]]), where the last position encodes one of four ML algorithms (0–3) and the others indicate selected (1) or excluded (0) features. BioAutoML uses Bayesian optimization to efficiently find a quasi-optimal feature-algorithm pair, balancing performance and speed. The process evaluates combinations until performance plateaus or after 50 trials (user-adjustable). The output may recommend a single algorithm or an ensemble.

# %% [markdown]
# ## 1. Installing BioAutoML

# %% [markdown]
# First, let's clone the BioAutoML repository from GitHub using Git. Then, we'll navigate into the BioAutoML directory.

# %%
# !git clone https://github.com/Bonidia/BioAutoML.git BioAutoML
# %cd /content/BioAutoML
# Out:
# Cloning into 'BioAutoML'...
# remote: Enumerating objects: 1081, done.
# remote: Counting objects: 100% (357/357), done.
# remote: Compressing objects: 100% (206/206), done.
# remote: Total 1081 (delta 195), reused 256 (delta 148), pack-reused 724 (from 1)
# Receiving objects: 100% (1081/1081), 82.17 MiB | 13.98 MiB/s, done.
# Resolving deltas: 100% (470/470), done.
# Updating files: 100% (416/416), done.
# /content/BioAutoML

# %% [markdown]
# We’ll use Git to switch to the workshop-specific branch. Next, we'll download the required code to run MathFeature within BioAutoML.

# %%
# !git checkout bageco
# !git submodule init
# !git submodule update
# Out:
# Branch 'bageco' set up to track remote branch 'bageco' from 'origin'.
# Switched to a new branch 'bageco'
# Submodule 'MathFeature' (https://github.com/Bonidia/MathFeature.git) registered for path 'MathFeature'
# Submodule 'MathFeature-WebServer' (https://github.com/Bonidia/MathFeature-WebServer.git) registered for path 'MathFeature-WebServer'
# Cloning into '/content/BioAutoML/MathFeature'...
# Cloning into '/content/BioAutoML/MathFeature-WebServer'...
# Submodule path 'MathFeature': checked out '69d2a3206c6db02be9d46db74ad61fc05cc6aee2'
# Submodule path 'MathFeature-WebServer': checked out '5d13e073b30d0f9b333adb411bc843722c09d0ba'

# %% [markdown]
# Let's now retrieve all the necessary packages to run BioAutoML. For our demonstration we will use [uv](https://astral.sh/blog/uv), a very fast package manager.
#
# If you really want to install BioAutoML locally, you can use miniconda installed in your machine. Do all the steps from before, with the exception of `!git checkout bageco`, and run the following:
#
# ```bash
# conda env create -f BioAutoML-env.yml -n bioautoml
# ```
#
# This will install any necessary packages for BioAutoML in a isolated environment and access with:
#
# ```bash
# conda activate bioautoml
# ```
#
# And you can exit the environment with:
#
# ```bash
# conda deactivate
# ```
#
# Let's continue using uv. Note that if you want to add to uv directly to run BioAutoML you can use:
#
# ```bash
# uv add scikit-learn==1.1.0 pandas catboost lightgbm matplotlib-inline  hyperopt setuptools biopython xgboost imbalanced-learn igraph tpot
# ```
#
# As we already have the list of packages inside BioAutoML folder to download, we will just use the command sync to download all the necessary packages.

# %%
# !uv sync
# Out:
# Using CPython 3.8.20
# Creating virtual environment at: .venv
# Resolved 80 packages in 5ms
# ⠙ Preparing packages... (0/49)
# ⠙ Preparing packages... (0/49)
# certifi    ------------------------------     0 B/153.96 KiB
# ⠙ Preparing packages... (0/49)
# urllib3    ------------------------------     0 B/123.38 KiB
# certifi    ------------------------------     0 B/153.96 KiB
# ⠙ Preparing packages... (0/49)
# cloudpickle ------------------------------     0 B/20.50 KiB
# urllib3    ------------------------------     0 B/123.38 KiB
# certifi    ------------------------------     0 B/153.96 KiB
# ⠙ Preparing packages... (0/49)
# threadpoolctl ------------------------------     0 B/17.98 KiB
# cloudpickle ------------------------------     0 B/20.50 KiB
# urllib3    ------------------------------     0 B/123.38 KiB
# certifi    ------------------------------     0 B/153.96 KiB
# ⠙ Preparing packages... (0/49)
# zipp       ------------------------------     0 B/8.98 KiB
# threadpoolctl ------------------------------     0 B/17.98 KiB
# cloudpickle ------------------------------     0 B/20.50 KiB
# urllib3    ------------------------------     0 B/123.38 KiB
# certifi    ------------------------------     0 B/153.96 KiB
# ⠙ Preparing packages... (0/49)
# cycler     ------------------------------     0 B/8.13 KiB
# zipp       ------------------------------     0 B/8.98 KiB
# threadpoolctl ------------------------------     0 B/17.98 KiB
# cloudpickle ------------------------------     0 B/20.50 KiB
# urllib3    ------------------------------     0 B/123.38 KiB
# certifi    ------------------------------     0 B/153.96 KiB
# ⠙ Preparing packages... (0/49)
# cycler     ------------------------------     0 B/8.13 KiB
# zipp       ------------------------------     0 B/8.98 KiB
# threadpoolctl ------------------------------     0 B/17.98 KiB
# cloudpickle ------------------------------     0 B/20.50 KiB
# urllib3    ------------------------------     0 B/123.38 KiB
# certifi    ------------------------------     0 B/153.96 KiB
# ⠙ Preparing packages... (0/49)
# cycler     ------------------------------     0 B/8.13 KiB
# zipp       ------------------------------     0 B/8.98 KiB
# threadpoolctl ------------------------------     0 B/17.98 KiB
# cloudpickle ------------------------------     0 B/20.50 KiB
# urllib3    ------------------------------     0 B/123.38 KiB
# certifi    ------------------------------ 14.88 KiB/153.96 KiB
# ⠙ Preparing packages... (0/49)
# cycler     ------------------------------     0 B/8.13 KiB
# zipp       ------------------------------     0 B/8.98 KiB
# threadpoolctl ------------------------------     0 B/17.98 KiB
# cloudpickle ------------------------------     0 B/20.50 KiB
# urllib3    ------------------------------ 14.88 KiB/123.38 KiB
# certifi    ------------------------------ 14.88 KiB/153.96 KiB
# ⠙ Preparing packages... (0/49)
# cycler     ------------------------------     0 B/8.13 KiB
# zipp       ------------------------------     0 B/8.98 KiB
# threadpoolctl ------------------------------     0 B/17.98 KiB
# cloudpickle ------------------------------ 14.88 KiB/20.50 KiB
# urllib3    ------------------------------ 14.88 KiB/123.38 KiB
# certifi    ------------------------------ 14.88 KiB/153.96 KiB
# ⠙ Preparing packages... (0/49)
# cycler     ------------------------------     0 B/8.13 KiB
# zipp       ------------------------------     0 B/8.98 KiB
# threadpoolctl ------------------------------ 14.88 KiB/17.98 KiB
# cloudpickle ------------------------------ 14.88 KiB/20.50 KiB
# urllib3    ------------------------------ 14.88 KiB/123.38 KiB
# certifi    ------------------------------ 14.88 KiB/153.96 KiB
# ⠙ Preparing packages... (0/49)
# cycler     ------------------------------     0 B/8.13 KiB
# zipp       ------------------------------ 8.98 KiB/8.98 KiB
# threadpoolctl ------------------------------ 14.88 KiB/17.98 KiB
# cloudpickle ------------------------------ 14.88 KiB/20.50 KiB
# urllib3    ------------------------------ 14.88 KiB/123.38 KiB
# certifi    ------------------------------ 14.88 KiB/153.96 KiB
# ⠙ Preparing packages... (0/49)
# cycler     ------------------------------ 8.13 KiB/8.13 KiB
# zipp       ------------------------------ 8.98 KiB/8.98 KiB
# threadpoolctl ------------------------------ 14.88 KiB/17.98 KiB
# cloudpickle ------------------------------ 14.88 KiB/20.50 KiB
# urllib3    ------------------------------ 14.88 KiB/123.38 KiB
# certifi    ------------------------------ 14.88 KiB/153.96 KiB
# ⠙ Preparing packages... (0/49)
# cycler     ------------------------------ 8.13 KiB/8.13 KiB
# zipp       ------------------------------ 8.98 KiB/8.98 KiB
# threadpoolctl ------------------------------ 14.88 KiB/17.98 KiB
# cloudpickle ------------------------------ 14.88 KiB/20.50 KiB
# urllib3    ------------------------------ 14.88 KiB/123.38 KiB
# certifi    ------------------------------ 14.88 KiB/153.96 KiB
# python-dateutil ------------------------------ 14.86 KiB/224.50 KiB
# ⠙ Preparing packages... (0/49)
# cycler     ------------------------------ 8.13 KiB/8.13 KiB
# zipp       ------------------------------ 8.98 KiB/8.98 KiB
# threadpoolctl ------------------------------ 14.88 KiB/17.98 KiB
# cloudpickle ------------------------------ 14.88 KiB/20.50 KiB
# urllib3    ------------------------------ 14.88 KiB/123.38 KiB
# certifi    ------------------------------ 14.88 KiB/153.96 KiB
# python-dateutil ------------------------------ 14.86 KiB/224.50 KiB
# setuptools ------------------------------     0 B/1.19 MiB
# ⠙ Preparing packages... (0/49)
# cycler     ------------------------------ 8.13 KiB/8.13 KiB
# zipp       ------------------------------ 8.98 KiB/8.98 KiB
# threadpoolctl ------------------------------ 14.88 KiB/17.98 KiB
# cloudpickle ------------------------------ 14.88 KiB/20.50 KiB
# urllib3    ------------------------------ 14.88 KiB/123.38 KiB
# certifi    ------------------------------ 14.88 KiB/153.96 KiB
# python-dateutil ------------------------------ 14.86 KiB/224.50 KiB
# setuptools ------------------------------     0 B/1.19 MiB
# igraph     ------------------------------     0 B/3.01 MiB
# ⠙ Preparing packages... (0/49)
# cycler     ------------------------------ 8.13 KiB/8.13 KiB
# zipp       ------------------------------ 8.98 KiB/8.98 KiB
# matplotlib-inline ------------------------------     0 B/9.67 KiB
# threadpoolctl ------------------------------ 14.88 KiB/17.98 KiB
# cloudpickle ------------------------------ 14.88 KiB/20.50 KiB
# urllib3    ------------------------------ 14.88 KiB/123.38 KiB
# certifi    ------------------------------ 14.88 KiB/153.96 KiB
# python-dateutil ------------------------------ 14.86 KiB/224.50 KiB
# setuptools ------------------------------     0 B/1.19 MiB
# igraph     ------------------------------     0 B/3.01 MiB
# ⠙ Preparing packages... (0/49)
# update-checker ------------------------------     0 B/6.84 KiB
# zipp       ------------------------------ 8.98 KiB/8.98 KiB
# matplotlib-inline ------------------------------ 9.67 KiB/9.67 KiB
# texttable  ------------------------------     0 B/10.52 KiB
# six        ------------------------------     0 B/10.79 KiB
# threadpoolctl ------------------------------ 14.88 KiB/17.98 KiB
# cloudpickle ------------------------------ 14.88 KiB/20.50 KiB
# importlib-resources ------------------------------ 14.87 KiB/35.27 KiB
# graphviz   ------------------------------     0 B/46.02 KiB
# requests   ------------------------------     0 B/63.33 KiB
# packaging  ------------------------------     0 B/64.91 KiB
# idna       ------------------------------     0 B/68.79 KiB
# tqdm       ------------------------------     0 B/76.70 KiB
# traitlets  ------------------------------     0 B/83.36 KiB
# tpot       ------------------------------ 11.08 KiB/85.33 KiB
# pyparsing  ------------------------------     0 B/101.66 KiB
# urllib3    ------------------------------ 14.88 KiB/123.38 KiB
# charset-normalizer ------------------------------     0 B/143.96 KiB
# certifi    ------------------------------ 14.88 KiB/153.96 KiB
# py4j       ------------------------------ 14.88 KiB/198.25 KiB
# python-dateutil ------------------------------ 14.86 KiB/224.50 KiB
# imbalanced-learn ------------------------------     0 B/252.27 KiB
# ⠙ Preparing packages... (0/49)
# update-checker ------------------------------ 6.84 KiB/6.84 KiB
# zipp       ------------------------------ 8.98 KiB/8.98 KiB
# matplotlib-inline ------------------------------ 9.67 KiB/9.67 KiB
# texttable  ------------------------------ 1.72 KiB/10.52 KiB
# six        ------------------------------ 10.79 KiB/10.79 KiB
# threadpoolctl ------------------------------ 17.98 KiB/17.98 KiB
# cloudpickle ------------------------------ 20.50 KiB/20.50 KiB
# importlib-resources ------------------------------ 14.87 KiB/35.27 KiB
# graphviz   ------------------------------     0 B/46.02 KiB
# requests   ------------------------------ 14.88 KiB/63.33 KiB
# packaging  ------------------------------     0 B/64.91 KiB
# idna       ------------------------------ 14.88 KiB/68.79 KiB
# tqdm       ------------------------------ 14.88 KiB/76.70 KiB
# traitlets  ------------------------------     0 B/83.36 KiB
# tpot       ------------------------------ 11.08 KiB/85.33 KiB
# pyparsing  ------------------------------ 16.00 KiB/101.66 KiB
# urllib3    ------------------------------ 30.88 KiB/123.38 KiB
# charset-normalizer ------------------------------ 16.00 KiB/143.96 KiB
# certifi    ------------------------------ 30.88 KiB/153.96 KiB
# py4j       ------------------------------ 14.88 KiB/198.25 KiB
# python-dateutil ------------------------------ 30.86 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 16.00 KiB/252.27 KiB
# ⠙ Preparing packages... (0/49)
# update-checker ------------------------------ 6.84 KiB/6.84 KiB
# zipp       ------------------------------ 8.98 KiB/8.98 KiB
# matplotlib-inline ------------------------------ 9.67 KiB/9.67 KiB
# texttable  ------------------------------ 1.72 KiB/10.52 KiB
# six        ------------------------------ 10.79 KiB/10.79 KiB
# cloudpickle ------------------------------ 20.50 KiB/20.50 KiB
# importlib-resources ------------------------------ 14.87 KiB/35.27 KiB
# graphviz   ------------------------------     0 B/46.02 KiB
# requests   ------------------------------ 14.88 KiB/63.33 KiB
# packaging  ------------------------------     0 B/64.91 KiB
# idna       ------------------------------ 14.88 KiB/68.79 KiB
# tqdm       ------------------------------ 14.88 KiB/76.70 KiB
# traitlets  ------------------------------     0 B/83.36 KiB
# tpot       ------------------------------ 11.08 KiB/85.33 KiB
# pyparsing  ------------------------------ 16.00 KiB/101.66 KiB
# urllib3    ------------------------------ 30.88 KiB/123.38 KiB
# charset-normalizer ------------------------------ 16.00 KiB/143.96 KiB
# certifi    ------------------------------ 30.88 KiB/153.96 KiB
# py4j       ------------------------------ 14.88 KiB/198.25 KiB
# python-dateutil ------------------------------ 30.86 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 16.00 KiB/252.27 KiB
# contourpy  ------------------------------ 14.92 KiB/294.07 KiB
# ⠙ Preparing packages... (0/49)
# update-checker ------------------------------ 6.84 KiB/6.84 KiB
# matplotlib-inline ------------------------------ 9.67 KiB/9.67 KiB
# texttable  ------------------------------ 10.52 KiB/10.52 KiB
# six        ------------------------------ 10.79 KiB/10.79 KiB
# cloudpickle ------------------------------ 20.50 KiB/20.50 KiB
# importlib-resources ------------------------------ 14.87 KiB/35.27 KiB
# graphviz   ------------------------------ 16.00 KiB/46.02 KiB
# requests   ------------------------------ 14.88 KiB/63.33 KiB
# packaging  ------------------------------ 16.00 KiB/64.91 KiB
# idna       ------------------------------ 14.88 KiB/68.79 KiB
# tqdm       ------------------------------ 14.88 KiB/76.70 KiB
# traitlets  ------------------------------ 16.00 KiB/83.36 KiB
# tpot       ------------------------------ 30.92 KiB/85.33 KiB
# pyparsing  ------------------------------ 64.00 KiB/101.66 KiB
# urllib3    ------------------------------ 46.88 KiB/123.38 KiB
# charset-normalizer ------------------------------ 32.00 KiB/143.96 KiB
# certifi    ------------------------------ 62.88 KiB/153.96 KiB
# py4j       ------------------------------ 46.88 KiB/198.25 KiB
# python-dateutil ------------------------------ 46.86 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 16.00 KiB/252.27 KiB
# contourpy  ------------------------------ 46.92 KiB/294.07 KiB
# joblib     ------------------------------ 16.00 KiB/294.74 KiB
# ⠙ Preparing packages... (0/49)
# matplotlib-inline ------------------------------ 9.67 KiB/9.67 KiB
# texttable  ------------------------------ 10.52 KiB/10.52 KiB
# six        ------------------------------ 10.79 KiB/10.79 KiB
# cloudpickle ------------------------------ 20.50 KiB/20.50 KiB
# importlib-resources ------------------------------ 14.87 KiB/35.27 KiB
# graphviz   ------------------------------ 16.00 KiB/46.02 KiB
# requests   ------------------------------ 14.88 KiB/63.33 KiB
# packaging  ------------------------------ 16.00 KiB/64.91 KiB
# idna       ------------------------------ 30.88 KiB/68.79 KiB
# tqdm       ------------------------------ 14.88 KiB/76.70 KiB
# traitlets  ------------------------------ 16.00 KiB/83.36 KiB
# tpot       ------------------------------ 30.92 KiB/85.33 KiB
# pyparsing  ------------------------------ 64.00 KiB/101.66 KiB
# urllib3    ------------------------------ 46.88 KiB/123.38 KiB
# charset-normalizer ------------------------------ 32.00 KiB/143.96 KiB
# certifi    ------------------------------ 140.47 KiB/153.96 KiB
# py4j       ------------------------------ 46.88 KiB/198.25 KiB
# python-dateutil ------------------------------ 46.86 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 16.00 KiB/252.27 KiB
# contourpy  ------------------------------ 139.66 KiB/294.07 KiB
# joblib     ------------------------------ 16.00 KiB/294.74 KiB
# tzdata     ------------------------------ 14.88 KiB/339.69 KiB
# ⠙ Preparing packages... (0/49)
# matplotlib-inline ------------------------------ 9.67 KiB/9.67 KiB
# texttable  ------------------------------ 10.52 KiB/10.52 KiB
# six        ------------------------------ 10.79 KiB/10.79 KiB
# cloudpickle ------------------------------ 20.50 KiB/20.50 KiB
# importlib-resources ------------------------------ 14.87 KiB/35.27 KiB
# graphviz   ------------------------------ 16.00 KiB/46.02 KiB
# requests   ------------------------------ 14.88 KiB/63.33 KiB
# packaging  ------------------------------ 16.00 KiB/64.91 KiB
# idna       ------------------------------ 30.88 KiB/68.79 KiB
# tqdm       ------------------------------ 14.88 KiB/76.70 KiB
# traitlets  ------------------------------ 16.00 KiB/83.36 KiB
# tpot       ------------------------------ 30.92 KiB/85.33 KiB
# pyparsing  ------------------------------ 64.00 KiB/101.66 KiB
# urllib3    ------------------------------ 46.88 KiB/123.38 KiB
# charset-normalizer ------------------------------ 32.00 KiB/143.96 KiB
# certifi    ------------------------------ 140.47 KiB/153.96 KiB
# py4j       ------------------------------ 46.88 KiB/198.25 KiB
# python-dateutil ------------------------------ 46.86 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 16.00 KiB/252.27 KiB
# contourpy  ------------------------------ 139.66 KiB/294.07 KiB
# joblib     ------------------------------ 16.00 KiB/294.74 KiB
# tzdata     ------------------------------ 14.88 KiB/339.69 KiB
# ⠙ Preparing packages... (0/49)
# matplotlib-inline ------------------------------ 9.67 KiB/9.67 KiB
# texttable  ------------------------------ 10.52 KiB/10.52 KiB
# six        ------------------------------ 10.79 KiB/10.79 KiB
# importlib-resources ------------------------------ 14.87 KiB/35.27 KiB
# graphviz   ------------------------------ 16.00 KiB/46.02 KiB
# requests   ------------------------------ 14.88 KiB/63.33 KiB
# packaging  ------------------------------ 16.00 KiB/64.91 KiB
# idna       ------------------------------ 30.88 KiB/68.79 KiB
# tqdm       ------------------------------ 14.88 KiB/76.70 KiB
# traitlets  ------------------------------ 32.00 KiB/83.36 KiB
# tpot       ------------------------------ 46.92 KiB/85.33 KiB
# pyparsing  ------------------------------ 79.89 KiB/101.66 KiB
# urllib3    ------------------------------ 46.88 KiB/123.38 KiB
# charset-normalizer ------------------------------ 32.00 KiB/143.96 KiB
# certifi    ------------------------------ 153.96 KiB/153.96 KiB
# py4j       ------------------------------ 46.88 KiB/198.25 KiB
# python-dateutil ------------------------------ 46.86 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 16.00 KiB/252.27 KiB
# contourpy  ------------------------------ 219.66 KiB/294.07 KiB
# joblib     ------------------------------ 27.49 KiB/294.74 KiB
# tzdata     ------------------------------ 14.88 KiB/339.69 KiB
# narwhals   ------------------------------ 62.88 KiB/351.45 KiB
# ⠙ Preparing packages... (0/49)
# matplotlib-inline ------------------------------ 9.67 KiB/9.67 KiB
# texttable  ------------------------------ 10.52 KiB/10.52 KiB
# six        ------------------------------ 10.79 KiB/10.79 KiB
# importlib-resources ------------------------------ 14.87 KiB/35.27 KiB
# graphviz   ------------------------------ 16.00 KiB/46.02 KiB
# requests   ------------------------------ 14.88 KiB/63.33 KiB
# packaging  ------------------------------ 16.00 KiB/64.91 KiB
# idna       ------------------------------ 30.88 KiB/68.79 KiB
# tqdm       ------------------------------ 14.88 KiB/76.70 KiB
# traitlets  ------------------------------ 32.00 KiB/83.36 KiB
# tpot       ------------------------------ 46.92 KiB/85.33 KiB
# pyparsing  ------------------------------ 79.89 KiB/101.66 KiB
# urllib3    ------------------------------ 46.88 KiB/123.38 KiB
# charset-normalizer ------------------------------ 125.36 KiB/143.96 KiB
# certifi    ------------------------------ 153.96 KiB/153.96 KiB
# py4j       ------------------------------ 46.88 KiB/198.25 KiB
# python-dateutil ------------------------------ 46.86 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 16.00 KiB/252.27 KiB
# contourpy  ------------------------------ 219.66 KiB/294.07 KiB
# joblib     ------------------------------ 27.49 KiB/294.74 KiB
# tzdata     ------------------------------ 14.88 KiB/339.69 KiB
# narwhals   ------------------------------ 62.88 KiB/351.45 KiB
# ⠹ Preparing packages... (5/49)
# texttable  ------------------------------ 10.52 KiB/10.52 KiB
# six        ------------------------------ 10.79 KiB/10.79 KiB
# importlib-resources ------------------------------ 14.87 KiB/35.27 KiB
# graphviz   ------------------------------ 16.00 KiB/46.02 KiB
# requests   ------------------------------ 14.88 KiB/63.33 KiB
# packaging  ------------------------------ 16.00 KiB/64.91 KiB
# idna       ------------------------------ 30.88 KiB/68.79 KiB
# tqdm       ------------------------------ 14.88 KiB/76.70 KiB
# traitlets  ------------------------------ 32.00 KiB/83.36 KiB
# tpot       ------------------------------ 46.92 KiB/85.33 KiB
# pyparsing  ------------------------------ 79.89 KiB/101.66 KiB
# urllib3    ------------------------------ 46.88 KiB/123.38 KiB
# charset-normalizer ------------------------------ 125.36 KiB/143.96 KiB
# certifi    ------------------------------ 153.96 KiB/153.96 KiB
# py4j       ------------------------------ 46.88 KiB/198.25 KiB
# python-dateutil ------------------------------ 46.86 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 32.00 KiB/252.27 KiB
# contourpy  ------------------------------ 224.53 KiB/294.07 KiB
# joblib     ------------------------------ 27.49 KiB/294.74 KiB
# tzdata     ------------------------------ 14.88 KiB/339.69 KiB
# narwhals   ------------------------------ 62.88 KiB/351.45 KiB
# future     ------------------------------ 46.88 KiB/479.81 KiB
# ⠹ Preparing packages... (5/49)
# texttable  ------------------------------ 10.52 KiB/10.52 KiB
# six        ------------------------------ 10.79 KiB/10.79 KiB
# importlib-resources ------------------------------ 14.87 KiB/35.27 KiB
# graphviz   ------------------------------ 16.00 KiB/46.02 KiB
# requests   ------------------------------ 14.88 KiB/63.33 KiB
# packaging  ------------------------------ 16.00 KiB/64.91 KiB
# idna       ------------------------------ 30.88 KiB/68.79 KiB
# tqdm       ------------------------------ 14.88 KiB/76.70 KiB
# tpot       ------------------------------ 46.92 KiB/85.33 KiB
# pyparsing  ------------------------------ 79.89 KiB/101.66 KiB
# urllib3    ------------------------------ 46.88 KiB/123.38 KiB
# charset-normalizer ------------------------------ 125.36 KiB/143.96 KiB
# certifi    ------------------------------ 153.96 KiB/153.96 KiB
# py4j       ------------------------------ 46.88 KiB/198.25 KiB
# python-dateutil ------------------------------ 46.86 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 32.00 KiB/252.27 KiB
# contourpy  ------------------------------ 224.53 KiB/294.07 KiB
# joblib     ------------------------------ 27.49 KiB/294.74 KiB
# tzdata     ------------------------------ 14.88 KiB/339.69 KiB
# narwhals   ------------------------------ 62.88 KiB/351.45 KiB
# future     ------------------------------ 46.88 KiB/479.81 KiB
# pytz       ------------------------------ 21.80 KiB/497.29 KiB
#    Building stopit==1.1.2
# ⠹ Preparing packages... (5/49)
# texttable  ------------------------------ 10.52 KiB/10.52 KiB
# six        ------------------------------ 10.79 KiB/10.79 KiB
# importlib-resources ------------------------------ 14.87 KiB/35.27 KiB
# graphviz   ------------------------------ 16.00 KiB/46.02 KiB
# requests   ------------------------------ 14.88 KiB/63.33 KiB
# packaging  ------------------------------ 32.00 KiB/64.91 KiB
# idna       ------------------------------ 30.88 KiB/68.79 KiB
# tqdm       ------------------------------ 14.88 KiB/76.70 KiB
# tpot       ------------------------------ 46.92 KiB/85.33 KiB
# pyparsing  ------------------------------ 79.89 KiB/101.66 KiB
# urllib3    ------------------------------ 46.88 KiB/123.38 KiB
# charset-normalizer ------------------------------ 125.36 KiB/143.96 KiB
# certifi    ------------------------------ 153.96 KiB/153.96 KiB
# py4j       ------------------------------ 46.88 KiB/198.25 KiB
# python-dateutil ------------------------------ 46.86 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 32.00 KiB/252.27 KiB
# contourpy  ------------------------------ 267.66 KiB/294.07 KiB
# joblib     ------------------------------ 32.00 KiB/294.74 KiB
# tzdata     ------------------------------ 14.88 KiB/339.69 KiB
# narwhals   ------------------------------ 62.88 KiB/351.45 KiB
# future     ------------------------------ 46.88 KiB/479.81 KiB
#    Building stopit==1.1.2
# ⠹ Preparing packages... (5/49)
# texttable  ------------------------------ 10.52 KiB/10.52 KiB
# importlib-resources ------------------------------ 14.87 KiB/35.27 KiB
# graphviz   ------------------------------ 16.00 KiB/46.02 KiB
# requests   ------------------------------ 14.88 KiB/63.33 KiB
# packaging  ------------------------------ 32.00 KiB/64.91 KiB
# idna       ------------------------------ 30.88 KiB/68.79 KiB
# tqdm       ------------------------------ 14.88 KiB/76.70 KiB
# tpot       ------------------------------ 46.92 KiB/85.33 KiB
# pyparsing  ------------------------------ 79.89 KiB/101.66 KiB
# urllib3    ------------------------------ 46.88 KiB/123.38 KiB
# charset-normalizer ------------------------------ 125.36 KiB/143.96 KiB
# certifi    ------------------------------ 153.96 KiB/153.96 KiB
# py4j       ------------------------------ 46.88 KiB/198.25 KiB
# python-dateutil ------------------------------ 46.86 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 32.00 KiB/252.27 KiB
# contourpy  ------------------------------ 271.66 KiB/294.07 KiB
# joblib     ------------------------------ 32.00 KiB/294.74 KiB
# tzdata     ------------------------------ 14.88 KiB/339.69 KiB
# narwhals   ------------------------------ 62.88 KiB/351.45 KiB
# future     ------------------------------ 46.88 KiB/479.81 KiB
# pytz       ------------------------------ 21.80 KiB/497.29 KiB
#    Building stopit==1.1.2
# ⠹ Preparing packages... (5/49)
# importlib-resources ------------------------------ 14.87 KiB/35.27 KiB
# graphviz   ------------------------------ 32.00 KiB/46.02 KiB
# requests   ------------------------------ 14.88 KiB/63.33 KiB
# packaging  ------------------------------ 32.00 KiB/64.91 KiB
# idna       ------------------------------ 62.88 KiB/68.79 KiB
# tqdm       ------------------------------ 14.88 KiB/76.70 KiB
# tpot       ------------------------------ 46.92 KiB/85.33 KiB
# pyparsing  ------------------------------ 95.89 KiB/101.66 KiB
# urllib3    ------------------------------ 46.88 KiB/123.38 KiB
# charset-normalizer ------------------------------ 125.36 KiB/143.96 KiB
# certifi    ------------------------------ 153.96 KiB/153.96 KiB
# py4j       ------------------------------ 46.88 KiB/198.25 KiB
# python-dateutil ------------------------------ 46.86 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 32.00 KiB/252.27 KiB
# contourpy  ------------------------------ 271.66 KiB/294.07 KiB
# joblib     ------------------------------ 48.00 KiB/294.74 KiB
# tzdata     ------------------------------ 14.88 KiB/339.69 KiB
# narwhals   ------------------------------ 77.86 KiB/351.45 KiB
# future     ------------------------------ 46.88 KiB/479.81 KiB
# pytz       ------------------------------ 21.80 KiB/497.29 KiB
# kiwisolver ------------------------------ 269.19 KiB/1.13 MiB
#    Building stopit==1.1.2
# ⠹ Preparing packages... (5/49)
# importlib-resources ------------------------------ 14.87 KiB/35.27 KiB
# graphviz   ------------------------------ 32.00 KiB/46.02 KiB
# requests   ------------------------------ 14.88 KiB/63.33 KiB
# packaging  ------------------------------ 32.00 KiB/64.91 KiB
# idna       ------------------------------ 62.88 KiB/68.79 KiB
# tqdm       ------------------------------ 14.88 KiB/76.70 KiB
# tpot       ------------------------------ 46.92 KiB/85.33 KiB
# pyparsing  ------------------------------ 95.89 KiB/101.66 KiB
# urllib3    ------------------------------ 46.88 KiB/123.38 KiB
# charset-normalizer ------------------------------ 125.36 KiB/143.96 KiB
# py4j       ------------------------------ 46.88 KiB/198.25 KiB
# python-dateutil ------------------------------ 46.86 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 32.00 KiB/252.27 KiB
# contourpy  ------------------------------ 271.66 KiB/294.07 KiB
# joblib     ------------------------------ 48.00 KiB/294.74 KiB
# tzdata     ------------------------------ 14.88 KiB/339.69 KiB
# narwhals   ------------------------------ 77.86 KiB/351.45 KiB
# future     ------------------------------ 46.88 KiB/479.81 KiB
# pytz       ------------------------------ 21.80 KiB/497.29 KiB
# kiwisolver ------------------------------ 269.19 KiB/1.13 MiB
# setuptools ------------------------------ 47.89 KiB/1.19 MiB
#    Building stopit==1.1.2
# ⠹ Preparing packages... (5/49)
# importlib-resources ------------------------------ 14.87 KiB/35.27 KiB
# graphviz   ------------------------------ 32.00 KiB/46.02 KiB
# requests   ------------------------------ 14.88 KiB/63.33 KiB
# packaging  ------------------------------ 32.00 KiB/64.91 KiB
# idna       ------------------------------ 62.88 KiB/68.79 KiB
# tqdm       ------------------------------ 14.88 KiB/76.70 KiB
# tpot       ------------------------------ 46.92 KiB/85.33 KiB
# pyparsing  ------------------------------ 95.89 KiB/101.66 KiB
# urllib3    ------------------------------ 46.88 KiB/123.38 KiB
# charset-normalizer ------------------------------ 125.36 KiB/143.96 KiB
# py4j       ------------------------------ 46.88 KiB/198.25 KiB
# python-dateutil ------------------------------ 62.75 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 32.00 KiB/252.27 KiB
# contourpy  ------------------------------ 271.66 KiB/294.07 KiB
# joblib     ------------------------------ 48.00 KiB/294.74 KiB
# tzdata     ------------------------------ 14.88 KiB/339.69 KiB
# narwhals   ------------------------------ 77.86 KiB/351.45 KiB
# future     ------------------------------ 46.88 KiB/479.81 KiB
# pytz       ------------------------------ 21.80 KiB/497.29 KiB
# kiwisolver ------------------------------ 269.19 KiB/1.13 MiB
# setuptools ------------------------------ 47.89 KiB/1.19 MiB
#    Building stopit==1.1.2
# ⠹ Preparing packages... (5/49)
# importlib-resources ------------------------------ 30.87 KiB/35.27 KiB
# graphviz   ------------------------------ 32.00 KiB/46.02 KiB
# requests   ------------------------------ 46.88 KiB/63.33 KiB
# packaging  ------------------------------ 48.00 KiB/64.91 KiB
# tqdm       ------------------------------ 14.88 KiB/76.70 KiB
# tpot       ------------------------------ 46.92 KiB/85.33 KiB
# pyparsing  ------------------------------ 101.66 KiB/101.66 KiB
# urllib3    ------------------------------ 78.88 KiB/123.38 KiB
# charset-normalizer ------------------------------ 143.65 KiB/143.96 KiB
# py4j       ------------------------------ 62.77 KiB/198.25 KiB
# python-dateutil ------------------------------ 219.84 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 32.00 KiB/252.27 KiB
# contourpy  ------------------------------ 287.55 KiB/294.07 KiB
# joblib     ------------------------------ 48.00 KiB/294.74 KiB
# tzdata     ------------------------------ 14.88 KiB/339.69 KiB
# narwhals   ------------------------------ 94.88 KiB/351.45 KiB
# future     ------------------------------ 78.88 KiB/479.81 KiB
# pytz       ------------------------------ 37.80 KiB/497.29 KiB
# kiwisolver ------------------------------ 317.19 KiB/1.13 MiB
# setuptools ------------------------------ 60.45 KiB/1.19 MiB
# hyperopt   ------------------------------ 62.83 KiB/1.51 MiB
#    Building stopit==1.1.2
# ⠹ Preparing packages... (5/49)
# importlib-resources ------------------------------ 30.87 KiB/35.27 KiB
# graphviz   ------------------------------ 32.00 KiB/46.02 KiB
# requests   ------------------------------ 46.88 KiB/63.33 KiB
# packaging  ------------------------------ 64.00 KiB/64.91 KiB
# tqdm       ------------------------------ 30.88 KiB/76.70 KiB
# tpot       ------------------------------ 62.92 KiB/85.33 KiB
# pyparsing  ------------------------------ 101.66 KiB/101.66 KiB
# urllib3    ------------------------------ 78.88 KiB/123.38 KiB
# charset-normalizer ------------------------------ 143.65 KiB/143.96 KiB
# py4j       ------------------------------ 78.77 KiB/198.25 KiB
# python-dateutil ------------------------------ 224.50 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 32.00 KiB/252.27 KiB
# contourpy  ------------------------------ 287.55 KiB/294.07 KiB
# joblib     ------------------------------ 80.00 KiB/294.74 KiB
# tzdata     ------------------------------ 14.88 KiB/339.69 KiB
# narwhals   ------------------------------ 94.88 KiB/351.45 KiB
# future     ------------------------------ 94.88 KiB/479.81 KiB
# pytz       ------------------------------ 37.80 KiB/497.29 KiB
# kiwisolver ------------------------------ 333.08 KiB/1.13 MiB
# setuptools ------------------------------ 60.45 KiB/1.19 MiB
# hyperopt   ------------------------------ 62.83 KiB/1.51 MiB
#    Building stopit==1.1.2
# ⠹ Preparing packages... (5/49)
# importlib-resources ------------------------------ 30.87 KiB/35.27 KiB
# graphviz   ------------------------------ 32.00 KiB/46.02 KiB
# requests   ------------------------------ 46.88 KiB/63.33 KiB
# packaging  ------------------------------ 64.00 KiB/64.91 KiB
# tqdm       ------------------------------ 30.88 KiB/76.70 KiB
# tpot       ------------------------------ 62.92 KiB/85.33 KiB
# urllib3    ------------------------------ 78.88 KiB/123.38 KiB
# charset-normalizer ------------------------------ 143.65 KiB/143.96 KiB
# py4j       ------------------------------ 78.77 KiB/198.25 KiB
# python-dateutil ------------------------------ 224.50 KiB/224.50 KiB
# imbalanced-learn ------------------------------ 48.00 KiB/252.27 KiB
# contourpy  ------------------------------ 294.07 KiB/294.07 KiB
# joblib     ------------------------------ 80.00 KiB/294.74 KiB
# tzdata     ------------------------------ 14.88 KiB/339.69 KiB
# narwhals   ------------------------------ 110.88 KiB/351.45 KiB
# future     ------------------------------ 94.88 KiB/479.81 KiB
# pytz       ------------------------------ 37.80 KiB/497.29 KiB
# kiwisolver ------------------------------ 349.19 KiB/1.13 MiB
# setuptools ------------------------------ 60.45 KiB/1.19 MiB
# hyperopt   ------------------------------ 62.83 KiB/1.51 MiB
# networkx   ------------------------------ 48.00 KiB/1.98 MiB
#    Building stopit==1.1.2
# ⠹ Preparing packages... (5/49)
# importlib-resources ------------------------------ 30.87 KiB/35.27 KiB
# graphviz   ------------------------------ 32.00 KiB/46.02 KiB
# requests   ------------------------------ 62.88 KiB/63.33 KiB
# packaging  ------------------------------ 64.00 KiB/64.91 KiB
# tqdm       ------------------------------ 46.88 KiB/76.70 KiB
# tpot       ------------------------------ 62.92 KiB/85.33 KiB
# urllib3    ------------------------------ 78.88 KiB/123.38 KiB
# charset-normalizer ------------------------------ 143.65 KiB/143.96 KiB
# py4j       ------------------------------ 78.77 KiB/198.25 KiB
# imbalanced-learn ------------------------------ 48.00 KiB/252.27 KiB
# contourpy  ------------------------------ 294.07 KiB/294.07 KiB
# joblib     ------------------------------ 110.75 KiB/294.74 KiB
# tzdata     ------------------------------ 14.88 KiB/339.69 KiB
# narwhals   ------------------------------ 126.88 KiB/351.45 KiB
# future     ------------------------------ 94.88 KiB/479.81 KiB
# pytz       ------------------------------ 37.80 KiB/497.29 KiB
# kiwisolver ------------------------------ 365.19 KiB/1.13 MiB
# setuptools ------------------------------ 60.45 KiB/1.19 MiB
# hyperopt   ------------------------------ 78.83 KiB/1.51 MiB
# networkx   ------------------------------ 64.00 KiB/1.98 MiB
# biopython  ------------------------------ 240.00 KiB/2.97 MiB
#    Building stopit==1.1.2
# ⠹ Preparing packages... (5/49)
# importlib-resources ------------------------------ 30.87 KiB/35.27 KiB
# graphviz   ------------------------------ 32.00 KiB/46.02 KiB
# requests   ------------------------------ 62.88 KiB/63.33 KiB
# packaging  ------------------------------ 64.00 KiB/64.91 KiB
# tqdm       ------------------------------ 46.88 KiB/76.70 KiB
# tpot       ------------------------------ 62.92 KiB/85.33 KiB
# urllib3    ------------------------------ 78.88 KiB/123.38 KiB
# charset-normalizer ------------------------------ 143.65 KiB/143.96 KiB
# py4j       ------------------------------ 78.77 KiB/198.25 KiB
# imbalanced-learn ------------------------------ 48.00 KiB/252.27 KiB
# contourpy  ------------------------------ 294.07 KiB/294.07 KiB
# joblib     ------------------------------ 110.75 KiB/294.74 KiB
# tzdata     ------------------------------ 14.88 KiB/339.69 KiB
# narwhals   ------------------------------ 126.88 KiB/351.45 KiB
# future     ------------------------------ 106.50 KiB/479.81 KiB
# pytz       ------------------------------ 37.80 KiB/497.29 KiB
# kiwisolver ------------------------------ 365.19 KiB/1.13 MiB
# setuptools ------------------------------ 60.45 KiB/1.19 MiB
# hyperopt   ------------------------------ 78.83 KiB/1.51 MiB
# networkx   ------------------------------ 64.00 KiB/1.98 MiB
# biopython  ------------------------------ 240.00 KiB/2.97 MiB
#    Building stopit==1.1.2
# ⠸ Preparing packages... (13/49)
# importlib-resources ------------------------------ 30.87 KiB/35.27 KiB
# graphviz   ------------------------------ 46.02 KiB/46.02 KiB
# requests   ------------------------------ 62.88 KiB/63.33 KiB
# packaging  ------------------------------ 64.00 KiB/64.91 KiB
# tqdm       ------------------------------ 46.88 KiB/76.70 KiB
# tpot       ------------------------------ 62.92 KiB/85.33 KiB
# urllib3    ------------------------------ 94.88 KiB/123.38 KiB
# py4j       ------------------------------ 78.77 KiB/198.25 KiB
# imbalanced-learn ------------------------------ 60.17 KiB/252.27 KiB
# contourpy  ------------------------------ 294.07 KiB/294.07 KiB
# joblib     ------------------------------ 110.75 KiB/294.74 KiB
# tzdata     ------------------------------ 14.88 KiB/339.69 KiB
# narwhals   ------------------------------ 126.88 KiB/351.45 KiB
# future     ------------------------------ 122.50 KiB/479.81 KiB
# pytz       ------------------------------ 37.80 KiB/497.29 KiB
# kiwisolver ------------------------------ 381.19 KiB/1.13 MiB
# setuptools ------------------------------ 60.45 KiB/1.19 MiB
# hyperopt   ------------------------------ 94.83 KiB/1.51 MiB
# networkx   ------------------------------ 80.00 KiB/1.98 MiB
# biopython  ------------------------------ 272.00 KiB/2.97 MiB
# igraph     ------------------------------ 398.22 KiB/3.01 MiB
#    Building stopit==1.1.2
# ⠸ Preparing packages... (13/49)
# importlib-resources ------------------------------ 30.87 KiB/35.27 KiB
# graphviz   ------------------------------ 46.02 KiB/46.02 KiB
# requests   ------------------------------ 62.88 KiB/63.33 KiB
# packaging  ------------------------------ 64.00 KiB/64.91 KiB
# tqdm       ------------------------------ 46.88 KiB/76.70 KiB
# tpot       ------------------------------ 62.92 KiB/85.33 KiB
# urllib3    ------------------------------ 94.88 KiB/123.38 KiB
# py4j       ------------------------------ 78.77 KiB/198.25 KiB
# imbalanced-learn ------------------------------ 60.17 KiB/252.27 KiB
# joblib     ------------------------------ 110.75 KiB/294.74 KiB
# tzdata     ------------------------------ 14.88 KiB/339.69 KiB
# narwhals   ------------------------------ 126.88 KiB/351.45 KiB
# future     ------------------------------ 122.50 KiB/479.81 KiB
# pytz       ------------------------------ 37.80 KiB/497.29 KiB
# kiwisolver ------------------------------ 381.19 KiB/1.13 MiB
# setuptools ------------------------------ 60.45 KiB/1.19 MiB
# hyperopt   ------------------------------ 94.83 KiB/1.51 MiB
# networkx   ------------------------------ 80.00 KiB/1.98 MiB
# biopython  ------------------------------ 272.00 KiB/2.97 MiB
# igraph     ------------------------------ 398.22 KiB/3.01 MiB
# lightgbm   ------------------------------ 396.01 KiB/3.40 MiB
#    Building stopit==1.1.2
# ⠸ Preparing packages... (13/49)
# importlib-resources ------------------------------ 30.87 KiB/35.27 KiB
# graphviz   ------------------------------ 46.02 KiB/46.02 KiB
# requests   ------------------------------ 62.88 KiB/63.33 KiB
# tqdm       ------------------------------ 46.88 KiB/76.70 KiB
# tpot       ------------------------------ 78.92 KiB/85.33 KiB
# urllib3    ------------------------------ 94.88 KiB/123.38 KiB
# py4j       ------------------------------ 78.77 KiB/198.25 KiB
# imbalanced-learn ------------------------------ 60.17 KiB/252.27 KiB
# joblib     ------------------------------ 110.75 KiB/294.74 KiB
# tzdata     ------------------------------ 30.88 KiB/339.69 KiB
# narwhals   ------------------------------ 126.88 KiB/351.45 KiB
# future     ------------------------------ 122.50 KiB/479.81 KiB
# pytz       ------------------------------ 37.80 KiB/497.29 KiB
# kiwisolver ------------------------------ 397.19 KiB/1.13 MiB
# setuptools ------------------------------ 60.45 KiB/1.19 MiB
# hyperopt   ------------------------------ 94.83 KiB/1.51 MiB
# networkx   ------------------------------ 96.00 KiB/1.98 MiB
# biopython  ------------------------------ 272.00 KiB/2.97 MiB
# igraph     ------------------------------ 398.22 KiB/3.01 MiB
# lightgbm   ------------------------------ 396.01 KiB/3.40 MiB
# pillow     ------------------------------ 396.64 KiB/4.32 MiB
#    Building stopit==1.1.2
# ⠸ Preparing packages... (13/49)
# importlib-resources ------------------------------ 30.87 KiB/35.27 KiB
# graphviz   ------------------------------ 46.02 KiB/46.02 KiB
# requests   ------------------------------ 62.88 KiB/63.33 KiB
# tqdm       ------------------------------ 62.78 KiB/76.70 KiB
# tpot       ------------------------------ 78.92 KiB/85.33 KiB
# urllib3    ------------------------------ 94.88 KiB/123.38 KiB
# py4j       ------------------------------ 78.77 KiB/198.25 KiB
# imbalanced-learn ------------------------------ 76.17 KiB/252.27 KiB
# joblib     ------------------------------ 126.75 KiB/294.74 KiB
# tzdata     ------------------------------ 30.88 KiB/339.69 KiB
# narwhals   ------------------------------ 142.88 KiB/351.45 KiB
# future     ------------------------------ 141.64 KiB/479.81 KiB
# pytz       ------------------------------ 37.80 KiB/497.29 KiB
# kiwisolver ------------------------------ 413.19 KiB/1.13 MiB
# setuptools ------------------------------ 76.45 KiB/1.19 MiB
# hyperopt   ------------------------------ 94.83 KiB/1.51 MiB
# networkx   ------------------------------ 96.00 KiB/1.98 MiB
# biopython  ------------------------------ 272.00 KiB/2.97 MiB
# igraph     ------------------------------ 414.22 KiB/3.01 MiB
# lightgbm   ------------------------------ 421.74 KiB/3.40 MiB
# pillow     ------------------------------ 399.29 KiB/4.32 MiB
#    Building stopit==1.1.2
# ⠸ Preparing packages... (13/49)
# importlib-resources ------------------------------ 30.87 KiB/35.27 KiB
# graphviz   ------------------------------ 46.02 KiB/46.02 KiB
# tqdm       ------------------------------ 62.78 KiB/76.70 KiB
# tpot       ------------------------------ 78.92 KiB/85.33 KiB
# urllib3    ------------------------------ 94.88 KiB/123.38 KiB
# py4j       ------------------------------ 78.77 KiB/198.25 KiB
# imbalanced-learn ------------------------------ 76.17 KiB/252.27 KiB
# joblib     ------------------------------ 126.75 KiB/294.74 KiB
# tzdata     ------------------------------ 30.88 KiB/339.69 KiB
# narwhals   ------------------------------ 142.88 KiB/351.45 KiB
# future     ------------------------------ 141.64 KiB/479.81 KiB
# pytz       ------------------------------ 37.80 KiB/497.29 KiB
# kiwisolver ------------------------------ 413.19 KiB/1.13 MiB
# setuptools ------------------------------ 76.45 KiB/1.19 MiB
# hyperopt   ------------------------------ 94.83 KiB/1.51 MiB
# networkx   ------------------------------ 96.00 KiB/1.98 MiB
# biopython  ------------------------------ 288.00 KiB/2.97 MiB
# igraph     ------------------------------ 430.22 KiB/3.01 MiB
# lightgbm   ------------------------------ 421.74 KiB/3.40 MiB
# pillow     ------------------------------ 399.29 KiB/4.32 MiB
# fonttools  ------------------------------ 126.88 KiB/4.47 MiB
#    Building stopit==1.1.2
# ⠸ Preparing packages... (13/49)
# importlib-resources ------------------------------ 30.87 KiB/35.27 KiB
# graphviz   ------------------------------ 46.02 KiB/46.02 KiB
# tqdm       ------------------------------ 62.78 KiB/76.70 KiB
# tpot       ------------------------------ 78.92 KiB/85.33 KiB
# urllib3    ------------------------------ 94.88 KiB/123.38 KiB
# py4j       ------------------------------ 78.77 KiB/198.25 KiB
# imbalanced-learn ------------------------------ 76.17 KiB/252.27 KiB
# joblib     ------------------------------ 126.75 KiB/294.74 KiB
# tzdata     ------------------------------ 30.88 KiB/339.69 KiB
# narwhals   ------------------------------ 142.88 KiB/351.45 KiB
# future     ------------------------------ 141.64 KiB/479.81 KiB
# pytz       ------------------------------ 37.80 KiB/497.29 KiB
# kiwisolver ------------------------------ 413.19 KiB/1.13 MiB
# setuptools ------------------------------ 76.45 KiB/1.19 MiB
# hyperopt   ------------------------------ 94.83 KiB/1.51 MiB
# networkx   ------------------------------ 96.00 KiB/1.98 MiB
# biopython  ------------------------------ 288.00 KiB/2.97 MiB
# igraph     ------------------------------ 430.22 KiB/3.01 MiB
# lightgbm   ------------------------------ 421.74 KiB/3.40 MiB
# pillow     ------------------------------ 399.29 KiB/4.32 MiB
# fonttools  ------------------------------ 126.88 KiB/4.47 MiB
#    Building stopit==1.1.2
# ⠸ Preparing packages... (13/49)
# graphviz   ------------------------------ 46.02 KiB/46.02 KiB
# tqdm       ------------------------------ 62.78 KiB/76.70 KiB
# tpot       ------------------------------ 78.92 KiB/85.33 KiB
# urllib3    ------------------------------ 94.88 KiB/123.38 KiB
# py4j       ------------------------------ 78.77 KiB/198.25 KiB
# imbalanced-learn ------------------------------ 76.17 KiB/252.27 KiB
# joblib     ------------------------------ 126.75 KiB/294.74 KiB
# tzdata     ------------------------------ 30.88 KiB/339.69 KiB
# narwhals   ------------------------------ 142.88 KiB/351.45 KiB
# future     ------------------------------ 141.64 KiB/479.81 KiB
# pytz       ------------------------------ 37.80 KiB/497.29 KiB
# kiwisolver ------------------------------ 445.19 KiB/1.13 MiB
# setuptools ------------------------------ 76.45 KiB/1.19 MiB
# hyperopt   ------------------------------ 94.83 KiB/1.51 MiB
# networkx   ------------------------------ 96.00 KiB/1.98 MiB
# biopython  ------------------------------ 288.00 KiB/2.97 MiB
# igraph     ------------------------------ 446.22 KiB/3.01 MiB
# lightgbm   ------------------------------ 453.52 KiB/3.40 MiB
# pillow     ------------------------------ 431.29 KiB/4.32 MiB
# fonttools  ------------------------------ 126.88 KiB/4.47 MiB
# matplotlib ------------------------------ 80.00 KiB/8.79 MiB
#    Building stopit==1.1.2
# ⠸ Preparing packages... (13/49)
# tqdm       ------------------------------ 62.78 KiB/76.70 KiB
# tpot       ------------------------------ 78.92 KiB/85.33 KiB
# urllib3    ------------------------------ 110.88 KiB/123.38 KiB
# py4j       ------------------------------ 198.25 KiB/198.25 KiB
# imbalanced-learn ------------------------------ 76.17 KiB/252.27 KiB
# joblib     ------------------------------ 142.75 KiB/294.74 KiB
# tzdata     ------------------------------ 30.88 KiB/339.69 KiB
# narwhals   ------------------------------ 142.88 KiB/351.45 KiB
# future     ------------------------------ 141.64 KiB/479.81 KiB
# pytz       ------------------------------ 37.80 KiB/497.29 KiB
# kiwisolver ------------------------------ 445.19 KiB/1.13 MiB
# setuptools ------------------------------ 76.45 KiB/1.19 MiB
# hyperopt   ------------------------------ 110.83 KiB/1.51 MiB
# networkx   ------------------------------ 96.00 KiB/1.98 MiB
# biopython  ------------------------------ 288.00 KiB/2.97 MiB
# igraph     ------------------------------ 446.22 KiB/3.01 MiB
# lightgbm   ------------------------------ 453.52 KiB/3.40 MiB
# pillow     ------------------------------ 431.29 KiB/4.32 MiB
# fonttools  ------------------------------ 206.88 KiB/4.47 MiB
# matplotlib ------------------------------ 96.00 KiB/8.79 MiB
# plotly     ------------------------------ 159.12 KiB/9.19 MiB
#    Building stopit==1.1.2
# ⠸ Preparing packages... (13/49)
# tqdm       ------------------------------ 76.70 KiB/76.70 KiB
# tpot       ------------------------------ 78.92 KiB/85.33 KiB
# urllib3    ------------------------------ 123.38 KiB/123.38 KiB
# py4j       ------------------------------ 198.25 KiB/198.25 KiB
# imbalanced-learn ------------------------------ 80.00 KiB/252.27 KiB
# joblib     ------------------------------ 142.75 KiB/294.74 KiB
# tzdata     ------------------------------ 30.88 KiB/339.69 KiB
# narwhals   ------------------------------ 158.88 KiB/351.45 KiB
# future     ------------------------------ 141.64 KiB/479.81 KiB
# pytz       ------------------------------ 53.80 KiB/497.29 KiB
# kiwisolver ------------------------------ 493.19 KiB/1.13 MiB
# setuptools ------------------------------ 76.45 KiB/1.19 MiB
# hyperopt   ------------------------------ 158.83 KiB/1.51 MiB
# networkx   ------------------------------ 112.00 KiB/1.98 MiB
# biopython  ------------------------------ 303.89 KiB/2.97 MiB
# igraph     ------------------------------ 492.04 KiB/3.01 MiB
# lightgbm   ------------------------------ 483.61 KiB/3.40 MiB
# pillow     ------------------------------ 463.29 KiB/4.32 MiB
# fonttools  ------------------------------ 510.54 KiB/4.47 MiB
# matplotlib ------------------------------ 96.00 KiB/8.79 MiB
# plotly     ------------------------------ 159.12 KiB/9.19 MiB
#    Building stopit==1.1.2
# ⠸ Preparing packages... (13/49)
# tqdm       ------------------------------ 76.70 KiB/76.70 KiB
# tpot       ------------------------------ 85.33 KiB/85.33 KiB
# urllib3    ------------------------------ 123.38 KiB/123.38 KiB
# imbalanced-learn ------------------------------ 80.00 KiB/252.27 KiB
# joblib     ------------------------------ 158.75 KiB/294.74 KiB
# tzdata     ------------------------------ 30.88 KiB/339.69 KiB
# narwhals   ------------------------------ 158.88 KiB/351.45 KiB
# future     ------------------------------ 142.88 KiB/479.81 KiB
# ...
# scikit-learn ------------------------------ 29.56 MiB/29.56 MiB
# scipy      ------------------------------ 32.94 MiB/32.94 MiB
# catboost   ------------------------------ 91.44 MiB/94.56 MiB
# xgboost    ------------------------------ 103.40 MiB/213.28 MiB
# ⠹ Preparing packages... (44/49)
# scikit-learn ------------------------------ 29.56 MiB/29.56 MiB
# catboost   ------------------------------ 91.44 MiB/94.56 MiB
# xgboost    ------------------------------ 103.40 MiB/213.28 MiB
# ⠹ Preparing packages... (44/49)
# catboost   ------------------------------ 91.48 MiB/94.56 MiB
# xgboost    ------------------------------ 104.00 MiB/213.28 MiB
# ⠹ Preparing packages... (44/49)
# catboost   ------------------------------ 91.50 MiB/94.56 MiB
# xgboost    ------------------------------ 104.25 MiB/213.28 MiB
# ⠹ Preparing packages... (44/49)
# catboost   ------------------------------ 91.50 MiB/94.56 MiB
# xgboost    ------------------------------ 105.06 MiB/213.28 MiB
# ⠹ Preparing packages... (44/49)
# catboost   ------------------------------ 91.50 MiB/94.56 MiB
# xgboost    ------------------------------ 106.31 MiB/213.28 MiB
# ⠸ Preparing packages... (46/49)
# catboost   ------------------------------ 91.50 MiB/94.56 MiB
# xgboost    ------------------------------ 108.15 MiB/213.28 MiB
# ⠸ Preparing packages... (46/49)
# catboost   ------------------------------ 91.52 MiB/94.56 MiB
# xgboost    ------------------------------ 108.79 MiB/213.28 MiB
# ⠸ Preparing packages... (46/49)
# catboost   ------------------------------ 91.52 MiB/94.56 MiB
# xgboost    ------------------------------ 111.09 MiB/213.28 MiB
# ⠸ Preparing packages... (46/49)
# catboost   ------------------------------ 91.53 MiB/94.56 MiB
# xgboost    ------------------------------ 111.45 MiB/213.28 MiB
# ⠼ Preparing packages... (46/49)
# catboost   ------------------------------ 92.45 MiB/94.56 MiB
# xgboost    ------------------------------ 112.11 MiB/213.28 MiB
# ⠼ Preparing packages... (46/49)
# catboost   ------------------------------ 92.45 MiB/94.56 MiB
# xgboost    ------------------------------ 113.09 MiB/213.28 MiB
# ⠼ Preparing packages... (46/49)
# catboost   ------------------------------ 92.67 MiB/94.56 MiB
# xgboost    ------------------------------ 114.59 MiB/213.28 MiB
# ⠼ Preparing packages... (46/49)
# catboost   ------------------------------ 93.05 MiB/94.56 MiB
# xgboost    ------------------------------ 115.57 MiB/213.28 MiB
# ⠴ Preparing packages... (46/49)
# catboost   ------------------------------ 93.44 MiB/94.56 MiB
# xgboost    ------------------------------ 116.07 MiB/213.28 MiB
# ⠴ Preparing packages... (46/49)
# catboost   ------------------------------ 93.48 MiB/94.56 MiB
# xgboost    ------------------------------ 117.58 MiB/213.28 MiB
# ⠴ Preparing packages... (46/49)
# catboost   ------------------------------ 94.53 MiB/94.56 MiB
# xgboost    ------------------------------ 117.90 MiB/213.28 MiB
# ⠴ Preparing packages... (46/49)
# catboost   ------------------------------ 94.53 MiB/94.56 MiB
# xgboost    ------------------------------ 119.42 MiB/213.28 MiB
# ⠦ Preparing packages... (46/49)
# catboost   ------------------------------ 94.53 MiB/94.56 MiB
# xgboost    ------------------------------ 119.60 MiB/213.28 MiB
# ⠦ Preparing packages... (46/49)
# catboost   ------------------------------ 94.53 MiB/94.56 MiB
# xgboost    ------------------------------ 121.30 MiB/213.28 MiB
# ⠦ Preparing packages... (46/49)
# xgboost    ------------------------------ 121.42 MiB/213.28 MiB
# ⠦ Preparing packages... (46/49)
# xgboost    ------------------------------ 122.44 MiB/213.28 MiB
# ⠦ Preparing packages... (46/49)
# xgboost    ------------------------------ 123.00 MiB/213.28 MiB
# ⠧ Preparing packages... (47/49)
# xgboost    ------------------------------ 124.81 MiB/213.28 MiB
# ⠧ Preparing packages... (47/49)
# xgboost    ------------------------------ 125.02 MiB/213.28 MiB
# ⠧ Preparing packages... (47/49)
# xgboost    ------------------------------ 126.25 MiB/213.28 MiB
# ⠧ Preparing packages... (47/49)
# xgboost    ------------------------------ 126.79 MiB/213.28 MiB
# ⠇ Preparing packages... (47/49)
# xgboost    ------------------------------ 127.00 MiB/213.28 MiB
# ⠇ Preparing packages... (47/49)
# xgboost    ------------------------------ 128.27 MiB/213.28 MiB
# ⠇ Preparing packages... (47/49)
# xgboost    ------------------------------ 129.02 MiB/213.28 MiB
# ⠇ Preparing packages... (47/49)
# xgboost    ------------------------------ 129.30 MiB/213.28 MiB
# ⠇ Preparing packages... (47/49)
# xgboost    ------------------------------ 130.89 MiB/213.28 MiB
# ⠋ Preparing packages... (47/49)
# xgboost    ------------------------------ 131.70 MiB/213.28 MiB
# ⠋ Preparing packages... (47/49)
# xgboost    ------------------------------ 132.39 MiB/213.28 MiB
# ⠋ Preparing packages... (47/49)
# xgboost    ------------------------------ 133.72 MiB/213.28 MiB
# ⠋ Preparing packages... (47/49)
# xgboost    ------------------------------ 134.14 MiB/213.28 MiB
# ⠙ Preparing packages... (47/49)
# xgboost    ------------------------------ 135.71 MiB/213.28 MiB
# ⠙ Preparing packages... (47/49)
# xgboost    ------------------------------ 136.02 MiB/213.28 MiB
# ⠙ Preparing packages... (47/49)
# xgboost    ------------------------------ 137.71 MiB/213.28 MiB
# ⠙ Preparing packages... (47/49)
# xgboost    ------------------------------ 137.79 MiB/213.28 MiB
# ⠹ Preparing packages... (47/49)
# xgboost    ------------------------------ 139.56 MiB/213.28 MiB
# ⠹ Preparing packages... (47/49)
# xgboost    ------------------------------ 139.73 MiB/213.28 MiB
# ⠹ Preparing packages... (47/49)
# xgboost    ------------------------------ 140.97 MiB/213.28 MiB
# ⠹ Preparing packages... (47/49)
# xgboost    ------------------------------ 141.73 MiB/213.28 MiB
# ⠸ Preparing packages... (47/49)
# xgboost    ------------------------------ 142.70 MiB/213.28 MiB
# ⠸ Preparing packages... (47/49)
# xgboost    ------------------------------ 143.70 MiB/213.28 MiB
# ⠸ Preparing packages... (47/49)
# xgboost    ------------------------------ 144.50 MiB/213.28 MiB
# ⠸ Preparing packages... (47/49)
# xgboost    ------------------------------ 145.73 MiB/213.28 MiB
# ⠼ Preparing packages... (47/49)
# xgboost    ------------------------------ 145.95 MiB/213.28 MiB
# ⠼ Preparing packages... (47/49)
# xgboost    ------------------------------ 147.16 MiB/213.28 MiB
# ⠼ Preparing packages... (47/49)
# xgboost    ------------------------------ 147.73 MiB/213.28 MiB
# ⠼ Preparing packages... (47/49)
# xgboost    ------------------------------ 148.31 MiB/213.28 MiB
# ⠴ Preparing packages... (47/49)
# xgboost    ------------------------------ 149.61 MiB/213.28 MiB
# ⠴ Preparing packages... (47/49)
# xgboost    ------------------------------ 149.73 MiB/213.28 MiB
# ⠴ Preparing packages... (47/49)
# xgboost    ------------------------------ 150.64 MiB/213.28 MiB
# ⠴ Preparing packages... (47/49)
# xgboost    ------------------------------ 151.73 MiB/213.28 MiB
# ⠦ Preparing packages... (47/49)
# xgboost    ------------------------------ 152.30 MiB/213.28 MiB
# ⠦ Preparing packages... (47/49)
# xgboost    ------------------------------ 153.72 MiB/213.28 MiB
# ⠦ Preparing packages... (47/49)
# xgboost    ------------------------------ 153.73 MiB/213.28 MiB
# ⠦ Preparing packages... (47/49)
# xgboost    ------------------------------ 155.62 MiB/213.28 MiB
# ⠧ Preparing packages... (47/49)
# xgboost    ------------------------------ 155.73 MiB/213.28 MiB
# ⠧ Preparing packages... (47/49)
# xgboost    ------------------------------ 157.11 MiB/213.28 MiB
# ⠧ Preparing packages... (47/49)
# xgboost    ------------------------------ 157.73 MiB/213.28 MiB
# ⠧ Preparing packages... (47/49)
# xgboost    ------------------------------ 157.89 MiB/213.28 MiB
# ⠇ Preparing packages... (47/49)
# xgboost    ------------------------------ 159.18 MiB/213.28 MiB
# ⠇ Preparing packages... (47/49)
# xgboost    ------------------------------ 159.73 MiB/213.28 MiB
# ⠇ Preparing packages... (47/49)
# xgboost    ------------------------------ 160.84 MiB/213.28 MiB
# ⠇ Preparing packages... (47/49)
# xgboost    ------------------------------ 161.73 MiB/213.28 MiB
# ⠋ Preparing packages... (47/49)
# xgboost    ------------------------------ 162.48 MiB/213.28 MiB
# ⠋ Preparing packages... (47/49)
# xgboost    ------------------------------ 163.73 MiB/213.28 MiB
# ⠋ Preparing packages... (47/49)
# xgboost    ------------------------------ 163.73 MiB/213.28 MiB
# ⠋ Preparing packages... (47/49)
# xgboost    ------------------------------ 165.12 MiB/213.28 MiB
# ⠙ Preparing packages... (47/49)
# xgboost    ------------------------------ 165.73 MiB/213.28 MiB
# ⠙ Preparing packages... (47/49)
# xgboost    ------------------------------ 166.53 MiB/213.28 MiB
# ⠙ Preparing packages... (47/49)
# xgboost    ------------------------------ 167.72 MiB/213.28 MiB
# ⠙ Preparing packages... (47/49)
# xgboost    ------------------------------ 167.98 MiB/213.28 MiB
# ⠹ Preparing packages... (47/49)
# xgboost    ------------------------------ 169.73 MiB/213.28 MiB
# ⠹ Preparing packages... (47/49)
# xgboost    ------------------------------ 169.73 MiB/213.28 MiB
# ⠹ Preparing packages... (47/49)
# xgboost    ------------------------------ 171.33 MiB/213.28 MiB
# ⠹ Preparing packages... (47/49)
# xgboost    ------------------------------ 171.73 MiB/213.28 MiB
# ⠸ Preparing packages... (47/49)
# xgboost    ------------------------------ 172.66 MiB/213.28 MiB
# ⠸ Preparing packages... (47/49)
# xgboost    ------------------------------ 173.73 MiB/213.28 MiB
# ⠸ Preparing packages... (47/49)
# xgboost    ------------------------------ 174.14 MiB/213.28 MiB
# ⠸ Preparing packages... (47/49)
# xgboost    ------------------------------ 175.72 MiB/213.28 MiB
# ⠼ Preparing packages... (47/49)
# xgboost    ------------------------------ 175.90 MiB/213.28 MiB
# ⠼ Preparing packages... (47/49)
# xgboost    ------------------------------ 177.51 MiB/213.28 MiB
# ⠼ Preparing packages... (47/49)
# xgboost    ------------------------------ 177.73 MiB/213.28 MiB
# ⠼ Preparing packages... (47/49)
# xgboost    ------------------------------ 179.10 MiB/213.28 MiB
# ⠴ Preparing packages... (47/49)
# xgboost    ------------------------------ 179.73 MiB/213.28 MiB
# ⠴ Preparing packages... (47/49)
# xgboost    ------------------------------ 180.99 MiB/213.28 MiB
# ⠴ Preparing packages... (47/49)
# xgboost    ------------------------------ 181.73 MiB/213.28 MiB
# ⠴ Preparing packages... (47/49)
# xgboost    ------------------------------ 182.51 MiB/213.28 MiB
# ⠦ Preparing packages... (47/49)
# xgboost    ------------------------------ 183.73 MiB/213.28 MiB
# ⠦ Preparing packages... (47/49)
# xgboost    ------------------------------ 184.20 MiB/213.28 MiB
# ⠦ Preparing packages... (47/49)
# xgboost    ------------------------------ 184.81 MiB/213.28 MiB
# ⠦ Preparing packages... (47/49)
# xgboost    ------------------------------ 185.99 MiB/213.28 MiB
# ⠧ Preparing packages... (47/49)
# xgboost    ------------------------------ 186.81 MiB/213.28 MiB
# ⠧ Preparing packages... (47/49)
# xgboost    ------------------------------ 187.56 MiB/213.28 MiB
# ⠧ Preparing packages... (47/49)
# xgboost    ------------------------------ 188.82 MiB/213.28 MiB
# ⠧ Preparing packages... (47/49)
# xgboost    ------------------------------ 189.48 MiB/213.28 MiB
# ⠇ Preparing packages... (47/49)
# xgboost    ------------------------------ 190.80 MiB/213.28 MiB
# ⠇ Preparing packages... (47/49)
# xgboost    ------------------------------ 190.92 MiB/213.28 MiB
# ⠇ Preparing packages... (47/49)
# xgboost    ------------------------------ 192.75 MiB/213.28 MiB
# ⠇ Preparing packages... (47/49)
# xgboost    ------------------------------ 192.81 MiB/213.28 MiB
# ⠋ Preparing packages... (47/49)
# xgboost    ------------------------------ 194.18 MiB/213.28 MiB
# ⠋ Preparing packages... (47/49)
# xgboost    ------------------------------ 194.79 MiB/213.28 MiB
# ⠋ Preparing packages... (47/49)
# xgboost    ------------------------------ 195.73 MiB/213.28 MiB
# ⠋ Preparing packages... (47/49)
# xgboost    ------------------------------ 195.78 MiB/213.28 MiB
# ⠙ Preparing packages... (47/49)
# xgboost    ------------------------------ 196.81 MiB/213.28 MiB
# ⠙ Preparing packages... (47/49)
# xgboost    ------------------------------ 197.62 MiB/213.28 MiB
# ⠙ Preparing packages... (47/49)
# xgboost    ------------------------------ 197.87 MiB/213.28 MiB
# ⠙ Preparing packages... (47/49)
# xgboost    ------------------------------ 198.83 MiB/213.28 MiB
# ⠹ Preparing packages... (47/49)
# xgboost    ------------------------------ 199.73 MiB/213.28 MiB
# ⠹ Preparing packages... (47/49)
# xgboost    ------------------------------ 200.82 MiB/213.28 MiB
# ⠹ Preparing packages... (47/49)
# xgboost    ------------------------------ 200.82 MiB/213.28 MiB
# ⠹ Preparing packages... (47/49)
# xgboost    ------------------------------ 202.25 MiB/213.28 MiB
# ⠸ Preparing packages... (47/49)
# xgboost    ------------------------------ 202.82 MiB/213.28 MiB
# ⠸ Preparing packages... (47/49)
# xgboost    ------------------------------ 204.20 MiB/213.28 MiB
# ⠸ Preparing packages... (47/49)
# xgboost    ------------------------------ 204.94 MiB/213.28 MiB
# ⠸ Preparing packages... (47/49)
# xgboost    ------------------------------ 206.71 MiB/213.28 MiB
# ⠼ Preparing packages... (47/49)
# xgboost    ------------------------------ 206.89 MiB/213.28 MiB
# ⠼ Preparing packages... (47/49)
# xgboost    ------------------------------ 208.82 MiB/213.28 MiB
# ⠼ Preparing packages... (47/49)
# xgboost    ------------------------------ 209.75 MiB/213.28 MiB
# ⠼ Preparing packages... (47/49)
# xgboost    ------------------------------ 210.78 MiB/213.28 MiB
# ⠴ Preparing packages... (47/49)
# xgboost    ------------------------------ 211.73 MiB/213.28 MiB
# ⠴ Preparing packages... (47/49)
# xgboost    ------------------------------ 212.31 MiB/213.28 MiB
# ⠴ Preparing packages... (47/49)
# xgboost    ------------------------------ 213.11 MiB/213.28 MiB
# ⠴ Preparing packages... (47/49)
# xgboost    ------------------------------ 213.28 MiB/213.28 MiB
# ⠦ Preparing packages... (47/49)
# ⠦ Preparing packages... (47/49)
# ⠦ Preparing packages... (47/49)
# ⠦ Preparing packages... (47/49)
# ⠦ Preparing packages... (47/49)
# ⠧ Preparing packages... (48/49)
# ⠧ Preparing packages... (48/49)
# ⠧ Preparing packages... (48/49)
# ⠧ Preparing packages... (48/49)
# ⠇ Preparing packages... (48/49)
# ⠇ Preparing packages... (48/49)
# ⠇ Preparing packages... (48/49)
# ⠇ Preparing packages... (48/49)
# ⠋ Preparing packages... (48/49)
# ⠋ Preparing packages... (48/49)
# ⠋ Preparing packages... (48/49)
# ⠋ Preparing packages... (48/49)
# ⠙ Preparing packages... (48/49)
# ⠙ Preparing packages... (48/49)
# ⠙ Preparing packages... (48/49)
# ⠙ Preparing packages... (48/49)
# ⠹ Preparing packages... (48/49)
# ⠹ Preparing packages... (48/49)
# ⠹ Preparing packages... (48/49)
# ⠹ Preparing packages... (48/49)
# ⠸ Preparing packages... (48/49)
# ⠸ Preparing packages... (48/49)
# ⠸ Preparing packages... (48/49)
# ⠸ Preparing packages... (48/49)
# ⠼ Preparing packages... (48/49)
# ⠼ Preparing packages... (48/49)
# ⠼ Preparing packages... (48/49)
# ⠼ Preparing packages... (48/49)
# ⠴ Preparing packages... (48/49)
# ⠴ Preparing packages... (48/49)
# ⠴ Preparing packages... (48/49)
# ⠴ Preparing packages... (48/49)
# ⠦ Preparing packages... (48/49)
# ⠦ Preparing packages... (48/49)
# Prepared 49 packages in 24.60s
# Installed 49 packages in 322ms
#  + biopython==1.83
#  + catboost==1.2.8
#  + certifi==2025.6.15
#  + charset-normalizer==3.4.2
#  + cloudpickle==3.1.1
#  + contourpy==1.1.1
#  + cycler==0.12.1
#  + deap==1.4.3
#  + fonttools==4.57.0
#  + future==1.0.0
#  + graphviz==0.20.3
#  + hyperopt==0.2.7
#  + idna==3.10
#  + igraph==0.11.8
#  + imbalanced-learn==0.12.4
#  + importlib-resources==6.4.5
#  + joblib==1.4.2
#  + kiwisolver==1.4.7
#  + lightgbm==4.6.0
#  + matplotlib==3.7.5
#  + matplotlib-inline==0.1.7
#  + narwhals==1.42.1
#  + networkx==3.1
#  + numpy==1.24.4
#  + nvidia-nccl-cu12==2.27.5
#  + packaging==25.0
#  + pandas==2.0.3
#  + pillow==10.4.0
#  + plotly==6.2.0
#  + py4j==0.10.9.9
#  + pyparsing==3.1.4
#  + python-dateutil==2.9.0.post0
#  + pytz==2025.2
#  + requests==2.32.4
#  + scikit-learn==1.1.0
#  + scipy==1.10.1
#  + setuptools==75.3.2
#  + six==1.17.0
#  + stopit==1.1.2
#  + texttable==1.7.0
#  + threadpoolctl==3.5.0
#  + tpot==0.12.1
#  + tqdm==4.67.1
#  + traitlets==5.14.3
#  + tzdata==2025.2
#  + update-checker==0.18.0
#  + urllib3==2.2.3
#  + xgboost==2.1.4
#  + zipp==3.20.2

# %% [markdown]
# ## 2. Running BioAutoML

# %% [markdown]
# BioAutoML provides multiple scripts for automated classification tasks, including:
#
# - `BioAutoML-feature.py`: Performs automated classification for DNA/RNA sequences. It extracts descriptors (e.g., using MathFeature), selects the most relevant features, and proceeds with binary or multiclass classification.
#
# - `BioAutoML-feature-protein.py`: Executes automated classification for protein sequences, following the same workflow as the DNA/RNA script—feature extraction, selection, and classification.
#
# - `BioAutoML-binary.py`: Handles binary classification tasks. This script can be called by the DNA/RNA or protein scripts or run independently using structured input data.
#
# - `BioAutoML-multiclass.py`: Manages multiclass classification. Like the binary script, it can be invoked by other BioAutoML scripts or used standalone with structured data.

# %% [markdown]
# ## 2.1 DNA/RNA classification

# %% [markdown]
# Let us use `BioAutoML-feature.py` for DNA/RNA classification.
#
# BioAutoML only deals with DNA/RNA sequences using the 4-letter nucleotide notation by IUPAC (A, G, C, and T), eliminating other sequences. BioAutoML considers Uracil in DNA as its counterpart to Thymine in DNA.
#
# To run the script, you can run it locally in the conda environment using `python BioAutoML-feature.py` and the rest of the required arguments. As we are using the uv package manager, we will use `uv run` to run the script in Google Colab.
#
# We have the following arguments that can be used to run the script:
#
# `--fasta_train`: List of paths containing FASTA files used for training;
#
# `--fasta_label_train`: List of labels for the FASTA files used for training;
#
# `--fasta_test`: List of paths containing FASTA files used for testing (optional);
#
# `--fasta_label_test`: List of labels for the FASTA files used for testing (optional);
#
# `--output`: Folder to create and save results;
#
# `--n_cpu`: Number of CPU cores to use (`-1` will use all cores available);
#
# `--estimations`: Number of trials using Bayesian optimization to find the best combination of descriptors and classifiers for classification.
#
# We will run the script using an example from the BioAutoML paper, which involves classifying three classes of RNA: rRNA, sRNA, and tRNA. We will use just five trials for a quick example, but it is recommended to choose at least 50 trials to generate a more accurate model for your problem.

# %%
# !uv run BioAutoML-feature.py \
--fasta_train exemplo_fasta/train/rRNA.fasta exemplo_fasta/train/sRNA.fasta exemplo_fasta/train/tRNA.fasta \
--fasta_label_train rRNA sRNA tRNA \
--fasta_test exemplo_fasta/test/rRNA.fasta exemplo_fasta/test/sRNA.fasta exemplo_fasta/test/tRNA.fasta \
--fasta_label_test rRNA sRNA tRNA \
--output experiment_1 --n_cpu -1 --estimations 5
# Out:
# Streaming output truncated to the last 5000 lines.
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# Saving results in experiment_1/training_kfold(10)_metrics.csv...
# Saving confusion matrix in experiment_1/training_confusion_matrix.csv...
# Saving trained model in experiment_1/trained_model.sav...
# Training: Finished...
# Generating Feature Importance - Selected feature subset...
# Saving results in experiment_1/feature_importance.csv...
# Generating Performance Test...
# Saving prediction in experiment_1/test_predictions.csv...
# Generating Metrics - Test set...
# Saving Metrics - Test set: experiment_1/metrics_test.csv...
# Saving confusion matrix in experiment_1/test_confusion_matrix.csv...
# Task completed - results generated in experiment_1/!
# Computation time - Pipeline: 1.5996325691541036 minutes

# %% [markdown]
# Multiple results regarding the classification are generated in the new folder created as output for the script.
#
# Let's use the Pandas library to check the generated results. For example we can check the best features found used for training (and therefore, for testing).

# %%
import pandas as pd

df_best_feature_train = pd.read_csv("experiment_1/best_feature_train.csv").sample(5)
df_best_feature_train
# Out:
#             A         C         G         T      A_AA      A_AC      A_CA  \
# 109 -1.345878  0.799880  0.822194 -0.048919 -0.441973 -0.464853 -0.402537
# 23   0.647306 -0.828351  0.551648 -0.503856  3.192843  3.084594  3.299759
# 164  0.516396 -0.681095  1.136730 -1.062747 -0.441973 -0.310530 -0.402537
# 22   0.647306 -0.828351  0.551648 -0.503856  3.192843  3.084594  3.299759
# 79   2.324133 -2.594021 -1.021115  0.777163  0.089951 -0.387691 -0.320264
#
#          A_CC      A_GA      A_GC  ...  fminimum  fnone_levated_peak  \
# 109 -0.306832 -0.473865 -0.257023  ... -0.409937           -0.487202
# 23   3.495221  2.981792  3.382541  ... -0.840442            2.943152
# 164 -0.373535 -0.243488 -0.480996  ... -0.790384           -0.310417
# 22   3.561923  2.981792  3.382541  ...  1.007191            2.941471
# 79  -0.440238 -0.320280 -0.425003  ...  0.232370           -0.244568
#
#      fsample_standard_deviation  fpercentile15  fpercentile25  fpercentile75  \
# 109                   -0.425184      -0.415600      -0.389070      -0.418632
# 23                     3.261952       3.082188       3.128148       3.257152
# 164                   -0.355742      -0.376844      -0.363672      -0.370348
# 22                     3.256341       3.212329       3.201782       3.213481
# 79                    -0.340510      -0.287667      -0.301333      -0.343359
#
#      finterquartile_range  fcoefficient_of_variation  fskewness  fkurtosis
# 109             -0.425868                  -1.072879   0.358490  -0.173172
# 23               3.288479                   0.249884   0.242949  -0.061293
# 164             -0.371934                   0.584781   0.094706  -0.508955
# 22               3.215813                   0.235656   0.150882  -0.118698
# 79              -0.353689                  -0.414428  -0.178851  -0.778003
#
# [5 rows x 110 columns]

# %% [markdown]
# BioAutoML employs 10-fold cross-validation on the training dataset to evaluate and recommend the most suitable descriptors and classifier for a given dataset. This approach ensures robust model selection by assessing average performance metrics along with their standard deviations.

# %%
df_training_kfold = pd.read_csv("experiment_1/training_kfold(10)_metrics.csv")
df_training_kfold
# Out:
#      ACC  std_ACC     MCC  std_MCC  F1_micro  std_F1_micro  F1_macro  \
# 0  0.995     0.02  0.9904     0.03     0.995          0.01     0.994
#
#    std_F1_macro    F1_w  std_F1_w   kappa  std_kappa
# 0          0.02  0.9947      0.02  0.9898       0.03

# %% [markdown]
# We have the following confusion matrix for the training dataset.

# %%
df_training_confusion_matrix = pd.read_csv("experiment_1/training_confusion_matrix.csv", header=None)
df_training_confusion_matrix
# Out:
#       0     1     2     3    4
# 0  REAL  rRNA  sRNA  tRNA  All
# 1  rRNA    32     0     0   32
# 2  sRNA     0   133     0  133
# 3  tRNA     0     1    39   40
# 4   All    32   134    39  205

# %% [markdown]
# A test dataset is optional for model evaluation in BioAutoML. If provided, it serves as an independent validation set, ensuring unbiased performance assessment. BioAutoML automatically applies the previously selected features to the test dataset for consistency.

# %%
df_best_feature_test = pd.read_csv("experiment_1/best_feature_test.csv").sample(5)
df_best_feature_test
# Out:
#            A         C         G         T      A_AA      A_AC      A_CA  \
# 47  1.229234 -1.181425 -1.271011  0.953439 -0.353319 -0.464853 -0.402537
# 21  2.864131 -1.994169 -1.399818  0.023458 -0.353319 -0.464853 -0.402537
# 29  0.903768 -0.972491 -1.331619  1.180598 -0.353319 -0.310530 -0.155717
# 36 -0.521347  1.217591  0.433211 -0.940024 -0.441973 -0.387691 -0.402537
# 18 -0.912791  1.566814  0.507657 -0.897705 -0.441973 -0.464853 -0.320264
#
#         A_CC      A_GA      A_GC  ...  fminimum  fnone_levated_peak  \
# 47 -0.440238 -0.473865 -0.425003  ...  0.040502           -0.470425
# 21 -0.440238 -0.320280 -0.480996  ... -0.466381           -0.604259
# 29 -0.306832 -0.397073 -0.369009  ...  2.450072           -0.342319
# 36 -0.373535 -0.473865 -0.201030  ... -0.126074           -0.439249
# 18 -0.373535 -0.473865 -0.257023  ... -0.092022           -0.448304
#
#     fsample_standard_deviation  fpercentile15  fpercentile25  fpercentile75  \
# 47                   -0.418350      -0.402672      -0.368749      -0.413217
# 21                   -0.446499      -0.467512      -0.463309      -0.452453
# 29                   -0.380088      -0.274594      -0.324833      -0.380452
# 36                   -0.401363      -0.408353      -0.400215      -0.421657
# 18                   -0.406175      -0.394241      -0.412207      -0.416914
#
#     finterquartile_range  fcoefficient_of_variation  fskewness  fkurtosis
# 47             -0.424140                  -0.837449  -0.691130  -1.174629
# 21             -0.449691                   0.441449  -0.026436   0.110300
# 29             -0.394137                  -0.892113   0.423859  -1.647557
# 36             -0.426884                   0.332392  -1.094954  -2.447554
# 18             -0.418005                  -0.002717  -0.115670  -1.456941
#
# [5 rows x 110 columns]

# %% [markdown]
# We can check the metrics regarding the test dataset.

# %%
df_metrics_test = pd.read_csv("experiment_1/metrics_test.csv")
df_metrics_test
# Out:
#      Unnamed: 0  precision    recall  f1-score    support
# 0          rRNA   0.888889  1.000000  0.941176   8.000000
# 1          sRNA   0.969697  0.969697  0.969697  33.000000
# 2          tRNA   1.000000  0.900000  0.947368  10.000000
# 3      accuracy   0.960784  0.960784  0.960784   0.960784
# 4     macro avg   0.952862  0.956566  0.952747  51.000000
# 5  weighted avg   0.962963  0.960784  0.960845  51.000000

# %% [markdown]
# We can also check the prediction done for individual samples.

# %%
df_test_predictions = pd.read_csv("experiment_1/test_predictions.csv", header=None).sample(5)
df_test_predictions
# Out:
#                            0     1
# 33  U00096.3/1437118-1437238  sRNA
# 15  U00096.3/4094319-4094389  sRNA
# 43    U00096.3/225381-225454  tRNA
# 25    U00096.3/984395-984437  sRNA
# 48    U00096.3/696740-696667  tRNA

# %% [markdown]
# Next we have the following confusion matrix for the test dataset.

# %%
df_test_confusion_matrix = pd.read_csv("experiment_1/test_confusion_matrix.csv", header=None)
df_test_confusion_matrix
# Out:
#       0     1     2     3    4
# 0  REAL  rRNA  sRNA  tRNA  All
# 1  rRNA     8     0     0    8
# 2  sRNA     1    32     0   33
# 3  tRNA     0     1     9   10
# 4   All     9    33     9   51

# %% [markdown]
# Finally, we can also the check the feature importance of the datasets used. For example, let's see the ten most important features.

# %%
df_feature_importance = pd.read_csv("experiment_1/feature_importance.csv", header=None).head(10)
df_feature_importance
# Out:
#                                              0
# 0                 1. Feature (G): (204.000000)
# 1             2. Feature (G_TTC): (142.000000)
# 2              3. Feature (A_TCC): (99.000000)
# 3              4. Feature (T_GCG): (95.000000)
# 4               5. Feature (G_TC): (79.000000)
# 5                  6. Feature (A): (70.000000)
# 6               7. Feature (A_GC): (68.000000)
# 7               8. Feature (G_GG): (63.000000)
# 8  9. Feature (fickett_score-ORF): (57.000000)
# 9             10. Feature (G_TCG): (55.000000)

# %% [markdown]
# We can check the best features found used for training (and therefore, for testing).

# %% [markdown]
# ## 2.2 Protein classification

# %% [markdown]
# Let’s use `BioAutoML-feature-protein.py` for protein classification.
#
# BioAutoML handles protein sequences represented with the standard 20-letter IUPAC amino acid notation, automatically filtering out sequences that contain ambiguous amino acids.
#
# The script accepts the same command-line arguments as the DNA/RNA classification script.
#
# In this example, we’ll run it on a dataset of [non-classically secreted proteins](https://academic.oup.com/bioinformatics/article/36/3/704/5545087) from Zhang et al.

# %%
# !uv run BioAutoML-feature-protein.py \
--fasta_train MathFeature/Case\ Studies/CS-I/train_P.fasta MathFeature/Case\ Studies/CS-I/train_N.fasta \
--fasta_label_train positive negative \
--fasta_test MathFeature/Case\ Studies/CS-I/test_P.fasta MathFeature/Case\ Studies/CS-I/test_N.fasta \
--fasta_label_test positive negative \
--output experiment_2 --n_cpu -1 --estimations 1
# Out:
# ###################################################################################
# ###################################################################################
# ##########         BioAutoML- Automated Feature Engineering             ###########
# ##########              Author: Robson Parmezan Bonidia                 ###########
# ##########         WebPage: https://bonidia.github.io/website/          ###########
# ###################################################################################
# ###################################################################################
#
#
# Train - MathFeature/Case Studies/CS-I/train_P.fasta: Found File
# Train - MathFeature/Case Studies/CS-I/train_N.fasta: Found File
# Test - MathFeature/Case Studies/CS-I/test_P.fasta: Found File
# Test - MathFeature/Case Studies/CS-I/test_N.fasta: Found File
# Error: experiment_2/feat_extraction - No such file or directory.
# Creating Directory...
# Extracting features with MathFeature...
# Automated Feature Engineering - Bayesian Optimization
# 100% 1/1 [07:58<00:00, 478.49s/trial, best loss: -0.7781024531024532]
# Done writing JSON data into .json file - Best descriptors!
# Computation time - Pipeline - Automated Feature Engineering: 10.959304972489674 minutes
#
#
# ###################################################################################
# ###################################################################################
# #####################        BioAutoML - Binary             #######################
# ##########              Author: Robson Parmezan Bonidia                 ###########
# ##########         WebPage: https://bonidia.github.io/website/          ###########
# ###################################################################################
# ###################################################################################
#
#
# Train - experiment_2/best_descriptors/best_train.csv: Found File
# Train_labels - experiment_2/feat_extraction/flabeltrain.csv: Found File
# Test - experiment_2/best_descriptors/best_test.csv: Found File
# Test_labels - experiment_2/feat_extraction/flabeltest.csv: Found File
# Test_nameseq - experiment_2/feat_extraction/fnameseqtest.csv: Found File
# Number of samples (train): 587
# Number of samples (test): 68
# Number of features (train): 815
# Number of features (test): 815
# Checking missing values...
# There are no missing values...
# Applying StandardScaler()....
# Choosing Classifier...
# Tuning: False
# Classifier: CatBoost
# Applying Feature Importance-Based Feature Selection...
# 100% 1/1 [01:02<00:00, 62.41s/trial, best loss: -0.7747746044045927]
# Best Feature Subset: 17
# Reduction: 798 features
# Saving dataset with selected feature subset - train: experiment_2/best_feature_train.csv
# Saving dataset with selected feature subset - test: experiment_2/best_feature_test.csv
# Feature Selection - Finished...
# Training: StratifiedKFold (cross-validation = 10)...
# Saving results in experiment_2/training_kfold(10)_metrics.csv...
# Saving confusion matrix in experiment_2/training_confusion_matrix.csv...
# Saving trained model in experiment_2/trained_model.sav...
# Training: Finished...
# Generating Feature Importance - Selected feature subset...
# Saving results in experiment_2/feature_importance.csv...
# Generating Performance Test...
# Saving prediction in experiment_2/test_predictions.csv...
# Generating Metrics - Test set...
# Saving Metrics - Test set: experiment_2/metrics_test.csv...
# Saving confusion matrix in experiment_2/test_confusion_matrix.csv...
# Task completed - results generated in experiment_2/!
# Computation time - Pipeline: 3.5092020551363627 minutes

# %% [markdown]
# We can check the best features found used for training.

# %%
df_best_feature_train = pd.read_csv("experiment_2/best_feature_train.csv").sample(5)
df_best_feature_train
# Out:
#           A_A       G_N       L_N        AA        AE        AV        EG  \
# 484  0.320398 -0.796494  0.803822 -0.938113  0.440584 -0.844942 -0.054795
# 236 -1.020591 -0.796494 -0.070772 -0.938113 -1.149214 -1.080399 -1.082223
# 497 -0.014849 -0.796494 -0.508069 -0.938113  0.092073 -0.222476 -0.146325
# 136 -1.020591 -0.796494 -0.945366  1.133587 -1.149214 -1.080399  2.150225
# 522  1.326140 -0.796494  1.241119 -0.202263 -1.149214 -0.729573 -1.082223
#
#            GA        GV        IK        KL        LL        QI        SK  \
# 484  0.416353 -0.007751  0.506367  0.317572 -0.581984 -0.557296 -0.467538
# 236 -1.147570 -1.108193 -1.056024 -1.306153  1.166336 -0.983263  5.538689
# 497  0.277028  0.395418  0.977123 -1.306153 -0.434371  0.568815  0.613915
# 136 -1.147570 -1.108193 -1.056024 -1.306153 -1.269994 -0.983263 -1.091667
# 522 -0.759201 -1.108193  0.939348  0.421933  0.438543  0.920789  1.233185
#
#            TE        VA        VG
# 484 -0.051507 -1.082512 -0.454238
# 236  2.400019 -1.082512 -1.088005
# 497  0.741342 -0.647020  0.066609
# 136 -1.016247 -1.082512 -1.088005
# 522 -0.057950 -0.726345 -1.088005

# %% [markdown]
# Average and standard deviation for metrics using 10-fold cross-validation.

# %%
df_training_kfold = pd.read_csv("experiment_2/training_kfold(10)_metrics.csv")
df_training_kfold
# Out:
#       ACC  std_ACC     MCC  std_MCC      F1  std_F1  balanced_ACC  \
# 0  0.8621     0.04  0.6024     0.12  0.6738    0.11        0.7754
#
#    std_balanced_ACC   kappa  std_kappa   gmean  std_gmean
# 0              0.07  0.5892       0.13  0.7523       0.09

# %% [markdown]
# Confusion matrix for training dataset.

# %%
df_training_confusion_matrix = pd.read_csv("experiment_2/training_confusion_matrix.csv", header=None)
df_training_confusion_matrix
# Out:
#           0         1         2    3
# 0      REAL  negative  positive  All
# 1  negative       420        26  446
# 2  positive        54        87  141
# 3       All       474       113  587

# %% [markdown]
# Test dataset used for prediction using selected descriptors and features.

# %%
df_best_feature_test = pd.read_csv("experiment_2/best_feature_test.csv").sample(5)
df_best_feature_test
# Out:
#          A_A       G_N       L_N        AA        AE        AV        EG  \
# 18  0.655646 -0.796494 -0.070772  4.792119 -1.149214 -1.080399  3.388183
# 48 -1.020591 -0.796494 -0.945366 -0.938113  2.458151 -1.080399 -1.082223
# 23 -1.020591 -0.796494 -0.508069  0.253573 -1.149214 -1.080399  2.636522
# 36 -1.020591 -0.136124 -0.508069 -0.355167 -0.344974  0.587166  0.736903
# 40  0.655646  0.524246 -0.070772 -0.938113 -0.517311 -0.425284 -0.367566
#
#           GA        GV        IK        KL        LL        QI        SK  \
# 18 -1.147570  1.285855 -1.056024  0.712398  0.725723 -0.983263 -1.091667
# 48  0.922477 -1.108193 -1.056024  0.536020 -1.269994 -0.983263 -1.091667
# 23  0.739287  2.874825  2.175420  3.731294 -1.269994 -0.983263 -1.091667
# 36 -0.224562 -1.108193 -0.265649  1.979454  3.602665 -0.983263  1.118452
# 40 -0.422350  1.188139 -0.435015 -0.660766  0.006179 -0.983263 -1.091667
#
#           TE        VA        VG
# 18  7.379045 -1.082512 -1.088005
# 48 -1.016247 -1.082512 -1.088005
# 23 -1.016247 -1.082512  1.205896
# 36 -1.016247  0.610437 -1.088005
# 40 -0.121511  0.247663 -0.206336

# %% [markdown]
# Now let's see metrics for binary classification task regarding the test dataset.

# %%
df_metrics_test = pd.read_csv("experiment_2/metrics_test.csv")
df_metrics_test
# Out:
#                   Metrics: Test Set
# 0      Accuracy: 0.6029411764705882
# 1        Recall: 0.7647058823529411
# 2     Precision: 0.5777777777777777
# 3            F1: 0.6582278481012658
# 4           AUC: 0.6548442906574395
# 5  balanced ACC: 0.6029411764705882
# 6         gmean: 0.5808358134744558
# 7          MCC: 0.21758445525607323

# %% [markdown]
# We can see predictions done regarding the test dataset.

# %%
df_test_predictions = pd.read_csv("experiment_2/test_predictions.csv", header=None).sample(5)
df_test_predictions
# Out:
#                         0         1
# 53  sp|Q7A827|HDOX2_STAAN  negative
# 9   sp|P9WN39|GLN1B_MYCTU  negative
# 6    sp|P54375|SODM_BACSU  negative
# 46   sp|Q72X78|SPEE_BACC1  negative
# 44    sp|Q92A79|NDK_LISIN  negative

# %% [markdown]
# Confusion matrix for test dataset.

# %%
df_test_confusion_matrix = pd.read_csv("experiment_2/test_confusion_matrix.csv", header=None)
df_test_confusion_matrix
# Out:
#           0         1         2    3
# 0      REAL  negative  positive  All
# 1  negative        26         8   34
# 2  positive        19        15   34
# 3       All        45        23   68

# %% [markdown]
# Feature importance for our dataset.

# %%
df_feature_importance = pd.read_csv("experiment_2/feature_importance.csv", header=None).head(10)
df_feature_importance
# Out:
#                               0
# 0  1. Feature (AA): (12.128527)
# 1   2. Feature (QI): (7.163575)
# 2   3. Feature (AV): (7.062948)
# 3   4. Feature (EG): (7.017453)
# 4   5. Feature (SK): (6.795861)
# 5   6. Feature (GV): (6.687290)
# 6   7. Feature (LL): (5.995464)
# 7  8. Feature (L_N): (5.774325)
# 8  9. Feature (G_N): (5.747755)
# 9  10. Feature (GA): (5.489212)

# %% [markdown]
# ## 2.3 Structured data classification

# %% [markdown]
# We can also use BioAutoML using structured data, without the need of biological sequences. We can directly use the scripts for binary and multiclass classification.
#
# As example, let us use `BioAutoML-binary.py` for binary classification. Note that `BioAutoML-multiclass.py` is very similar to the binary classification script (with the exception of not having feature selection as an argument).
#
# The structured dataset requires separate CSV files for features and labels, where the labels file must include a column named `label`, and this applies to both training and test sets. For test set evaluation, an additional CSV file is required containing sample names in a column titled `nameseq`.
#
# We have the following arguments that can be used to run the script:
#
# `--train`: Path to the CSV file consisting of the training dataset;
#
# `--train_label`: Path to the CSV file consisting of the labels for the training dataset;
#
# `--test`: Path to the CSV file consisting of the test dataset;
#
# `--test_label`: Path to the CSV file consisting of the labels for the test dataset;
#
# `--test_nameseq`: Path to the CSV file consisting of the names for the samples used in the test dataset;
#
# `--normalization`: Normalization - Features (default = False);
#
# `--featureselection`: Feature Selection (default = True);
#
# `--n_cpu`: Number of CPU cores to use (`-1` will use all cores available);
#
# `--classifier`: Classifier to be used; 0: CatBoost, 1: Random Forest, 2: LightGBM, 3: XGBoost;
#
# `--estimations`: Number of trials using Bayesian optimization to find the best combination of descriptors and classifiers for classification. Note: In this script the original BioAutoML uses a fixed number of trials;
#
# `--imbalance`: To deal with the imbalanced dataset problem (default = False);
#
# `--tuning`: Tuning Classifier (default = False);
#
# `--output`: Folder to create and save results;
#
# We will run an AntiCancer dataset as our example of structured data.

# %%
# !uv run BioAutoML-binary.py \
--train example_csv/AntiCancer/train.csv \
--train_label example_csv/AntiCancer/train_labels.csv \
--test example_csv/AntiCancer/test.csv \
--test_label example_csv/AntiCancer/test_labels.csv \
--test_nameseq example_csv/AntiCancer/test_names.csv \
--normalization True \
--featureselection 1 \
--classifier 1 \
--tuning True \
--output experiment_3 --n_cpu -1 --estimations 5
# Out:
# ###################################################################################
# ###################################################################################
# #####################        BioAutoML - Binary             #######################
# ##########              Author: Robson Parmezan Bonidia                 ###########
# ##########         WebPage: https://bonidia.github.io/website/          ###########
# ###################################################################################
# ###################################################################################
#
#
# Train - example_csv/AntiCancer/train.csv: Found File
# Train_labels - example_csv/AntiCancer/train_labels.csv: Found File
# Test - example_csv/AntiCancer/test.csv: Found File
# Test_labels - example_csv/AntiCancer/test_labels.csv: Found File
# Test_nameseq - example_csv/AntiCancer/test_names.csv: Found File
# Number of samples (train): 240
# Number of samples (test): 104
# Number of features (train): 32
# Number of features (test): 32
# Checking missing values...
# There are no missing values...
# Applying StandardScaler()....
# Choosing Classifier...
# Tuning: True
# Classifier: Random Forest
# 100% 5/5 [00:47<00:00,  9.44s/trial, best loss: -0.8413451402066203]
# Finished Tuning
# Applying Feature Importance-Based Feature Selection...
# 100% 5/5 [01:23<00:00, 16.74s/trial, best loss: -0.8265190807505798]
# Best Feature Subset: 5
# Reduction: 27 features
# Saving dataset with selected feature subset - train: experiment_3/best_feature_train.csv
# Saving dataset with selected feature subset - test: experiment_3/best_feature_test.csv
# Feature Selection - Finished...
# Training: StratifiedKFold (cross-validation = 10)...
# Saving results in experiment_3/training_kfold(10)_metrics.csv...
# Saving confusion matrix in experiment_3/training_confusion_matrix.csv...
# Saving trained model in experiment_3/trained_model.sav...
# Training: Finished...
# Generating Feature Importance - Selected feature subset...
# Saving results in experiment_3/feature_importance.csv...
# Generating Performance Test...
# Saving prediction in experiment_3/test_predictions.csv...
# Generating Metrics - Test set...
# Saving Metrics - Test set: experiment_3/metrics_test.csv...
# Saving confusion matrix in experiment_3/test_confusion_matrix.csv...
# Task completed - results generated in experiment_3/!
# Computation time - Pipeline: 3.546472962697347 minutes

# %% [markdown]
# The training dataset with selected features.

# %%
df_best_feature_train = pd.read_csv("experiment_3/best_feature_train.csv").sample(5)
df_best_feature_train
# Out:
#             C         K         P         Q         R
# 60  -0.029100 -0.129560 -0.063861 -0.069758 -0.117077
# 195 -0.073475 -0.131870 -0.064167 -0.061191 -0.114593
# 100 -0.073475 -0.130348 -0.072736 -0.062450 -0.108602
# 24  -0.073475 -0.107231 -0.072736 -0.069758 -0.117077
# 83  -0.073475 -0.129217 -0.072736 -0.069758 -0.111536

# %% [markdown]
# Average and standard deviation of metrics using 10-fold cross-validation.

# %%
df_training_kfold = pd.read_csv("experiment_3/training_kfold(10)_metrics.csv")
df_training_kfold
# Out:
#       ACC  std_ACC     MCC  std_MCC      F1  std_F1  balanced_ACC  \
# 0  0.8417     0.06  0.6516     0.13  0.7587    0.09        0.8112
#
#    std_balanced_ACC  kappa  std_kappa   gmean  std_gmean
# 0              0.07  0.642       0.13  0.8014       0.07

# %% [markdown]
# Confusion matrix for training dataset.

# %%
df_training_confusion_matrix = pd.read_csv("experiment_3/training_confusion_matrix.csv", header=None)
df_training_confusion_matrix
# Out:
#       0    1   2    3
# 0  REAL    0   1  All
# 1     0  142  12  154
# 2     1   27  59   86
# 3   All  169  71  240

# %% [markdown]
# Selected features for test dataset.

# %%
df_best_feature_test = pd.read_csv("experiment_3/best_feature_test.csv").sample(5)
df_best_feature_test
# Out:
#            C         K         P         Q         R
# 83 -0.073475 -0.134026 -0.065833 -0.055955 -0.117077
# 9  -0.073475 -0.134026 -0.072736 -0.060202 -0.117077
# 28 -0.073475 -0.120864 -0.072736 -0.069758 -0.117077
# 55 -0.073475 -0.129560 -0.063861 -0.065321 -0.117077
# 79 -0.063121 -0.134026 -0.054098 -0.069758 -0.106271

# %% [markdown]
# Metrics regarding the test dataset.

# %%
df_metrics_test = pd.read_csv("experiment_3/metrics_test.csv")
df_metrics_test
# Out:
#                   Metrics: Test Set
# 0      Accuracy: 0.8269230769230769
# 1        Recall: 0.9038461538461539
# 2     Precision: 0.7833333333333333
# 3            F1: 0.8392857142857143
# 4           AUC: 0.8946005917159764
# 5  balanced ACC: 0.8269230769230769
# 6         gmean: 0.8233374857156787
# 7           MCC: 0.6617241025372945

# %% [markdown]
# Predictions for the test dataset.

# %%
df_test_predictions = pd.read_csv("experiment_3/test_predictions.csv", header=None).sample(5)
df_test_predictions
# Out:
#               0  1
# 9        ACP_10  0
# 62   non-ACP_20  0
# 84  non-ACP_176  1
# 19       ACP_29  1
# 90  non-ACP_182  0

# %% [markdown]
# Confusion matrix for the test dataset.

# %%
df_test_confusion_matrix = pd.read_csv("experiment_3/test_confusion_matrix.csv", header=None)
df_test_confusion_matrix
# Out:
#       0   1   2    3
# 0  REAL   0   1  All
# 1     0  47   5   52
# 2     1  13  39   52
# 3   All  60  44  104

# %% [markdown]
# Feature importance for the dataset with the most important features.

# %%
df_feature_importance = pd.read_csv("experiment_3/feature_importance.csv", header=None).head(10)
df_feature_importance
# Out:
#                             0
# 0  1. Feature (K): (0.294172)
# 1  2. Feature (C): (0.218803)
# 2  3. Feature (Q): (0.180643)
# 3  4. Feature (P): (0.158340)
# 4  5. Feature (R): (0.148042)
